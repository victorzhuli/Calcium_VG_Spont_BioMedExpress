# %%
import graphlab as gl
import numpy as np
import pandas as pd
import os
from pylab import *
# Out:
# This non-commercial license of GraphLab Create for academic use is assigned to victor.li.zhu@rutgers.edu and will expire on October 06, 2017.
# [INFO] graphlab.cython.cy_server: GraphLab Create v2.1 started. Logging: /tmp/graphlab_server_1492260146.log

# %%
# input parameters
#=================================
classifier_list = ['LR']
#=================================

window_length_list = [200]
window_step = 50
feature_type_list = [1, 2, 3] #1: prefrontal ROI, #2: Back ROIs, #3: all ROIs
l2_penalty_list = np.logspace(-2, 1.5, num=15, endpoint=True, base=10.0, dtype=None).tolist()
l1_penalty = 0.0

for mouse_id in range(1,7):

    for win_ln_idx in range(len(window_length_list)): 
        window_length = window_length_list[win_ln_idx]
        
        ##========================= load features
        # print on screen: progress
        current_progress = ("\n========================================\nLoading features: mouse%02d, window_length%03d ...\n" \
                            % (mouse_id, window_length))
        print current_progress

        # load and organize feature matrix
        comb = lz_load_feature_matrix(mouse_id, window_length, window_step)       
        
        for classifier_idx in range(len(classifier_list)):
            classifier = classifier_list[classifier_idx]

            # initiate
            AC  = [[0] * len(l2_penalty_list) for _ in range(len(feature_type_list))] 
            SE  = [[0] * len(l2_penalty_list) for _ in range(len(feature_type_list))] 
            SP  = [[0] * len(l2_penalty_list) for _ in range(len(feature_type_list))]
            AUC = [[0] * len(l2_penalty_list) for _ in range(len(feature_type_list))]

            for feature_type_idx in range(len(feature_type_list)):
                feature_type = feature_type_list[feature_type_idx]

                ##========================= classification
                for l2_penalty_idx in range(len(l2_penalty_list)):
                    l2_penalty = l2_penalty_list[l2_penalty_idx]

                    # print on screen: progress
                    current_progress = ("\n----------------------------------------\nClassifying --> classifier: %s, feature_type%03d, l2_penalty_%f ..." \
                                        % (classifier, feature_type, l2_penalty))
                    print current_progress

                    if classifier == 'LR':
                        AC[feature_type_idx][l2_penalty_idx],SE[feature_type_idx][l2_penalty_idx],SP[feature_type_idx][l2_penalty_idx],AUC[feature_type_idx][l2_penalty_idx] = \
                            lz_logistic_AC_SE_SP(comb, feature_type, l2_penalty, l1_penalty)

            ##====================== save results
            AC_saveName = ("%s_spk_mouse%02d_window_length%03d_AC.csv" \
                           % (classifier,mouse_id,window_length))
            SE_saveName = ("%s_spk_mouse%02d_window_length%03d_SE.csv" \
                           % (classifier,mouse_id,window_length))
            SP_saveName = ("%s_spk_mouse%02d_window_length%03d_SP.csv" \
                           % (classifier,mouse_id,window_length))
            AUC_saveName = ("%s_spk_mouse%02d_window_length%03d_AUC.csv" \
                           % (classifier,mouse_id,window_length))
            df_AC = pd.DataFrame(AC)
            df_SE = pd.DataFrame(SE)        
            df_SP = pd.DataFrame(SP)  
            df_AUC = pd.DataFrame(AUC)  
            
            os.chdir("/Users/lizhu/Dropbox/projects/calcium/comparison/ROI4FluoroSNNAP/classification_results") 
            df_AC.to_csv(AC_saveName, index = False, header = False)
            df_SE.to_csv(SE_saveName, index = False, header = False)
            df_SP.to_csv(SP_saveName, index = False, header = False)
            df_AUC.to_csv(AUC_saveName, index = False, header = False)
# Out:
# ========================================
# Loading features: mouse01, window_length200 ...
#
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.010000 ...
# AC_mean =  0.843775815411
# AC_std =  0.025593123795
# SE_mean =  0.438688253775
# SE_std =  0.155074682194
# SP_mean =  0.943763389579
# SP_std =  0.0192006903609
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.017783 ...
# AC_mean =  0.843775815411
# AC_std =  0.025593123795
# SE_mean =  0.438688253775
# SE_std =  0.155074682194
# SP_mean =  0.943763389579
# SP_std =  0.0192006903609
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.031623 ...
# AC_mean =  0.843775815411
# AC_std =  0.025593123795
# SE_mean =  0.438688253775
# SE_std =  0.155074682194
# SP_mean =  0.943763389579
# SP_std =  0.0192006903609
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.056234 ...
# AC_mean =  0.843775815411
# AC_std =  0.025593123795
# SE_mean =  0.438688253775
# SE_std =  0.155074682194
# SP_mean =  0.943763389579
# SP_std =  0.0192006903609
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.100000 ...
# AC_mean =  0.843775815411
# AC_std =  0.025593123795
# SE_mean =  0.438688253775
# SE_std =  0.155074682194
# SP_mean =  0.943763389579
# SP_std =  0.0192006903609
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.177828 ...
# AC_mean =  0.843775815411
# AC_std =  0.025593123795
# SE_mean =  0.438688253775
# SE_std =  0.155074682194
# SP_mean =  0.943763389579
# SP_std =  0.0192006903609
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.316228 ...
# AC_mean =  0.843775815411
# AC_std =  0.025593123795
# SE_mean =  0.438688253775
# SE_std =  0.155074682194
# SP_mean =  0.943763389579
# SP_std =  0.0192006903609
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.562341 ...
# AC_mean =  0.842080900157
# AC_std =  0.0235259941053
# SE_mean =  0.429794973143
# SE_std =  0.148158487965
# SP_mean =  0.943763389579
# SP_std =  0.0192006903609
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_1.000000 ...
# AC_mean =  0.839545648768
# AC_std =  0.0231916184126
# SE_mean =  0.425447147056
# SE_std =  0.143406456628
# SP_mean =  0.941471400606
# SP_std =  0.0185890202128
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_1.778279 ...
# AC_mean =  0.842052414186
# AC_std =  0.0200883524069
# SE_mean =  0.422158144498
# SE_std =  0.137159099492
# SP_mean =  0.94554048229
# SP_std =  0.0182772392237
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_3.162278 ...
# AC_mean =  0.836981911409
# AC_std =  0.0193701314621
# SE_mean =  0.397305989407
# SE_std =  0.128577945842
# SP_mean =  0.94554048229
# SP_std =  0.0182772392237
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_5.623413 ...
# AC_mean =  0.831904287139
# AC_std =  0.0229161666951
# SE_mean =  0.370265904598
# SE_std =  0.123751645057
# SP_mean =  0.946506041637
# SP_std =  0.0206122703764
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_10.000000 ...
# AC_mean =  0.825160233585
# AC_std =  0.0256243428959
# SE_mean =  0.327031396566
# SE_std =  0.122667661447
# SP_mean =  0.949812979194
# SP_std =  0.0254601748992
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_17.782794 ...
# AC_mean =  0.823472439823
# AC_std =  0.0278371086601
# SE_mean =  0.285859610126
# SE_std =  0.109097292461
# SP_mean =  0.956996322046
# SP_std =  0.0210302809815
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_31.622777 ...
# AC_mean =  0.808268052984
# AC_std =  0.0434051682979
# SE_mean =  0.193574273127
# SE_std =  0.11067386477
# SP_mean =  0.964432418496
# SP_std =  0.0192726531867
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.010000 ...
# AC_mean =  0.830244979348
# AC_std =  0.0280986351352
# SE_mean =  0.410654156159
# SE_std =  0.0946125333263
# SP_mean =  0.937459833433
# SP_std =  0.0263663674577
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.017783 ...
# AC_mean =  0.830244979348
# AC_std =  0.0280986351352
# SE_mean =  0.410654156159
# SE_std =  0.0946125333263
# SP_mean =  0.937459833433
# SP_std =  0.0263663674577
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.031623 ...
# AC_mean =  0.830244979348
# AC_std =  0.0280986351352
# SE_mean =  0.410654156159
# SE_std =  0.0946125333263
# SP_mean =  0.937459833433
# SP_std =  0.0263663674577
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.056234 ...
# AC_mean =  0.830244979348
# AC_std =  0.0280986351352
# SE_mean =  0.410654156159
# SE_std =  0.0946125333263
# SP_mean =  0.937459833433
# SP_std =  0.0263663674577
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.100000 ...
# AC_mean =  0.830244979348
# AC_std =  0.0280986351352
# SE_mean =  0.410654156159
# SE_std =  0.0946125333263
# SP_mean =  0.937459833433
# SP_std =  0.0263663674577
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.177828 ...
# AC_mean =  0.828557185586
# AC_std =  0.0274735188381
# SE_mean =  0.403276027042
# SE_std =  0.0933429152652
# SP_mean =  0.937459833433
# SP_std =  0.0263663674577
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.316228 ...
# AC_mean =  0.829404643213
# AC_std =  0.0281654494706
# SE_mean =  0.407442693709
# SE_std =  0.0965813683687
# SP_mean =  0.937459833433
# SP_std =  0.0263663674577
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.562341 ...
# AC_mean =  0.829397521721
# AC_std =  0.0292268210676
# SE_mean =  0.408501517238
# SE_std =  0.090743597072
# SP_mean =  0.937459833433
# SP_std =  0.0263663674577
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_1.000000 ...
# AC_mean =  0.829397521721
# AC_std =  0.0292268210676
# SE_mean =  0.403956062693
# SE_std =  0.0917332694012
# SP_mean =  0.938512465012
# SP_std =  0.0273528514303
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_1.778279 ...
# AC_mean =  0.828542942601
# AC_std =  0.0340979597301
# SE_mean =  0.396667060135
# SE_std =  0.0979723887432
# SP_mean =  0.939515707354
# SP_std =  0.0287708221247
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_3.162278 ...
# AC_mean =  0.831911408631
# AC_std =  0.0313907617536
# SE_mean =  0.392283943252
# SE_std =  0.0883973404334
# SP_mean =  0.94468773362
# SP_std =  0.0239833852251
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_5.623413 ...
# AC_mean =  0.83022361487
# AC_std =  0.0352195217929
# SE_mean =  0.351522420461
# SE_std =  0.078665643406
# SP_mean =  0.95313903591
# SP_std =  0.0216978225331
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_10.000000 ...
# AC_mean =  0.826833784361
# AC_std =  0.0324639349494
# SE_mean =  0.30980164124
# SE_std =  0.0698301763709
# SP_mean =  0.959374891963
# SP_std =  0.0182805441832
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_17.782794 ...
# AC_mean =  0.820937188435
# AC_std =  0.0313696570372
# SE_mean =  0.260142785603
# SE_std =  0.0827839347411
# SP_mean =  0.964616812706
# SP_std =  0.0175008355339
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_31.622777 ...
# AC_mean =  0.819235151688
# AC_std =  0.0371105629268
# SE_mean =  0.220085059016
# SE_std =  0.089289104763
# SP_mean =  0.971647255461
# SP_std =  0.0151853847316
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.010000 ...
# AC_mean =  0.866550348953
# AC_std =  0.0210302742719
# SE_mean =  0.568049987949
# SE_std =  0.0456578152788
# SP_mean =  0.941600705783
# SP_std =  0.0221423274847
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.017783 ...
# AC_mean =  0.868238142715
# AC_std =  0.0221738123953
# SE_mean =  0.572049987949
# SE_std =  0.0429445711637
# SP_mean =  0.94264237245
# SP_std =  0.0235925691916
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.031623 ...
# AC_mean =  0.868238142715
# AC_std =  0.0221738123953
# SE_mean =  0.572049987949
# SE_std =  0.0429445711637
# SP_mean =  0.94264237245
# SP_std =  0.0235925691916
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.056234 ...
# AC_mean =  0.869925936476
# AC_std =  0.0234467453895
# SE_mean =  0.584287750187
# SE_std =  0.0463411472478
# SP_mean =  0.94264237245
# SP_std =  0.0235925691916
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.100000 ...
# AC_mean =  0.869925936476
# AC_std =  0.0234467453895
# SE_mean =  0.584287750187
# SE_std =  0.0463411472478
# SP_mean =  0.94264237245
# SP_std =  0.0235925691916
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.177828 ...
# AC_mean =  0.871613730238
# AC_std =  0.0230179334348
# SE_mean =  0.584666538066
# SE_std =  0.0428402059633
# SP_mean =  0.944737130072
# SP_std =  0.0230786161903
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.316228 ...
# AC_mean =  0.871606608745
# AC_std =  0.0242630718265
# SE_mean =  0.584666538066
# SE_std =  0.0428402059633
# SP_mean =  0.944868992935
# SP_std =  0.0256953953414
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.562341 ...
# AC_mean =  0.870766272611
# AC_std =  0.0224760457363
# SE_mean =  0.570849015009
# SE_std =  0.0507882985546
# SP_mean =  0.946952552349
# SP_std =  0.0258653676884
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_1.000000 ...
# AC_mean =  0.870766272611
# AC_std =  0.0228038835502
# SE_mean =  0.567223473883
# SE_std =  0.0540696601604
# SP_mean =  0.948016382136
# SP_std =  0.0260556400474
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_1.778279 ...
# AC_mean =  0.872461187865
# AC_std =  0.0232094340693
# SE_mean =  0.575768928429
# SE_std =  0.0544190020701
# SP_mean =  0.947983480184
# SP_std =  0.0244264721152
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_3.162278 ...
# AC_mean =  0.867383563595
# AC_std =  0.022504948963
# SE_mean =  0.548570834962
# SE_std =  0.0505669059312
# SP_mean =  0.94913484158
# SP_std =  0.0268755757577
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_5.623413 ...
# AC_mean =  0.869078478849
# AC_std =  0.0222150668942
# SE_mean =  0.544439459092
# SE_std =  0.0628038159373
# SP_mean =  0.952249328829
# SP_std =  0.0263969138536
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_10.000000 ...
# AC_mean =  0.866536105968
# AC_std =  0.0257266216664
# SE_mean =  0.53455710615
# SE_std =  0.068927585163
# SP_mean =  0.952151058388
# SP_std =  0.0231723269435
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_17.782794 ...
# AC_mean =  0.863993733086
# AC_std =  0.0336606946565
# SE_mean =  0.498785524791
# SE_std =  0.0813165447171
# SP_mean =  0.958424597437
# SP_std =  0.0233901588101
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_31.622777 ...
# AC_mean =  0.858068651189
# AC_std =  0.0360521864722
# SE_mean =  0.4508537213
# SE_std =  0.0810761515831
# SP_mean =  0.962526581072
# SP_std =  0.0217295755599
#
# ========================================
# Loading features: mouse02, window_length200 ...
#
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.010000 ...
# AC_mean =  0.855339435545
# AC_std =  0.0328303695959
# SE_mean =  0.70543808598
# SE_std =  0.0742976549603
# SP_mean =  0.928370640352
# SP_std =  0.0284910619162
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.017783 ...
# AC_mean =  0.855339435545
# AC_std =  0.0328303695959
# SE_mean =  0.70543808598
# SE_std =  0.0742976549603
# SP_mean =  0.928370640352
# SP_std =  0.0284910619162
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.031623 ...
# AC_mean =  0.855339435545
# AC_std =  0.0328303695959
# SE_mean =  0.70543808598
# SE_std =  0.0742976549603
# SP_mean =  0.928370640352
# SP_std =  0.0284910619162
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.056234 ...
# AC_mean =  0.855339435545
# AC_std =  0.0299392499514
# SE_mean =  0.703312482116
# SE_std =  0.0664593756687
# SP_mean =  0.928370640352
# SP_std =  0.0284910619162
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.100000 ...
# AC_mean =  0.856216628528
# AC_std =  0.031429150531
# SE_mean =  0.703312482116
# SE_std =  0.0664593756687
# SP_mean =  0.929561116542
# SP_std =  0.0292116149767
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.177828 ...
# AC_mean =  0.857086193745
# AC_std =  0.0311840201581
# SE_mean =  0.703312482116
# SE_std =  0.0664593756687
# SP_mean =  0.930765935819
# SP_std =  0.0267724731086
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.316228 ...
# AC_mean =  0.857955758963
# AC_std =  0.0294082504739
# SE_mean =  0.703312482116
# SE_std =  0.0664593756687
# SP_mean =  0.932194507248
# SP_std =  0.0269974562242
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.562341 ...
# AC_mean =  0.857086193745
# AC_std =  0.0311840201581
# SE_mean =  0.701090259893
# SE_std =  0.0708464895248
# SP_mean =  0.932194507248
# SP_std =  0.0269974562242
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_1.000000 ...
# AC_mean =  0.858817696415
# AC_std =  0.0360888009395
# SE_mean =  0.6971730609
# SE_std =  0.0722535051871
# SP_mean =  0.936778058846
# SP_std =  0.0228759164798
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_1.778279 ...
# AC_mean =  0.86055682685
# AC_std =  0.0383709859907
# SE_mean =  0.691667108519
# SE_std =  0.0731779459072
# SP_mean =  0.941762379691
# SP_std =  0.018872290882
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_3.162278 ...
# AC_mean =  0.858787185355
# AC_std =  0.0359738541776
# SE_mean =  0.688217631167
# SE_std =  0.0658879554971
# SP_mean =  0.94042500474
# SP_std =  0.0203847728049
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_5.623413 ...
# AC_mean =  0.862273073989
# AC_std =  0.0355747579671
# SE_mean =  0.6934259645
# SE_std =  0.0652101767104
# SP_mean =  0.943044052359
# SP_std =  0.0218786553242
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_10.000000 ...
# AC_mean =  0.860526315789
# AC_std =  0.0349979159547
# SE_mean =  0.686639114023
# SE_std =  0.0640984808028
# SP_mean =  0.943044052359
# SP_std =  0.0218786553242
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_17.782794 ...
# AC_mean =  0.859649122807
# AC_std =  0.0348797437964
# SE_mean =  0.68455578069
# SE_std =  0.0636968222188
# SP_mean =  0.94294053269
# SP_std =  0.0219858103422
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_31.622777 ...
# AC_mean =  0.852692601068
# AC_std =  0.0415566885148
# SE_mean =  0.660798763655
# SE_std =  0.0747959840781
# SP_mean =  0.945529907899
# SP_std =  0.0209687246245
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.010000 ...
# AC_mean =  0.798604118993
# AC_std =  0.0307790868619
# SE_mean =  0.618806914777
# SE_std =  0.100525302326
# SP_mean =  0.890669479342
# SP_std =  0.0331865312464
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.017783 ...
# AC_mean =  0.798604118993
# AC_std =  0.0307790868619
# SE_mean =  0.618806914777
# SE_std =  0.100525302326
# SP_mean =  0.890669479342
# SP_std =  0.0331865312464
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.031623 ...
# AC_mean =  0.798604118993
# AC_std =  0.0307790868619
# SE_mean =  0.618806914777
# SE_std =  0.100525302326
# SP_mean =  0.890669479342
# SP_std =  0.0331865312464
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.056234 ...
# AC_mean =  0.799473684211
# AC_std =  0.0325951716305
# SE_mean =  0.618806914777
# SE_std =  0.100525302326
# SP_mean =  0.891756435863
# SP_std =  0.0326511913437
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.100000 ...
# AC_mean =  0.801212814645
# AC_std =  0.0325768522508
# SE_mean =  0.618806914777
# SE_std =  0.100525302326
# SP_mean =  0.894389826569
# SP_std =  0.0347937005074
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.177828 ...
# AC_mean =  0.801212814645
# AC_std =  0.0325768522508
# SE_mean =  0.618806914777
# SE_std =  0.100525302326
# SP_mean =  0.894389826569
# SP_std =  0.0347937005074
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.316228 ...
# AC_mean =  0.800343249428
# AC_std =  0.0322477920445
# SE_mean =  0.61594977192
# SE_std =  0.100613163025
# SP_mean =  0.894389826569
# SP_std =  0.0347937005074
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.562341 ...
# AC_mean =  0.802082379863
# AC_std =  0.031946497972
# SE_mean =  0.62532477192
# SE_std =  0.0965707174838
# SP_mean =  0.893185007292
# SP_std =  0.0362982786439
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_1.000000 ...
# AC_mean =  0.800343249428
# AC_std =  0.0310532723721
# SE_mean =  0.619342629063
# SE_std =  0.0960495921497
# SP_mean =  0.893185007292
# SP_std =  0.0362982786439
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_1.778279 ...
# AC_mean =  0.800358504958
# AC_std =  0.0353139170309
# SE_mean =  0.608467025198
# SE_std =  0.0954565426109
# SP_mean =  0.897857735472
# SP_std =  0.0334486701337
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_3.162278 ...
# AC_mean =  0.799481311976
# AC_std =  0.0373194951898
# SE_mean =  0.600611334141
# SE_std =  0.0960957234152
# SP_mean =  0.900314555007
# SP_std =  0.0332972812792
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_5.623413 ...
# AC_mean =  0.802959572845
# AC_std =  0.0397599300874
# SE_mean =  0.597010143665
# SE_std =  0.0912947319871
# SP_mean =  0.906506414688
# SP_std =  0.0355061281926
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_10.000000 ...
# AC_mean =  0.795987795576
# AC_std =  0.0391531360393
# SE_mean =  0.569286713713
# SE_std =  0.0874784555706
# SP_mean =  0.907593001741
# SP_std =  0.0304283337466
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_17.782794 ...
# AC_mean =  0.802082379863
# AC_std =  0.0363772274482
# SE_mean =  0.558008403609
# SE_std =  0.0864886909678
# SP_mean =  0.921660244762
# SP_std =  0.0303870655681
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_31.622777 ...
# AC_mean =  0.789877955759
# AC_std =  0.036673609862
# SE_mean =  0.505093504351
# SE_std =  0.0822986714475
# SP_mean =  0.928448405232
# SP_std =  0.0309390879663
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.010000 ...
# AC_mean =  0.863157894737
# AC_std =  0.0274067838484
# SE_mean =  0.776162723661
# SE_std =  0.0737067779395
# SP_mean =  0.907625918344
# SP_std =  0.0220917392129
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.017783 ...
# AC_mean =  0.863157894737
# AC_std =  0.0274067838484
# SE_mean =  0.776162723661
# SE_std =  0.0737067779395
# SP_mean =  0.907625918344
# SP_std =  0.0220917392129
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.031623 ...
# AC_mean =  0.863157894737
# AC_std =  0.0274067838484
# SE_mean =  0.776162723661
# SE_std =  0.0737067779395
# SP_mean =  0.907625918344
# SP_std =  0.0220917392129
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.056234 ...
# AC_mean =  0.863157894737
# AC_std =  0.0274067838484
# SE_mean =  0.776162723661
# SE_std =  0.0737067779395
# SP_mean =  0.907625918344
# SP_std =  0.0220917392129
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.100000 ...
# AC_mean =  0.864027459954
# AC_std =  0.0277322964025
# SE_mean =  0.778543676042
# SE_std =  0.0751170542288
# SP_mean =  0.907625918344
# SP_std =  0.0220917392129
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.177828 ...
# AC_mean =  0.864027459954
# AC_std =  0.0271815105736
# SE_mean =  0.777769866519
# SE_std =  0.0748460332099
# SP_mean =  0.907625918344
# SP_std =  0.0220917392129
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.316228 ...
# AC_mean =  0.864027459954
# AC_std =  0.0235745874528
# SE_mean =  0.774018414718
# SE_std =  0.0760635871173
# SP_mean =  0.909054489773
# SP_std =  0.0210667421244
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.562341 ...
# AC_mean =  0.865774218154
# AC_std =  0.0263052201329
# SE_mean =  0.779732700433
# SE_std =  0.0784490727617
# SP_mean =  0.909099670495
# SP_std =  0.0241864082334
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_1.000000 ...
# AC_mean =  0.864904652937
# AC_std =  0.0274348018122
# SE_mean =  0.775000557575
# SE_std =  0.0798059078142
# SP_mean =  0.910429164331
# SP_std =  0.0243463810388
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_1.778279 ...
# AC_mean =  0.865758962624
# AC_std =  0.0223144253719
# SE_mean =  0.772619605194
# SE_std =  0.0732187012146
# SP_mean =  0.913364616159
# SP_std =  0.0241736123391
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_3.162278 ...
# AC_mean =  0.870968726163
# AC_std =  0.0212438447159
# SE_mean =  0.777966827417
# SE_std =  0.0704692510159
# SP_mean =  0.918473981031
# SP_std =  0.0252061345662
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_5.623413 ...
# AC_mean =  0.875339435545
# AC_std =  0.024579306834
# SE_mean =  0.776647382972
# SE_std =  0.0766430321801
# SP_mean =  0.925945143653
# SP_std =  0.0250300461264
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_10.000000 ...
# AC_mean =  0.875339435545
# AC_std =  0.0272075023578
# SE_mean =  0.773790240115
# SE_std =  0.0783626879062
# SP_mean =  0.926867056439
# SP_std =  0.0253636418774
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_17.782794 ...
# AC_mean =  0.870976353928
# AC_std =  0.0308187054791
# SE_mean =  0.748030706627
# SE_std =  0.0842586641196
# SP_mean =  0.933207712605
# SP_std =  0.0208103985049
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_31.622777 ...
# AC_mean =  0.860511060259
# AC_std =  0.0343398738608
# SE_mean =  0.705134901698
# SE_std =  0.0655870712272
# SP_mean =  0.935443149717
# SP_std =  0.0235452888684
#
# ========================================
# Loading features: mouse03, window_length200 ...
#
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.010000 ...
# AC_mean =  0.822135774218
# AC_std =  0.0210869230666
# SE_mean =  0.305702583478
# SE_std =  0.0753375433079
# SP_mean =  0.95836460727
# SP_std =  0.0159018259428
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.017783 ...
# AC_mean =  0.822135774218
# AC_std =  0.0210869230666
# SE_mean =  0.305702583478
# SE_std =  0.0753375433079
# SP_mean =  0.95836460727
# SP_std =  0.0159018259428
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.031623 ...
# AC_mean =  0.822135774218
# AC_std =  0.0210869230666
# SE_mean =  0.305702583478
# SE_std =  0.0753375433079
# SP_mean =  0.95836460727
# SP_std =  0.0159018259428
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.056234 ...
# AC_mean =  0.822135774218
# AC_std =  0.0210869230666
# SE_mean =  0.305702583478
# SE_std =  0.0753375433079
# SP_mean =  0.95836460727
# SP_std =  0.0159018259428
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.100000 ...
# AC_mean =  0.822135774218
# AC_std =  0.0210869230666
# SE_mean =  0.305702583478
# SE_std =  0.0753375433079
# SP_mean =  0.95836460727
# SP_std =  0.0159018259428
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.177828 ...
# AC_mean =  0.821266209001
# AC_std =  0.0221350540108
# SE_mean =  0.301998879774
# SE_std =  0.0766086054118
# SP_mean =  0.95836460727
# SP_std =  0.0159018259428
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.316228 ...
# AC_mean =  0.821266209001
# AC_std =  0.0221350540108
# SE_mean =  0.301998879774
# SE_std =  0.0766086054118
# SP_mean =  0.95836460727
# SP_std =  0.0159018259428
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.562341 ...
# AC_mean =  0.821266209001
# AC_std =  0.0234617158249
# SE_mean =  0.298796848312
# SE_std =  0.0841799858712
# SP_mean =  0.959406273937
# SP_std =  0.0140522016999
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_1.000000 ...
# AC_mean =  0.822128146453
# AC_std =  0.0228696743088
# SE_mean =  0.298476335491
# SE_std =  0.0847840195247
# SP_mean =  0.960555699224
# SP_std =  0.0149466778935
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_1.778279 ...
# AC_mean =  0.821250953471
# AC_std =  0.0232608617486
# SE_mean =  0.294309668824
# SE_std =  0.0860309665584
# SP_mean =  0.960555699224
# SP_std =  0.0149466778935
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_3.162278 ...
# AC_mean =  0.821250953471
# AC_std =  0.0232608617486
# SE_mean =  0.294309668824
# SE_std =  0.0860309665584
# SP_mean =  0.960555699224
# SP_std =  0.0149466778935
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_5.623413 ...
# AC_mean =  0.817772692601
# AC_std =  0.0204869046839
# SE_mean =  0.27204684393
# SE_std =  0.0867315156035
# SP_mean =  0.961642655746
# SP_std =  0.0141999113485
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_10.000000 ...
# AC_mean =  0.816903127384
# AC_std =  0.0174909226875
# SE_mean =  0.251294857286
# SE_std =  0.0630212708713
# SP_mean =  0.966016762213
# SP_std =  0.0134925060839
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_17.782794 ...
# AC_mean =  0.817795575896
# AC_std =  0.0210153178097
# SE_mean =  0.223381707634
# SE_std =  0.0783343771932
# SP_mean =  0.974780028267
# SP_std =  0.0125329354681
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_31.622777 ...
# AC_mean =  0.814309687262
# AC_std =  0.02421740811
# SE_mean =  0.190288583603
# SE_std =  0.0732961475199
# SP_mean =  0.979171114951
# SP_std =  0.0145036570309
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.010000 ...
# AC_mean =  0.801250953471
# AC_std =  0.0249064038736
# SE_mean =  0.225581135462
# SE_std =  0.0710861146523
# SP_mean =  0.952808744821
# SP_std =  0.0251360955102
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.017783 ...
# AC_mean =  0.801250953471
# AC_std =  0.0249064038736
# SE_mean =  0.225581135462
# SE_std =  0.0710861146523
# SP_mean =  0.952808744821
# SP_std =  0.0251360955102
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.031623 ...
# AC_mean =  0.801250953471
# AC_std =  0.0249064038736
# SE_mean =  0.225581135462
# SE_std =  0.0710861146523
# SP_mean =  0.952808744821
# SP_std =  0.0251360955102
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.056234 ...
# AC_mean =  0.801250953471
# AC_std =  0.0249064038736
# SE_mean =  0.225581135462
# SE_std =  0.0710861146523
# SP_mean =  0.952808744821
# SP_std =  0.0251360955102
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.100000 ...
# AC_mean =  0.801250953471
# AC_std =  0.0249064038736
# SE_mean =  0.225581135462
# SE_std =  0.0710861146523
# SP_mean =  0.952808744821
# SP_std =  0.0251360955102
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.177828 ...
# AC_mean =  0.799504195271
# AC_std =  0.0261741120395
# SE_mean =  0.218286705754
# SE_std =  0.0710937841519
# SP_mean =  0.952808744821
# SP_std =  0.0251360955102
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.316228 ...
# AC_mean =  0.799504195271
# AC_std =  0.0249918516255
# SE_mean =  0.213023547859
# SE_std =  0.0770671042675
# SP_mean =  0.953872574608
# SP_std =  0.0236925814795
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.562341 ...
# AC_mean =  0.802112890923
# AC_std =  0.0268080741326
# SE_mean =  0.213023547859
# SE_std =  0.0770671042675
# SP_mean =  0.957065027584
# SP_std =  0.0231495833681
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_1.000000 ...
# AC_mean =  0.802097635393
# AC_std =  0.026636506193
# SE_mean =  0.205029817452
# SE_std =  0.0718500181366
# SP_mean =  0.959192687158
# SP_std =  0.0210347847445
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_1.778279 ...
# AC_mean =  0.797726926011
# AC_std =  0.0260773821426
# SE_mean =  0.17964190715
# SE_std =  0.0682270145043
# SP_mean =  0.96027964368
# SP_std =  0.0194010453843
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_3.162278 ...
# AC_mean =  0.796864988558
# AC_std =  0.0248896311709
# SE_mean =  0.167737145245
# SE_std =  0.0607317841111
# SP_mean =  0.962430429989
# SP_std =  0.018922880867
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_5.623413 ...
# AC_mean =  0.794233409611
# AC_std =  0.0276494478816
# SE_mean =  0.140091435272
# SE_std =  0.0547556150813
# SP_mean =  0.966799353553
# SP_std =  0.0175197671586
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_10.000000 ...
# AC_mean =  0.795972540046
# AC_std =  0.0238929023193
# SE_mean =  0.115156581271
# SE_std =  0.0460089775031
# SP_mean =  0.975748244855
# SP_std =  0.0145214391363
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_17.782794 ...
# AC_mean =  0.798573607933
# AC_std =  0.0247174440292
# SE_mean =  0.0718025325222
# SE_std =  0.0425694355789
# SP_mean =  0.99000174499
# SP_std =  0.0115428705869
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_31.622777 ...
# AC_mean =  0.795964912281
# AC_std =  0.0304232996046
# SE_mean =  0.0338284029813
# SE_std =  0.0268145887061
# SP_mean =  0.997699933906
# SP_std =  0.00460165133579
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.010000 ...
# AC_mean =  0.837818459191
# AC_std =  0.0244800116323
# SE_mean =  0.468864141906
# SE_std =  0.132106863281
# SP_mean =  0.935349311315
# SP_std =  0.0313876011639
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.017783 ...
# AC_mean =  0.837818459191
# AC_std =  0.0244800116323
# SE_mean =  0.468864141906
# SE_std =  0.132106863281
# SP_mean =  0.935349311315
# SP_std =  0.0313876011639
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.031623 ...
# AC_mean =  0.837818459191
# AC_std =  0.0244800116323
# SE_mean =  0.468864141906
# SE_std =  0.132106863281
# SP_mean =  0.935349311315
# SP_std =  0.0313876011639
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.056234 ...
# AC_mean =  0.838695652174
# AC_std =  0.0241441128404
# SE_mean =  0.468864141906
# SE_std =  0.132106863281
# SP_mean =  0.936436267836
# SP_std =  0.0307786262806
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.100000 ...
# AC_mean =  0.838695652174
# AC_std =  0.0241441128404
# SE_mean =  0.468864141906
# SE_std =  0.132106863281
# SP_mean =  0.936436267836
# SP_std =  0.0307786262806
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.177828 ...
# AC_mean =  0.838695652174
# AC_std =  0.0241441128404
# SE_mean =  0.468864141906
# SE_std =  0.132106863281
# SP_mean =  0.936436267836
# SP_std =  0.0307786262806
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.316228 ...
# AC_mean =  0.837826086957
# AC_std =  0.0224902541289
# SE_mean =  0.460670161973
# SE_std =  0.123879145922
# SP_mean =  0.937559863342
# SP_std =  0.0324195498213
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.562341 ...
# AC_mean =  0.838695652174
# AC_std =  0.020036559203
# SE_mean =  0.456322335886
# SE_std =  0.11443243178
# SP_mean =  0.939665359796
# SP_std =  0.0313018919737
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_1.000000 ...
# AC_mean =  0.840434782609
# AC_std =  0.0196170472808
# SE_mean =  0.456322335886
# SE_std =  0.11443243178
# SP_mean =  0.941866516833
# SP_std =  0.0306553469814
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_1.778279 ...
# AC_mean =  0.839565217391
# AC_std =  0.0204235044126
# SE_mean =  0.444540726691
# SE_std =  0.114323787411
# SP_mean =  0.943995140022
# SP_std =  0.0290629374717
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_3.162278 ...
# AC_mean =  0.836064073227
# AC_std =  0.0228704718711
# SE_mean =  0.412547190631
# SE_std =  0.103927127511
# SP_mean =  0.948370274344
# SP_std =  0.0306491853162
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_5.623413 ...
# AC_mean =  0.835194508009
# AC_std =  0.0227193773146
# SE_mean =  0.399306083911
# SE_std =  0.0863265639597
# SP_mean =  0.950655864574
# SP_std =  0.0301520603882
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_10.000000 ...
# AC_mean =  0.831708619375
# AC_std =  0.0211725118531
# SE_mean =  0.366565676171
# SE_std =  0.0975345059821
# SP_mean =  0.954952254289
# SP_std =  0.0259413093917
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_17.782794 ...
# AC_mean =  0.82823798627
# AC_std =  0.0217541078118
# SE_mean =  0.322289216763
# SE_std =  0.113655626983
# SP_mean =  0.96140557683
# SP_std =  0.0238753666567
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_31.622777 ...
# AC_mean =  0.821266209001
# AC_std =  0.0247172733697
# SE_mean =  0.266160653936
# SE_std =  0.123938499553
# SP_mean =  0.968037028261
# SP_std =  0.0202435200753
#
# ========================================
# Loading features: mouse04, window_length200 ...
#
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.010000 ...
# AC_mean =  0.787957555904
# AC_std =  0.0364829176029
# SE_mean =  0.682407540693
# SE_std =  0.0529864613254
# SP_mean =  0.845212093185
# SP_std =  0.0431567325584
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.017783 ...
# AC_mean =  0.787957555904
# AC_std =  0.0364829176029
# SE_mean =  0.682407540693
# SE_std =  0.0529864613254
# SP_mean =  0.845212093185
# SP_std =  0.0431567325584
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.031623 ...
# AC_mean =  0.787957555904
# AC_std =  0.0364829176029
# SE_mean =  0.682407540693
# SE_std =  0.0529864613254
# SP_mean =  0.845212093185
# SP_std =  0.0431567325584
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.056234 ...
# AC_mean =  0.787957555904
# AC_std =  0.0364829176029
# SE_mean =  0.682407540693
# SE_std =  0.0529864613254
# SP_mean =  0.845212093185
# SP_std =  0.0431567325584
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.100000 ...
# AC_mean =  0.787117219769
# AC_std =  0.0353458276991
# SE_mean =  0.680185318471
# SE_std =  0.0492761789088
# SP_mean =  0.845212093185
# SP_std =  0.0431567325584
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.177828 ...
# AC_mean =  0.787117219769
# AC_std =  0.0353458276991
# SE_mean =  0.680185318471
# SE_std =  0.0492761789088
# SP_mean =  0.845212093185
# SP_std =  0.0431567325584
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.316228 ...
# AC_mean =  0.787117219769
# AC_std =  0.0353458276991
# SE_mean =  0.680185318471
# SE_std =  0.0492761789088
# SP_mean =  0.845212093185
# SP_std =  0.0431567325584
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.562341 ...
# AC_mean =  0.788797892038
# AC_std =  0.0352390001524
# SE_mean =  0.680185318471
# SE_std =  0.0492761789088
# SP_mean =  0.847759967252
# SP_std =  0.0417187104435
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_1.000000 ...
# AC_mean =  0.789638228173
# AC_std =  0.0363405863126
# SE_mean =  0.677963096248
# SE_std =  0.0522513159011
# SP_mean =  0.850393369885
# SP_std =  0.0437332193436
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_1.778279 ...
# AC_mean =  0.790492807292
# AC_std =  0.0343431936651
# SE_mean =  0.675655650806
# SE_std =  0.0543844568604
# SP_mean =  0.853152121788
# SP_std =  0.0434689156909
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_3.162278 ...
# AC_mean =  0.790478564307
# AC_std =  0.0377826086918
# SE_mean =  0.669037293318
# SE_std =  0.0627155923308
# SP_mean =  0.857067997223
# SP_std =  0.0446721152812
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_5.623413 ...
# AC_mean =  0.789652471158
# AC_std =  0.0368404810012
# SE_mean =  0.661717316546
# SE_std =  0.0592228973117
# SP_mean =  0.859722708896
# SP_std =  0.0431053695581
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_10.000000 ...
# AC_mean =  0.790499928785
# AC_std =  0.0357061841862
# SE_mean =  0.659217316546
# SE_std =  0.0601846172101
# SP_mean =  0.862500486674
# SP_std =  0.0412764968637
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_17.782794 ...
# AC_mean =  0.792180601054
# AC_std =  0.0390615631939
# SE_mean =  0.654495094324
# SE_std =  0.0659058191856
# SP_mean =  0.867719300912
# SP_std =  0.0437021891842
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_31.622777 ...
# AC_mean =  0.795577553055
# AC_std =  0.0364328806492
# SE_mean =  0.642305522998
# SE_std =  0.0606647983247
# SP_mean =  0.879407756619
# SP_std =  0.0430448354745
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.010000 ...
# AC_mean =  0.78802877083
# AC_std =  0.0219040317099
# SE_mean =  0.625085524433
# SE_std =  0.0379858778371
# SP_mean =  0.876657976714
# SP_std =  0.0433385121664
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.017783 ...
# AC_mean =  0.78802877083
# AC_std =  0.0219040317099
# SE_mean =  0.625085524433
# SE_std =  0.0379858778371
# SP_mean =  0.876657976714
# SP_std =  0.0433385121664
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.031623 ...
# AC_mean =  0.78802877083
# AC_std =  0.0219040317099
# SE_mean =  0.625085524433
# SE_std =  0.0379858778371
# SP_mean =  0.876657976714
# SP_std =  0.0433385121664
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.056234 ...
# AC_mean =  0.78802877083
# AC_std =  0.0219040317099
# SE_mean =  0.625085524433
# SE_std =  0.0379858778371
# SP_mean =  0.876657976714
# SP_std =  0.0433385121664
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.100000 ...
# AC_mean =  0.788876228457
# AC_std =  0.0217271174185
# SE_mean =  0.625085524433
# SE_std =  0.0379858778371
# SP_mean =  0.877940027996
# SP_std =  0.0426005142788
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.177828 ...
# AC_mean =  0.790556900726
# AC_std =  0.0242017408562
# SE_mean =  0.627307746655
# SE_std =  0.0384011142012
# SP_mean =  0.879291379348
# SP_std =  0.0444805119107
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.316228 ...
# AC_mean =  0.790556900726
# AC_std =  0.0242017408562
# SE_mean =  0.627307746655
# SE_std =  0.0384011142012
# SP_mean =  0.879291379348
# SP_std =  0.0444805119107
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.562341 ...
# AC_mean =  0.791404358354
# AC_std =  0.0242504434869
# SE_mean =  0.627307746655
# SE_std =  0.0384011142012
# SP_mean =  0.88057343063
# SP_std =  0.0455269849034
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_1.000000 ...
# AC_mean =  0.78888334995
# AC_std =  0.0286752055525
# SE_mean =  0.625133833612
# SE_std =  0.0387760602007
# SP_mean =  0.878164851164
# SP_std =  0.0526207034368
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_1.778279 ...
# AC_mean =  0.787202677681
# AC_std =  0.0280578758532
# SE_mean =  0.627514785993
# SE_std =  0.0320253224611
# SP_mean =  0.874218894593
# SP_std =  0.0502574516355
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_3.162278 ...
# AC_mean =  0.788876228457
# AC_std =  0.0232800974343
# SE_mean =  0.627264159426
# SE_std =  0.0384730647916
# SP_mean =  0.876750540163
# SP_std =  0.045460967794
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_5.623413 ...
# AC_mean =  0.791418601339
# AC_std =  0.0225873372027
# SE_mean =  0.624700056862
# SE_std =  0.0365688962425
# SP_mean =  0.882148180954
# SP_std =  0.0483864756469
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_10.000000 ...
# AC_mean =  0.791418601339
# AC_std =  0.0222886895573
# SE_mean =  0.615316588028
# SE_std =  0.034647622738
# SP_mean =  0.887437122493
# SP_std =  0.0498375307303
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_17.782794 ...
# AC_mean =  0.786340977069
# AC_std =  0.0227067048696
# SE_mean =  0.605743938455
# SE_std =  0.0404886848713
# SP_mean =  0.884873019929
# SP_std =  0.0515367911979
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_31.622777 ...
# AC_mean =  0.782110810426
# AC_std =  0.0226634318119
# SE_mean =  0.586502628659
# SE_std =  0.0427371646233
# SP_mean =  0.888615133546
# SP_std =  0.0477126055413
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.010000 ...
# AC_mean =  0.823493804301
# AC_std =  0.032183304958
# SE_mean =  0.703914795043
# SE_std =  0.0380023763148
# SP_mean =  0.888864373488
# SP_std =  0.0600319547383
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.017783 ...
# AC_mean =  0.823493804301
# AC_std =  0.032183304958
# SE_mean =  0.703914795043
# SE_std =  0.0380023763148
# SP_mean =  0.888864373488
# SP_std =  0.0600319547383
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.031623 ...
# AC_mean =  0.823493804301
# AC_std =  0.032183304958
# SE_mean =  0.703914795043
# SE_std =  0.0380023763148
# SP_mean =  0.888864373488
# SP_std =  0.0600319547383
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.056234 ...
# AC_mean =  0.822646346674
# AC_std =  0.031648256335
# SE_mean =  0.701692572821
# SE_std =  0.0418680990653
# SP_mean =  0.888864373488
# SP_std =  0.0600319547383
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.100000 ...
# AC_mean =  0.823493804301
# AC_std =  0.031277953316
# SE_mean =  0.701692572821
# SE_std =  0.0418680990653
# SP_mean =  0.890130196273
# SP_std =  0.0595575751784
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.177828 ...
# AC_mean =  0.822653468167
# AC_std =  0.0333424004824
# SE_mean =  0.699128470257
# SE_std =  0.0401277573427
# SP_mean =  0.890130196273
# SP_std =  0.0595575751784
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.316228 ...
# AC_mean =  0.825188719556
# AC_std =  0.0345968541707
# SE_mean =  0.701350692479
# SE_std =  0.0362336281233
# SP_mean =  0.892763598906
# SP_std =  0.060047162442
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.562341 ...
# AC_mean =  0.825188719556
# AC_std =  0.0358207265431
# SE_mean =  0.706204493648
# SE_std =  0.034689008506
# SP_mean =  0.889985821129
# SP_std =  0.0614312039795
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_1.000000 ...
# AC_mean =  0.824334140436
# AC_std =  0.0345811214464
# SE_mean =  0.708985398381
# SE_std =  0.0383090174828
# SP_mean =  0.887333906833
# SP_std =  0.0582421320323
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_1.778279 ...
# AC_mean =  0.825188719556
# AC_std =  0.0275303136509
# SE_mean =  0.706885127378
# SE_std =  0.0352709892488
# SP_mean =  0.889865552402
# SP_std =  0.0550169037527
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_3.162278 ...
# AC_mean =  0.824348383421
# AC_std =  0.0289592896397
# SE_mean =  0.700040563348
# SE_std =  0.0327642000166
# SP_mean =  0.892451080969
# SP_std =  0.0562785137505
#
# ...
# AC_mean =  0.86491240564
# AC_std =  0.0256652796025
# SE_mean =  0.554411463934
# SE_std =  0.110953736515
# SP_mean =  0.937952014198
# SP_std =  0.0241621843932
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.017783 ...
# AC_mean =  0.86491240564
# AC_std =  0.0256652796025
# SE_mean =  0.554411463934
# SE_std =  0.110953736515
# SP_mean =  0.937952014198
# SP_std =  0.0241621843932
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.031623 ...
# AC_mean =  0.86491240564
# AC_std =  0.0256652796025
# SE_mean =  0.554411463934
# SE_std =  0.110953736515
# SP_mean =  0.937952014198
# SP_std =  0.0241621843932
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.056234 ...
# AC_mean =  0.86491240564
# AC_std =  0.0256652796025
# SE_mean =  0.554411463934
# SE_std =  0.110953736515
# SP_mean =  0.937952014198
# SP_std =  0.0241621843932
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.100000 ...
# AC_mean =  0.864064948013
# AC_std =  0.0249586891552
# SE_mean =  0.554411463934
# SE_std =  0.110953736515
# SP_mean =  0.936961915188
# SP_std =  0.0250322569574
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.177828 ...
# AC_mean =  0.863217490386
# AC_std =  0.023903256978
# SE_mean =  0.54914830604
# SE_std =  0.110913328537
# SP_mean =  0.936961915188
# SP_std =  0.0250322569574
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.316228 ...
# AC_mean =  0.864064948013
# AC_std =  0.0252447985323
# SE_mean =  0.55414830604
# SE_std =  0.111961079785
# SP_mean =  0.936961915188
# SP_std =  0.0250322569574
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.562341 ...
# AC_mean =  0.86491240564
# AC_std =  0.0285780886629
# SE_mean =  0.55946881886
# SE_std =  0.115626139188
# SP_mean =  0.936961915188
# SP_std =  0.0250322569574
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_1.000000 ...
# AC_mean =  0.86405782652
# AC_std =  0.0335919148272
# SE_mean =  0.552325961717
# SE_std =  0.125293856415
# SP_mean =  0.938037184005
# SP_std =  0.0227644640394
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_1.778279 ...
# AC_mean =  0.864898162655
# AC_std =  0.0337377428573
# SE_mean =  0.553375745267
# SE_std =  0.125349207162
# SP_mean =  0.939047285015
# SP_std =  0.0234638138512
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_3.162278 ...
# AC_mean =  0.865745620282
# AC_std =  0.0348597727901
# SE_mean =  0.545958162849
# SE_std =  0.128692258553
# SP_mean =  0.942221128715
# SP_std =  0.0239496824681
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_5.623413 ...
# AC_mean =  0.865759863267
# AC_std =  0.0371657868534
# SE_mean =  0.539812652013
# SE_std =  0.119426455679
# SP_mean =  0.943109674796
# SP_std =  0.0277293919337
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_10.000000 ...
# AC_mean =  0.861551061102
# AC_std =  0.0376188824149
# SE_mean =  0.529910473719
# SE_std =  0.121618334392
# SP_mean =  0.93997753684
# SP_std =  0.0275975768626
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_17.782794 ...
# AC_mean =  0.857320894459
# AC_std =  0.0369246235656
# SE_mean =  0.490174201219
# SE_std =  0.142720012065
# SP_mean =  0.944182308375
# SP_std =  0.029436607697
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_31.622777 ...
# AC_mean =  0.851410055548
# AC_std =  0.0419209101947
# SE_mean =  0.423287485723
# SE_std =  0.140589444161
# SP_mean =  0.953693160988
# SP_std =  0.0243319465187
#
# ========================================
# Loading features: mouse06, window_length200 ...
#
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.010000 ...
# AC_mean =  0.885137444808
# AC_std =  0.0208069115645
# SE_mean =  0.28256612024
# SE_std =  0.130475191489
# SP_mean =  0.974922421803
# SP_std =  0.0105333445223
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.017783 ...
# AC_mean =  0.885137444808
# AC_std =  0.0208069115645
# SE_mean =  0.28256612024
# SE_std =  0.130475191489
# SP_mean =  0.974922421803
# SP_std =  0.0105333445223
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.031623 ...
# AC_mean =  0.885137444808
# AC_std =  0.0208069115645
# SE_mean =  0.28256612024
# SE_std =  0.130475191489
# SP_mean =  0.974922421803
# SP_std =  0.0105333445223
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.056234 ...
# AC_mean =  0.885977780943
# AC_std =  0.0208471392326
# SE_mean =  0.28256612024
# SE_std =  0.130475191489
# SP_mean =  0.975857001242
# SP_std =  0.00978831829559
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.100000 ...
# AC_mean =  0.885977780943
# AC_std =  0.0208471392326
# SE_mean =  0.28256612024
# SE_std =  0.130475191489
# SP_mean =  0.975857001242
# SP_std =  0.00978831829559
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.177828 ...
# AC_mean =  0.885977780943
# AC_std =  0.0208471392326
# SE_mean =  0.28256612024
# SE_std =  0.130475191489
# SP_mean =  0.975857001242
# SP_std =  0.00978831829559
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.316228 ...
# AC_mean =  0.88682523857
# AC_std =  0.0208142555024
# SE_mean =  0.28256612024
# SE_std =  0.130475191489
# SP_mean =  0.976800397469
# SP_std =  0.00979664148878
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.562341 ...
# AC_mean =  0.883449651047
# AC_std =  0.0210011405975
# SE_mean =  0.244230438464
# SE_std =  0.103690764751
# SP_mean =  0.978724185852
# SP_std =  0.0112249952236
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_1.000000 ...
# AC_mean =  0.884289987181
# AC_std =  0.021113989962
# SE_mean =  0.237980438464
# SE_std =  0.101242124017
# SP_mean =  0.980666665814
# SP_std =  0.0114711791333
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_1.778279 ...
# AC_mean =  0.878393391255
# AC_std =  0.0248136800506
# SE_mean =  0.178940091556
# SE_std =  0.0985971988607
# SP_mean =  0.982571427719
# SP_std =  0.0113599415234
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_3.162278 ...
# AC_mean =  0.875851018373
# AC_std =  0.0185155810018
# SE_mean =  0.0949060292133
# SE_std =  0.0593574285844
# SP_mean =  0.991294221097
# SP_std =  0.00795656039349
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_5.623413 ...
# AC_mean =  0.867419171058
# AC_std =  0.0191585637931
# SE_mean =  0.0253393665158
# SE_std =  0.04098458597
# SP_mean =  0.992304322107
# SP_std =  0.00834691205577
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_10.000000 ...
# AC_mean =  0.869947300954
# AC_std =  0.0196134182608
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  0.999065420561
# SP_std =  0.00280373831776
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_17.782794 ...
# AC_mean =  0.870787637089
# AC_std =  0.0206401252689
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_31.622777 ...
# AC_mean =  0.870787637089
# AC_std =  0.0206401252689
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.010000 ...
# AC_mean =  0.873315766985
# AC_std =  0.0239202542779
# SE_mean =  0.159743887434
# SE_std =  0.0891501529963
# SP_mean =  0.979981393101
# SP_std =  0.0267232071783
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.017783 ...
# AC_mean =  0.873315766985
# AC_std =  0.0239202542779
# SE_mean =  0.159743887434
# SE_std =  0.0891501529963
# SP_mean =  0.979981393101
# SP_std =  0.0267232071783
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.031623 ...
# AC_mean =  0.873315766985
# AC_std =  0.0239202542779
# SE_mean =  0.159743887434
# SE_std =  0.0891501529963
# SP_mean =  0.979981393101
# SP_std =  0.0267232071783
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.056234 ...
# AC_mean =  0.875003560746
# AC_std =  0.024464391102
# SE_mean =  0.159743887434
# SE_std =  0.0891501529963
# SP_mean =  0.98191416621
# SP_std =  0.027403548457
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.100000 ...
# AC_mean =  0.875851018373
# AC_std =  0.0236279933292
# SE_mean =  0.159743887434
# SE_std =  0.0891501529963
# SP_mean =  0.98292426722
# SP_std =  0.0278615893559
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.177828 ...
# AC_mean =  0.874163224612
# AC_std =  0.0240496719126
# SE_mean =  0.148230729539
# SE_std =  0.0890399362156
# SP_mean =  0.98292426722
# SP_std =  0.0278615893559
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.316228 ...
# AC_mean =  0.87247543085
# AC_std =  0.025211996102
# SE_mean =  0.127765043264
# SE_std =  0.0843394547919
# SP_mean =  0.98385884666
# SP_std =  0.0273161356942
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.562341 ...
# AC_mean =  0.875017803732
# AC_std =  0.0222438771747
# SE_mean =  0.127765043264
# SE_std =  0.0843394547919
# SP_mean =  0.986735738122
# SP_std =  0.0223733273869
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_1.000000 ...
# AC_mean =  0.871635094716
# AC_std =  0.0187618897071
# SE_mean =  0.100574872324
# SE_std =  0.0521997929057
# SP_mean =  0.986735738122
# SP_std =  0.0223733273869
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_1.778279 ...
# AC_mean =  0.868259507193
# AC_std =  0.0233097333819
# SE_mean =  0.0692904725993
# SE_std =  0.0568752177896
# SP_mean =  0.987688119075
# SP_std =  0.0227124132319
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_3.162278 ...
# AC_mean =  0.867419171058
# AC_std =  0.0212610144889
# SE_mean =  0.0216346153846
# SE_std =  0.0478480127329
# SP_mean =  0.993330862859
# SP_std =  0.0112198639502
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_5.623413 ...
# AC_mean =  0.868259507193
# AC_std =  0.019587249686
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  0.997131925324
# SP_std =  0.00438308793344
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_10.000000 ...
# AC_mean =  0.870787637089
# AC_std =  0.0206401252689
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_17.782794 ...
# AC_mean =  0.870787637089
# AC_std =  0.0206401252689
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_31.622777 ...
# AC_mean =  0.870787637089
# AC_std =  0.0206401252689
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.010000 ...
# AC_mean =  0.904550633813
# AC_std =  0.0190081710974
# SE_mean =  0.489745739726
# SE_std =  0.101309316419
# SP_mean =  0.967094925992
# SP_std =  0.00863156985992
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.017783 ...
# AC_mean =  0.90539809144
# AC_std =  0.017312821768
# SE_mean =  0.489745739726
# SE_std =  0.101309316419
# SP_mean =  0.968105027002
# SP_std =  0.00943098025935
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.031623 ...
# AC_mean =  0.904557755306
# AC_std =  0.0169802073135
# SE_mean =  0.484190184171
# SE_std =  0.0990461266038
# SP_mean =  0.968105027002
# SP_std =  0.00943098025935
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.056234 ...
# AC_mean =  0.904557755306
# AC_std =  0.0169802073135
# SE_mean =  0.484190184171
# SE_std =  0.0990461266038
# SP_mean =  0.968105027002
# SP_std =  0.00943098025935
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.100000 ...
# AC_mean =  0.904564876798
# AC_std =  0.0160684437482
# SE_mean =  0.478634628615
# SE_std =  0.0995602749729
# SP_mean =  0.969085419159
# SP_std =  0.00912357210341
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.177828 ...
# AC_mean =  0.905405212933
# AC_std =  0.0159833030496
# SE_mean =  0.484190184171
# SE_std =  0.0990461266038
# SP_mean =  0.969085419159
# SP_std =  0.00912357210341
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.316228 ...
# AC_mean =  0.905412334425
# AC_std =  0.0159389060892
# SE_mean =  0.478634628615
# SE_std =  0.0995602749729
# SP_mean =  0.970075518169
# SP_std =  0.00971912862202
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.562341 ...
# AC_mean =  0.903717419171
# AC_std =  0.0189992028394
# SE_mean =  0.453254412426
# SE_std =  0.108418955621
# SP_mean =  0.97196247856
# SP_std =  0.00889947701232
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_1.000000 ...
# AC_mean =  0.902029625409
# AC_std =  0.0224362747905
# SE_mean =  0.414667182663
# SE_std =  0.105688964606
# SP_mean =  0.975736231405
# SP_std =  0.00991005136341
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_1.778279 ...
# AC_mean =  0.896111665005
# AC_std =  0.0275764169281
# SE_mean =  0.340076340928
# SE_std =  0.122094077297
# SP_mean =  0.980582358263
# SP_std =  0.00754260390181
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_3.162278 ...
# AC_mean =  0.888520153824
# AC_std =  0.0238306086709
# SE_mean =  0.257003817046
# SE_std =  0.0974610133675
# SP_mean =  0.983537139722
# SP_std =  0.00979257840705
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_5.623413 ...
# AC_mean =  0.879219484404
# AC_std =  0.0210905382895
# SE_mean =  0.189535868328
# SE_std =  0.0940613959594
# SP_mean =  0.981592681861
# SP_std =  0.0153738309958
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_10.000000 ...
# AC_mean =  0.870759151118
# AC_std =  0.0240198520343
# SE_mean =  0.110950689318
# SE_std =  0.0813810150385
# SP_mean =  0.983507485518
# SP_std =  0.0152355249314
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_17.782794 ...
# AC_mean =  0.860653753027
# AC_std =  0.0239060998935
# SE_mean =  0.0330316742081
# SE_std =  0.042690095548
# SP_mean =  0.983507485518
# SP_std =  0.0152355249314
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_31.622777 ...
# AC_mean =  0.869099843327
# AC_std =  0.0185225752911
# SE_mean =  0.00769230769231
# SE_std =  0.0230769230769
# SP_mean =  0.997169643382
# SP_std =  0.00432362439189

# %%
# load and organize feature matrix
def lz_load_feature_matrix(mouse_id, window_length, window_step):
    fileName = "format4ML_spike_mouse_0" + str(mouse_id) + "_windowLen" + str(window_length) + "_winStep_0" + str(window_step) + ".csv"
    loadPath = "/Users/lizhu/Dropbox/projects/calcium/comparison/ROI4FluoroSNNAP/" + fileName
    comb = gl.SFrame.read_csv(loadPath, delimiter=',',header=False,verbose = False)
    colName_dg = 'spikes'
    colName_dg = gl.SArray([colName_dg + repr(i+1) for i in range(30)])

    colName = colName_dg.append(gl.SArray(['Whisker']))
    colName = (list(colName))
    dictionary = dict(zip(comb.column_names(), colName))
    comb = comb.rename(dictionary)
    comb = gl.toolkits.cross_validation.shuffle(comb, random_seed=1)
    # comb['Whisker'].show(view = 'Categorical')
    
    return comb

# %%
# train and cross-validation
def lz_logistic_AC_SE_SP(data, feature_type, l2_penalty, l1_penalty):
    
    # clearify features

    if feature_type == 1:   feature_spk = list(comb.column_names()[i] for i in [4, 5, 6, 7, 8, 11, 12, 13, 14, 15])
    elif feature_type == 2: feature_spk = list(comb.column_names()[i] for i in [1, 2, 16, 17, 18, 23, 24, 25, 26, 28])
    elif feature_type == 3: feature_spk = list(comb.column_names()[0:30])
        
    feature = feature_spk

    # Kfold
    num_fold = 10
    folds = gl.cross_validation.KFold(comb, num_fold)
    SE = [None] * num_fold
    SP = [None] * num_fold
    AC = [None] * num_fold
    AUC = [None] * num_fold
    
    # print specificity
    idx = 0
    for train, valid in folds:
        m = gl.logistic_classifier.create(train,
                                          target='Whisker',
                                          features=feature,
                                          l2_penalty = l2_penalty, 
                                          l1_penalty = l1_penalty,
                                          validation_set=None,
                                          verbose = False)
        results = m.evaluate(valid)
        confusion_matrix = results['confusion_matrix']

        AUC[idx] = results['auc']
                    
        TP, TN, FP, FN = lz_extract_ACC_SE_SP(confusion_matrix)
        SP[idx] = float(TN) / (TN + FP)
        SE[idx] = float(TP) / (TP + FN)
        AC[idx] = float(TP+TN) / (TP+TN+FP+FN)
        
        idx = idx + 1
        
    AC_mn = np.mean(AC)
    AC_sd = np.std(AC)
    SE_mn = np.mean(SE)
    SE_sd = np.std(SE)
    SP_mn = np.mean(SP)
    SP_sd = np.std(SP)
    AUC_mn = np.mean(AUC)
    AUC_sd = np.std(AUC)
    
    print 'AC_mean = ', AC_mn
    print 'AC_std = ',  AC_sd
    print 'SE_mean = ', SE_mn
    print 'SE_std = ',  SE_sd
    print 'SP_mean = ', SP_mn
    print 'SP_std = ',  SP_sd
    
    return AC_mn, SE_mn, SP_mn, AUC_mn

# %%
def lz_extract_ACC_SE_SP(confusion_matrix):
    TP = confusion_matrix[(confusion_matrix['target_label']==1) & (confusion_matrix['predicted_label']==1)]
    if np.size(TP) == 0:
        TP = 0
    else:
        TP = TP['count'][0]
    TN = confusion_matrix[(confusion_matrix['target_label']==0) & (confusion_matrix['predicted_label']==0)]
    if np.size(TN) == 0:
        TN = 0
    else:
        TN = TN['count'][0]
    FP = confusion_matrix[(confusion_matrix['target_label']==0) & (confusion_matrix['predicted_label']==1)]
    if np.size(FP) == 0:
        FP = 0
    else:
        FP = FP['count'][0]
    FN = confusion_matrix[(confusion_matrix['target_label']==1) & (confusion_matrix['predicted_label']==0)]
    if np.size(FN) == 0:
        FN = 0
    else:
        FN = FN['count'][0]
    
    return TP, TN, FP, FN
