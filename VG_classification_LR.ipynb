# %%
import graphlab as gl
import numpy as np
import pandas as pd
import os
from pylab import *
# Out:
# [INFO] graphlab.cython.cy_server: GraphLab Create v2.1 started. Logging: /tmp/graphlab_server_1488957357.log
# This non-commercial license of GraphLab Create for academic use is assigned to victor.li.zhu@rutgers.edu and will expire on October 06, 2017.

# %%
import threading
threading.activeCount()

from ipyparallel import Client
rc = Client()

rc.ids
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %%
# input parameters
#=================================
classifier_list = ['LR']
#=================================

window_length_list = [100, 150, 200, 250, 300]
window_step = 50
feature_type_list = [1, 2, 3, 12, 13, 23, 123]  # 1: dg, 2: cc, 3: pl, 12: dg+cc, 13: dg+pl, 23: cc+pl, 123: dg+cc+pl
l2_penalty_list = np.logspace(-2, 1.5, num=15, endpoint=True, base=10.0, dtype=None).tolist()
l1_penalty = 0.0

for mouse_id in range(1,7):

    for win_ln_idx in range(len(window_length_list)): # NOTE HERE!!!!! REMOVE "1" AFTER THIS SESSION!!!!!!!!!!!!!
        window_length = window_length_list[win_ln_idx]
        
        ##========================= load features
        # print on screen: progress
        current_progress = ("\n========================================\nLoading features: mouse%02d, window_length%03d ...\n" \
                            % (mouse_id, window_length))
        print current_progress

        # load and organize feature matrix
        comb = lz_load_feature_matrix(mouse_id, window_length, window_step)       
        
        for classifier_idx in range(len(classifier_list)):
            classifier = classifier_list[classifier_idx]

            # initiate
            AC = [[0] * len(l2_penalty_list) for _ in range(len(feature_type_list))] 
            SE = [[0] * len(l2_penalty_list) for _ in range(len(feature_type_list))] 
            SP = [[0] * len(l2_penalty_list) for _ in range(len(feature_type_list))] 

            for feature_type_idx in range(len(feature_type_list)):
                feature_type = feature_type_list[feature_type_idx]

                ##========================= classification
                for l2_penalty_idx in range(len(l2_penalty_list)):
                    l2_penalty = l2_penalty_list[l2_penalty_idx]

                    # print on screen: progress
                    current_progress = ("\n----------------------------------------\nClassifying --> classifier: %s, feature_type%03d, l2_penalty_%f ..." \
                                        % (classifier, feature_type, l2_penalty))
                    print current_progress

                    if classifier == 'LR':
                        AC[feature_type_idx][l2_penalty_idx],SE[feature_type_idx][l2_penalty_idx],SP[feature_type_idx][l2_penalty_idx] = \
                            lz_logistic_AC_SE_SP(comb, feature_type, l2_penalty, l1_penalty)
                    if classifier == 'SVM':
                        AC[feature_type_idx][l2_penalty_idx],SE[feature_type_idx][l2_penalty_idx],SP[feature_type_idx][l2_penalty_idx] = \
                            lz_svm_AC_SE_SP(comb, feature_type, l2_penalty)
                    # if classifier == 'RF'
                        # ...
                    # if classifier == 'KNN'
                        # ...

            ##====================== save results
            AC_saveName = ("%s_mouse%02d_window_length%03d_AC.csv" \
                           % (classifier,mouse_id,window_length))
            SE_saveName = ("%s_mouse%02d_window_length%03d_SE.csv" \
                           % (classifier,mouse_id,window_length))
            SP_saveName = ("%s_mouse%02d_window_length%03d_SP.csv" \
                           % (classifier,mouse_id,window_length))
            df_AC = pd.DataFrame(AC)
            df_SE = pd.DataFrame(SE)        
            df_SP = pd.DataFrame(SP)  
            
            os.chdir("/Users/lizhu/Dropbox/projects/calcium/classification_result") 
            df_AC.to_csv(AC_saveName, index = False, header = False)
            df_SE.to_csv(SE_saveName, index = False, header = False)
            df_SP.to_csv(SP_saveName, index = False, header = False)
# Out:
# ========================================
# Loading features: mouse01, window_length100 ...
#
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.010000 ...
# AC_mean =  0.869451612903
# AC_std =  0.044709996275
# SE_mean =  0.619175360458
# SE_std =  0.103728954224
# SP_mean =  0.931137705554
# SP_std =  0.0243459301256
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.017783 ...
# AC_mean =  0.870251612903
# AC_std =  0.0445333716023
# SE_mean =  0.615329206612
# SE_std =  0.103083139399
# SP_mean =  0.933109345026
# SP_std =  0.0241518603499
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.031623 ...
# AC_mean =  0.870251612903
# AC_std =  0.042923433999
# SE_mean =  0.615329206612
# SE_std =  0.103083139399
# SP_mean =  0.933241217617
# SP_std =  0.0230772154986
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.056234 ...
# AC_mean =  0.86864516129
# AC_std =  0.0426867105191
# SE_mean =  0.620592364507
# SE_std =  0.105102288321
# SP_mean =  0.930106302119
# SP_std =  0.0236779337556
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.100000 ...
# AC_mean =  0.869451612903
# AC_std =  0.0423578064459
# SE_mean =  0.626495142285
# SE_std =  0.100919653985
# SP_mean =  0.930219796615
# SP_std =  0.0231371797818
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.177828 ...
# AC_mean =  0.867058064516
# AC_std =  0.045566689186
# SE_mean =  0.599593918508
# SE_std =  0.111644789492
# SP_mean =  0.934296135209
# SP_std =  0.0216062172889
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.316228 ...
# AC_mean =  0.863858064516
# AC_std =  0.0449628154843
# SE_mean =  0.582151273434
# SE_std =  0.110670888997
# SP_mean =  0.934383666818
# SP_std =  0.0210122257553
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.562341 ...
# AC_mean =  0.857451612903
# AC_std =  0.0465985244035
# SE_mean =  0.566053135461
# SE_std =  0.117274076881
# SP_mean =  0.931535335903
# SP_std =  0.0184202891684
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_1.000000 ...
# AC_mean =  0.855838709677
# AC_std =  0.0463590587793
# SE_mean =  0.540024284926
# SE_std =  0.117448272019
# SP_mean =  0.935495220105
# SP_std =  0.0204857501973
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_1.778279 ...
# AC_mean =  0.853419354839
# AC_std =  0.0387162682561
# SE_mean =  0.505148725543
# SE_std =  0.0856042751032
# SP_mean =  0.940789319405
# SP_std =  0.0204777453802
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_3.162278 ...
# AC_mean =  0.853406451613
# AC_std =  0.0372287224217
# SE_mean =  0.462867706124
# SE_std =  0.0756339486713
# SP_mean =  0.950748474064
# SP_std =  0.0180220808324
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_5.623413 ...
# AC_mean =  0.8414
# AC_std =  0.0433440467559
# SE_mean =  0.37860609785
# SE_std =  0.0952155262796
# SP_mean =  0.956731956336
# SP_std =  0.0194249755087
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_10.000000 ...
# AC_mean =  0.834993548387
# AC_std =  0.0471967758471
# SE_mean =  0.292887959993
# SE_std =  0.118781969512
# SP_mean =  0.971017952737
# SP_std =  0.0112127666188
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_17.782794 ...
# AC_mean =  0.826193548387
# AC_std =  0.0510488207697
# SE_mean =  0.162324298509
# SE_std =  0.0829084780346
# SP_mean =  0.991922265872
# SP_std =  0.0100413478375
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_31.622777 ...
# AC_mean =  0.808548387097
# AC_std =  0.0456942674414
# SE_mean =  0.0422085224717
# SE_std =  0.0363777058662
# SP_mean =  0.998046502763
# SP_std =  0.00390984059178
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.010000 ...
# AC_mean =  0.842212903226
# AC_std =  0.0393302096386
# SE_mean =  0.396999783842
# SE_std =  0.0998509667266
# SP_mean =  0.955362341105
# SP_std =  0.0186604534556
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.017783 ...
# AC_mean =  0.834187096774
# AC_std =  0.0412574914838
# SE_mean =  0.347685885021
# SE_std =  0.0793869649797
# SP_mean =  0.957114576377
# SP_std =  0.0191740753347
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.031623 ...
# AC_mean =  0.828593548387
# AC_std =  0.045940420177
# SE_mean =  0.306353953064
# SE_std =  0.101187942865
# SP_mean =  0.961075172039
# SP_std =  0.0183779279259
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.056234 ...
# AC_mean =  0.822974193548
# AC_std =  0.0443067018559
# SE_mean =  0.247957817037
# SE_std =  0.0879730812194
# SP_mean =  0.967106981
# SP_std =  0.0175697038145
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.100000 ...
# AC_mean =  0.812567741935
# AC_std =  0.0487559003073
# SE_mean =  0.17021571265
# SE_std =  0.0730876284308
# SP_mean =  0.972813178343
# SP_std =  0.0138883036956
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.177828 ...
# AC_mean =  0.808567741935
# AC_std =  0.0507101190164
# SE_mean =  0.112476175141
# SE_std =  0.0558542068495
# SP_mean =  0.981836521566
# SP_std =  0.0145761246833
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.316228 ...
# AC_mean =  0.80855483871
# AC_std =  0.048004259263
# SE_mean =  0.0574648122345
# SE_std =  0.0376814459275
# SP_mean =  0.993762268613
# SP_std =  0.00701922661929
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.562341 ...
# AC_mean =  0.802941935484
# AC_std =  0.0439347468083
# SE_mean =  0.00277777777778
# SE_std =  0.00833333333333
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_1.000000 ...
# AC_mean =  0.802141935484
# AC_std =  0.0454832834554
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_1.778279 ...
# AC_mean =  0.802141935484
# AC_std =  0.0454832834554
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_3.162278 ...
# AC_mean =  0.802141935484
# AC_std =  0.0454832834554
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_5.623413 ...
# AC_mean =  0.802141935484
# AC_std =  0.0454832834554
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_10.000000 ...
# AC_mean =  0.802141935484
# AC_std =  0.0454832834554
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_17.782794 ...
# AC_mean =  0.802141935484
# AC_std =  0.0454832834554
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_31.622777 ...
# AC_mean =  0.802141935484
# AC_std =  0.0454832834554
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.010000 ...
# AC_mean =  0.809322580645
# AC_std =  0.0253059407009
# SE_mean =  0.236823008862
# SE_std =  0.0892311452187
# SP_mean =  0.949284307012
# SP_std =  0.0109165374609
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.017783 ...
# AC_mean =  0.809322580645
# AC_std =  0.0253059407009
# SE_mean =  0.236823008862
# SE_std =  0.0892311452187
# SP_mean =  0.949284307012
# SP_std =  0.0109165374609
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.031623 ...
# AC_mean =  0.808516129032
# AC_std =  0.0231312051888
# SE_mean =  0.226004295412
# SE_std =  0.0881011238241
# SP_mean =  0.950315234847
# SP_std =  0.0102843120803
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.056234 ...
# AC_mean =  0.810116129032
# AC_std =  0.0241255267421
# SE_mean =  0.226004295412
# SE_std =  0.0881011238241
# SP_mean =  0.952286874319
# SP_std =  0.011165936325
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.100000 ...
# AC_mean =  0.813316129032
# AC_std =  0.0241631499349
# SE_mean =  0.224587291364
# SE_std =  0.0884889837924
# SP_mean =  0.956277178834
# SP_std =  0.01176359388
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.177828 ...
# AC_mean =  0.813309677419
# AC_std =  0.0242097674667
# SE_mean =  0.219694614596
# SE_std =  0.094047841485
# SP_mean =  0.957287279844
# SP_std =  0.0115699353506
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.316228 ...
# AC_mean =  0.812522580645
# AC_std =  0.0273879660943
# SE_mean =  0.204484477511
# SE_std =  0.0932877749872
# SP_mean =  0.960154464454
# SP_std =  0.00839457135618
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.562341 ...
# AC_mean =  0.817335483871
# AC_std =  0.0305816530391
# SE_mean =  0.206252154278
# SE_std =  0.0883315910747
# SP_mean =  0.966068321492
# SP_std =  0.00988817748589
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_1.000000 ...
# AC_mean =  0.818941935484
# AC_std =  0.029585315704
# SE_mean =  0.180201450596
# SE_std =  0.0790405282327
# SP_mean =  0.974048491627
# SP_std =  0.00867000653779
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_1.778279 ...
# AC_mean =  0.82295483871
# AC_std =  0.0256795719636
# SE_mean =  0.169559661829
# SE_std =  0.066317753543
# SP_mean =  0.982411037501
# SP_std =  0.0109820079143
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_3.162278 ...
# AC_mean =  0.819761290323
# AC_std =  0.0301629297467
# SE_mean =  0.128420921184
# SE_std =  0.0567792078495
# SP_mean =  0.988175115574
# SP_std =  0.00960906819617
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_5.623413 ...
# AC_mean =  0.814961290323
# AC_std =  0.0401754989764
# SE_mean =  0.0954805976188
# SE_std =  0.0488219566617
# SP_mean =  0.992100252282
# SP_std =  0.00717600825272
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_10.000000 ...
# AC_mean =  0.81015483871
# AC_std =  0.041821663899
# SE_mean =  0.0560498529249
# SE_std =  0.0465325801982
# SP_mean =  0.996138883486
# SP_std =  0.00634190218109
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_17.782794 ...
# AC_mean =  0.806948387097
# AC_std =  0.0448370484724
# SE_mean =  0.0232267732268
# SE_std =  0.0302816384591
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_31.622777 ...
# AC_mean =  0.802941935484
# AC_std =  0.0450850527016
# SE_mean =  0.00357142857143
# SE_std =  0.0107142857143
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type012, l2_penalty_0.010000 ...
# AC_mean =  0.875838709677
# AC_std =  0.0325271262765
# SE_mean =  0.617600875002
# SE_std =  0.0872773051243
# SP_mean =  0.938420618726
# SP_std =  0.0191314207666
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type012, l2_penalty_0.017783 ...
# AC_mean =  0.87584516129
# AC_std =  0.0349774917963
# SE_mean =  0.618394525796
# SE_std =  0.095174964895
# SP_mean =  0.938457614657
# SP_std =  0.0194708445966
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type012, l2_penalty_0.031623 ...
# AC_mean =  0.87584516129
# AC_std =  0.0377946056527
# SE_mean =  0.624667784701
# SE_std =  0.084580846255
# SP_mean =  0.937241115621
# SP_std =  0.0210395459285
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type012, l2_penalty_0.056234 ...
# AC_mean =  0.873438709677
# AC_std =  0.0372059101523
# SE_mean =  0.611000202283
# SE_std =  0.0890348131552
# SP_mean =  0.938496347857
# SP_std =  0.0183432072116
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type012, l2_penalty_0.100000 ...
# AC_mean =  0.86944516129
# AC_std =  0.0435578121223
# SE_mean =  0.600182894591
# SE_std =  0.0965461925154
# SP_mean =  0.936240274817
# SP_std =  0.0216888881542
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type012, l2_penalty_0.177828 ...
# AC_mean =  0.866251612903
# AC_std =  0.0497155316726
# SE_mean =  0.596563268603
# SE_std =  0.119509845934
# SP_mean =  0.934221609774
# SP_std =  0.0235959257871
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type012, l2_penalty_0.316228 ...
# AC_mean =  0.864651612903
# AC_std =  0.0443201901032
# SE_mean =  0.585023401306
# SE_std =  0.107856269457
# SP_mean =  0.934296135209
# SP_std =  0.0206401662665
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type012, l2_penalty_0.562341 ...
# AC_mean =  0.85904516129
# AC_std =  0.0442716879249
# SE_mean =  0.557539426947
# SE_std =  0.119622864255
# SP_mean =  0.934515539409
# SP_std =  0.0189775479435
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type012, l2_penalty_1.000000 ...
# AC_mean =  0.855838709677
# AC_std =  0.0439495430113
# SE_mean =  0.538162258064
# SE_std =  0.10874257588
# SP_mean =  0.935495220105
# SP_std =  0.0204857501973
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type012, l2_penalty_1.778279 ...
# AC_mean =  0.857425806452
# AC_std =  0.0391717842134
# SE_mean =  0.51880349183
# SE_std =  0.0926335195452
# SP_mean =  0.942760958877
# SP_std =  0.0206722148704
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type012, l2_penalty_3.162278 ...
# AC_mean =  0.848606451613
# AC_std =  0.0372725060686
# SE_mean =  0.44693986569
# SE_std =  0.083367667811
# SP_mean =  0.948861681611
# SP_std =  0.0186809995054
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type012, l2_penalty_5.623413 ...
# AC_mean =  0.843806451613
# AC_std =  0.0415983370355
# SE_mean =  0.388707107951
# SE_std =  0.0977853030435
# SP_mean =  0.956731956336
# SP_std =  0.0194249755087
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type012, l2_penalty_10.000000 ...
# AC_mean =  0.834993548387
# AC_std =  0.0476018450311
# SE_mean =  0.292887959993
# SE_std =  0.118781969512
# SP_mean =  0.97095278493
# SP_std =  0.0114654883882
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type012, l2_penalty_17.782794 ...
# AC_mean =  0.826187096774
# AC_std =  0.0510603523663
# SE_mean =  0.167587456403
# SE_std =  0.0841219129854
# SP_mean =  0.990978869646
# SP_std =  0.00967458663542
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type012, l2_penalty_31.622777 ...
# AC_mean =  0.809348387097
# AC_std =  0.0467166850028
# SE_mean =  0.0474716803664
# SE_std =  0.0472903580845
# SP_mean =  0.998046502763
# SP_std =  0.00390984059178
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type013, l2_penalty_0.010000 ...
# AC_mean =  0.867825806452
# AC_std =  0.0386343358202
# SE_mean =  0.609972428887
# SE_std =  0.0967543851204
# SP_mean =  0.931498776126
# SP_std =  0.0231048302414
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type013, l2_penalty_0.017783 ...
# AC_mean =  0.869432258065
# AC_std =  0.0397404461388
# SE_mean =  0.613818582733
# SE_std =  0.0961265902358
# SP_mean =  0.932414000476
# SP_std =  0.0227095187931
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type013, l2_penalty_0.031623 ...
# AC_mean =  0.868632258065
# AC_std =  0.0379493698527
# SE_mean =  0.613818582733
# SE_std =  0.0961265902358
# SP_mean =  0.931553914292
# SP_std =  0.0233284203617
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type013, l2_penalty_0.056234 ...
# AC_mean =  0.871038709677
# AC_std =  0.038489291455
# SE_mean =  0.624637296183
# SE_std =  0.0898733038345
# SP_mean =  0.932497310518
# SP_std =  0.0228291340894
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type013, l2_penalty_0.100000 ...
# AC_mean =  0.875038709677
# AC_std =  0.0440490167801
# SE_mean =  0.642079941258
# SE_std =  0.0937291176096
# SP_mean =  0.93318306158
# SP_std =  0.0293346263447
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type013, l2_penalty_0.177828 ...
# AC_mean =  0.872638709677
# AC_std =  0.043496623477
# SE_mean =  0.624985924164
# SE_std =  0.102600882462
# SP_mean =  0.934209331695
# SP_std =  0.0263954565787
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type013, l2_penalty_0.316228 ...
# AC_mean =  0.867025806452
# AC_std =  0.039442276742
# SE_mean =  0.602843793633
# SE_std =  0.0853774146772
# SP_mean =  0.932245037275
# SP_std =  0.0234216902303
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type013, l2_penalty_0.562341 ...
# AC_mean =  0.867832258065
# AC_std =  0.0414985094325
# SE_mean =  0.599366715156
# SE_std =  0.0874414273582
# SP_mean =  0.934166616669
# SP_std =  0.025700056297
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type013, l2_penalty_1.000000 ...
# AC_mean =  0.863819354839
# AC_std =  0.0389212904081
# SE_mean =  0.568892657051
# SE_std =  0.0893827451511
# SP_mean =  0.936434870365
# SP_std =  0.0223917075433
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type013, l2_penalty_1.778279 ...
# AC_mean =  0.859825806452
# AC_std =  0.0407018350403
# SE_mean =  0.538251751903
# SE_std =  0.0678165713474
# SP_mean =  0.939500396489
# SP_std =  0.0250864757842
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type013, l2_penalty_3.162278 ...
# AC_mean =  0.857438709677
# AC_std =  0.0384958832617
# SE_mean =  0.504881266394
# SE_std =  0.0579052387153
# SP_mean =  0.94451965571
# SP_std =  0.0232930603059
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type013, l2_penalty_5.623413 ...
# AC_mean =  0.85504516129
# AC_std =  0.0416217824985
# SE_mean =  0.454564167558
# SE_std =  0.0715543175537
# SP_mean =  0.953400031445
# SP_std =  0.021691738521
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type013, l2_penalty_10.000000 ...
# AC_mean =  0.848619354839
# AC_std =  0.0420848575396
# SE_mean =  0.362729905329
# SE_std =  0.0793908501874
# SP_mean =  0.968739515896
# SP_std =  0.0195222568627
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type013, l2_penalty_17.782794 ...
# AC_mean =  0.835806451613
# AC_std =  0.0494443800868
# SE_mean =  0.256744151317
# SE_std =  0.0908417821895
# SP_mean =  0.979706562574
# SP_std =  0.0138553789934
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type013, l2_penalty_31.622777 ...
# AC_mean =  0.818980645161
# AC_std =  0.0457722434739
# SE_mean =  0.105347485117
# SE_std =  0.0705050181177
# SP_mean =  0.996226415094
# SP_std =  0.00625778262331
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type023, l2_penalty_0.010000 ...
# AC_mean =  0.858232258065
# AC_std =  0.0308221334854
# SE_mean =  0.503074337943
# SE_std =  0.0955389607607
# SP_mean =  0.944766320033
# SP_std =  0.0191645170498
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type023, l2_penalty_0.017783 ...
# AC_mean =  0.855006451613
# AC_std =  0.0276798735659
# SE_mean =  0.474606259968
# SE_std =  0.0856122167496
# SP_mean =  0.946965184356
# SP_std =  0.0184935323225
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type023, l2_penalty_0.031623 ...
# AC_mean =  0.851006451613
# AC_std =  0.0340540453116
# SE_mean =  0.452330618942
# SE_std =  0.0966675654348
# SP_mean =  0.947852908842
# SP_std =  0.0207290363116
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type023, l2_penalty_0.056234 ...
# AC_mean =  0.847806451613
# AC_std =  0.0358110081379
# SE_mean =  0.416340530814
# SE_std =  0.0926968709645
# SP_mean =  0.952646090825
# SP_std =  0.022370049761
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type023, l2_penalty_0.100000 ...
# AC_mean =  0.8454
# AC_std =  0.0354736413407
# SE_mean =  0.396945689544
# SE_std =  0.106727669271
# SP_mean =  0.954787843852
# SP_std =  0.0192379003673
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type023, l2_penalty_0.177828 ...
# AC_mean =  0.837380645161
# AC_std =  0.0347435762035
# SE_mean =  0.358953802046
# SE_std =  0.102631822196
# SP_mean =  0.953712575035
# SP_std =  0.0176556049698
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type023, l2_penalty_0.316228 ...
# AC_mean =  0.831767741935
# AC_std =  0.0374023120254
# SE_mean =  0.310495279574
# SE_std =  0.106560227701
# SP_mean =  0.958647812754
# SP_std =  0.0167488412803
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type023, l2_penalty_0.562341 ...
# AC_mean =  0.82695483871
# AC_std =  0.0312762163082
# SE_mean =  0.24898378303
# SE_std =  0.101909961657
# SP_mean =  0.966815527219
# SP_std =  0.0126859120762
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type023, l2_penalty_1.000000 ...
# AC_mean =  0.824561290323
# AC_std =  0.0308715717742
# SE_mean =  0.204714455866
# SE_std =  0.100451263322
# SP_mean =  0.974949311266
# SP_std =  0.0160920717422
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type023, l2_penalty_1.778279 ...
# AC_mean =  0.825361290323
# AC_std =  0.0305338480918
# SE_mean =  0.172022148173
# SE_std =  0.0877884738174
# SP_mean =  0.984087921822
# SP_std =  0.0101071183414
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type023, l2_penalty_3.162278 ...
# AC_mean =  0.822167741935
# AC_std =  0.0321192782188
# SE_mean =  0.145746322391
# SE_std =  0.0729888912385
# SP_mean =  0.987165014564
# SP_std =  0.00881069081559
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type023, l2_penalty_5.623413 ...
# AC_mean =  0.815761290323
# AC_std =  0.0383130872351
# SE_mean =  0.0934964706346
# SE_std =  0.0567998682007
# SP_mean =  0.993110353292
# SP_std =  0.00749872230352
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type023, l2_penalty_10.000000 ...
# AC_mean =  0.80935483871
# AC_std =  0.043578197682
# SE_mean =  0.0532720751471
# SE_std =  0.0489059561659
# SP_mean =  0.996138883486
# SP_std =  0.00634190218109
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type023, l2_penalty_17.782794 ...
# AC_mean =  0.806948387097
# AC_std =  0.0448370484724
# SE_mean =  0.0232267732268
# SE_std =  0.0302816384591
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type023, l2_penalty_31.622777 ...
# AC_mean =  0.802941935484
# AC_std =  0.0450850527016
# SE_mean =  0.00357142857143
# SE_std =  0.0107142857143
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type123, l2_penalty_0.010000 ...
# AC_mean =  0.876619354839
# AC_std =  0.0255234025765
# SE_mean =  0.632442666982
# SE_std =  0.0803009648284
# SP_mean =  0.93594459172
# SP_std =  0.0185654277392
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type123, l2_penalty_0.017783 ...
# AC_mean =  0.879019354839
# AC_std =  0.0282189860884
# SE_mean =  0.637082471622
# SE_std =  0.0854265988807
# SP_mean =  0.937849526408
# SP_std =  0.0205372668719
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type123, l2_penalty_0.031623 ...
# AC_mean =  0.875012903226
# AC_std =  0.0281613021468
# SE_mean =  0.627486165151
# SE_std =  0.102148161815
# SP_mean =  0.934885928162
# SP_std =  0.0226369955097
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type123, l2_penalty_0.056234 ...
# AC_mean =  0.874212903226
# AC_std =  0.033526916827
# SE_mean =  0.615401028066
# SE_std =  0.115627822032
# SP_mean =  0.936667814312
# SP_std =  0.0216953648475
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type123, l2_penalty_0.100000 ...
# AC_mean =  0.873412903226
# AC_std =  0.0365807982019
# SE_mean =  0.621016264437
# SE_std =  0.120069795825
# SP_mean =  0.934362564686
# SP_std =  0.0234906490845
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type123, l2_penalty_0.177828 ...
# AC_mean =  0.871825806452
# AC_std =  0.0414874131834
# SE_mean =  0.618726887148
# SE_std =  0.103554629309
# SP_mean =  0.934297396879
# SP_std =  0.0233655343932
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type123, l2_penalty_0.316228 ...
# AC_mean =  0.869425806452
# AC_std =  0.0392711585235
# SE_mean =  0.608182898972
# SE_std =  0.110041415019
# SP_mean =  0.933303464974
# SP_std =  0.0224546093017
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type123, l2_penalty_0.562341 ...
# AC_mean =  0.867019354839
# AC_std =  0.0418208437991
# SE_mean =  0.597731216152
# SE_std =  0.107025137146
# SP_mean =  0.933273756121
# SP_std =  0.0242564392444
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type123, l2_penalty_1.000000 ...
# AC_mean =  0.861419354839
# AC_std =  0.0382549310581
# SE_mean =  0.565104778263
# SE_std =  0.0875975060211
# SP_mean =  0.934492703887
# SP_std =  0.0242642648433
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type123, l2_penalty_1.778279 ...
# AC_mean =  0.859025806452
# AC_std =  0.0402159255267
# SE_mean =  0.538057154833
# SE_std =  0.0750787773101
# SP_mean =  0.938469468654
# SP_std =  0.0253316519531
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type123, l2_penalty_3.162278 ...
# AC_mean =  0.853432258065
# AC_std =  0.0388578861671
# SE_mean =  0.493422933061
# SE_std =  0.0623917346351
# SP_mean =  0.942529162543
# SP_std =  0.0232217189418
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type123, l2_penalty_5.623413 ...
# AC_mean =  0.85424516129
# AC_std =  0.0433290322581
# SE_mean =  0.447593013711
# SE_std =  0.0809176416305
# SP_mean =  0.954410132455
# SP_std =  0.0202634389736
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type123, l2_penalty_10.000000 ...
# AC_mean =  0.849419354839
# AC_std =  0.0428941052639
# SE_mean =  0.373548618779
# SE_std =  0.0767300925563
# SP_mean =  0.967796119669
# SP_std =  0.019124494584
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type123, l2_penalty_17.782794 ...
# AC_mean =  0.837406451613
# AC_std =  0.0477116974861
# SE_mean =  0.26336808294
# SE_std =  0.0904620574248
# SP_mean =  0.979706562574
# SP_std =  0.0138553789934
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type123, l2_penalty_31.622777 ...
# AC_mean =  0.817374193548
# AC_std =  0.0450171899183
# SE_mean =  0.0969558767256
# SE_std =  0.0614296433154
# SP_mean =  0.996226415094
# SP_std =  0.00625778262331
#
# ========================================
# Loading features: mouse01, window_length150 ...
#
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.010000 ...
# AC_mean =  0.882393984555
# AC_std =  0.0227459661352
# SE_mean =  0.679543775953
# SE_std =  0.104562918141
# SP_mean =  0.932236001311
# SP_std =  0.023168917399
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.017783 ...
# AC_mean =  0.877455629319
# AC_std =  0.0216556973243
# SE_mean =  0.667581007337
# SE_std =  0.101693173277
# SP_mean =  0.9291063142
# SP_std =  0.0219661286301
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.031623 ...
# AC_mean =  0.876629183038
# AC_std =  0.0215361889941
# SE_mean =  0.65958727693
# SE_std =  0.095889495743
# SP_mean =  0.93009641321
# SP_std =  0.0217915038437
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.056234 ...
# AC_mean =  0.875809510906
# AC_std =  0.0207034034075
# SE_mean =  0.65958727693
# SE_std =  0.095889495743
# SP_mean =  0.929140639143
# SP_std =  0.0196905466419
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.100000 ...
# AC_mean =  0.873350494513
# AC_std =  0.0191922365219
# SE_mean =  0.663810879414
# SE_std =  0.101678775591
# SP_mean =  0.925078364293
# SP_std =  0.021772741548
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.177828 ...
# AC_mean =  0.875829833356
# AC_std =  0.0215162824726
# SE_mean =  0.65496648307
# SE_std =  0.0975938173464
# SP_mean =  0.930018496286
# SP_std =  0.0196796109107
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.316228 ...
# AC_mean =  0.872557918981
# AC_std =  0.0261685162977
# SE_mean =  0.643845465296
# SE_std =  0.102707813882
# SP_mean =  0.928955557554
# SP_std =  0.0205700632578
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.562341 ...
# AC_mean =  0.865980219482
# AC_std =  0.0244885694888
# SE_mean =  0.621939364151
# SE_std =  0.100942292793
# SP_mean =  0.925975565677
# SP_std =  0.0197977394405
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_1.000000 ...
# AC_mean =  0.863507654789
# AC_std =  0.0242923969765
# SE_mean =  0.602361384659
# SE_std =  0.0915719250487
# SP_mean =  0.928006074851
# SP_std =  0.0194518488592
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_1.778279 ...
# AC_mean =  0.860242514564
# AC_std =  0.0241237253662
# SE_mean =  0.571667404726
# SE_std =  0.101050801645
# SP_mean =  0.931093231392
# SP_std =  0.0172990503229
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_3.162278 ...
# AC_mean =  0.85694350359
# AC_std =  0.0224914384186
# SE_mean =  0.53474786874
# SE_std =  0.103343158034
# SP_mean =  0.936272049125
# SP_std =  0.016969763298
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_5.623413 ...
# AC_mean =  0.852838368785
# AC_std =  0.0283682955213
# SE_mean =  0.470698142992
# SE_std =  0.111823152074
# SP_mean =  0.947621697863
# SP_std =  0.0176399624267
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_10.000000 ...
# AC_mean =  0.838023303075
# AC_std =  0.0287629548834
# SE_mean =  0.356744728147
# SE_std =  0.100079472717
# SP_mean =  0.957945356044
# SP_std =  0.0170073142946
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_17.782794 ...
# AC_mean =  0.828952716434
# AC_std =  0.0385511029036
# SE_mean =  0.244269208081
# SE_std =  0.151211082636
# SP_mean =  0.976425253629
# SP_std =  0.013256416024
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_31.622777 ...
# AC_mean =  0.815783769137
# AC_std =  0.0313490967805
# SE_mean =  0.0992098302331
# SE_std =  0.0601636123138
# SP_mean =  0.994865091571
# SP_std =  0.00684019243152
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.010000 ...
# AC_mean =  0.854396423249
# AC_std =  0.0275021006375
# SE_mean =  0.490243871016
# SE_std =  0.0969562400447
# SP_mean =  0.945436396682
# SP_std =  0.0168063706508
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.017783 ...
# AC_mean =  0.851097412275
# AC_std =  0.0297924222109
# SE_mean =  0.456658144038
# SE_std =  0.0966922723352
# SP_mean =  0.949455297496
# SP_std =  0.0213110069891
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.031623 ...
# AC_mean =  0.846152282888
# AC_std =  0.0365399733609
# SE_mean =  0.413322827569
# SE_std =  0.112238799353
# SP_mean =  0.954625064578
# SP_std =  0.0221626721239
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.056234 ...
# AC_mean =  0.833823330172
# AC_std =  0.0333796733643
# SE_mean =  0.326612521661
# SE_std =  0.114571425268
# SP_mean =  0.960873460065
# SP_std =  0.0184151244582
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.100000 ...
# AC_mean =  0.819855033193
# AC_std =  0.0324595185837
# SE_mean =  0.239767914772
# SE_std =  0.111329852265
# SP_mean =  0.964970717617
# SP_std =  0.0162208244706
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.177828 ...
# AC_mean =  0.808325430159
# AC_std =  0.0320610750789
# SE_mean =  0.14285549214
# SE_std =  0.0677658959339
# SP_mean =  0.974208633698
# SP_std =  0.0167352829175
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.316228 ...
# AC_mean =  0.80999187102
# AC_std =  0.0272034617166
# SE_mean =  0.0886888605592
# SE_std =  0.0448952477563
# SP_mean =  0.989754485465
# SP_std =  0.01101805519
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.562341 ...
# AC_mean =  0.805087386533
# AC_std =  0.0276630112333
# SE_mean =  0.026433747412
# SE_std =  0.0368586868536
# SP_mean =  0.998979591837
# SP_std =  0.0030612244898
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_1.000000 ...
# AC_mean =  0.801795149709
# AC_std =  0.0241109008623
# SE_mean =  0.00357142857143
# SE_std =  0.0107142857143
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_1.778279 ...
# AC_mean =  0.800968703428
# AC_std =  0.025073862977
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_3.162278 ...
# AC_mean =  0.800968703428
# AC_std =  0.025073862977
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_5.623413 ...
# AC_mean =  0.800968703428
# AC_std =  0.025073862977
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_10.000000 ...
# AC_mean =  0.800968703428
# AC_std =  0.025073862977
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_17.782794 ...
# AC_mean =  0.800968703428
# AC_std =  0.025073862977
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_31.622777 ...
# AC_mean =  0.800968703428
# AC_std =  0.025073862977
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.010000 ...
# AC_mean =  0.829752066116
# AC_std =  0.0299254584671
# SE_mean =  0.35675248498
# SE_std =  0.126939390869
# SP_mean =  0.946430357359
# SP_std =  0.0164054888093
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.017783 ...
# AC_mean =  0.826459829291
# AC_std =  0.0286483402143
# SE_mean =  0.352207030434
# SE_std =  0.127424403677
# SP_mean =  0.943439458029
# SP_std =  0.0144289485489
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.031623 ...
# AC_mean =  0.826459829291
# AC_std =  0.0317623813615
# SE_mean =  0.353040363768
# SE_std =  0.145021436123
# SP_mean =  0.943439458029
# SP_std =  0.0144289485489
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.056234 ...
# AC_mean =  0.827286275572
# AC_std =  0.0314198506782
# SE_mean =  0.352897913625
# SE_std =  0.147480447304
# SP_mean =  0.944514726846
# SP_std =  0.0124596738698
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.100000 ...
# AC_mean =  0.826459829291
# AC_std =  0.0295564596157
# SE_mean =  0.344648755376
# SE_std =  0.146250981197
# SP_mean =  0.94553513501
# SP_std =  0.0131805363202
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.177828 ...
# AC_mean =  0.826466603441
# AC_std =  0.0295188668774
# SE_mean =  0.331075987564
# SE_std =  0.133917411141
# SP_mean =  0.948515727186
# SP_std =  0.014931795259
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.316228 ...
# AC_mean =  0.82565370546
# AC_std =  0.0248514384208
# SE_mean =  0.313477245726
# SE_std =  0.110170338473
# SP_mean =  0.951656487879
# SP_std =  0.0105939507467
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.562341 ...
# AC_mean =  0.82565370546
# AC_std =  0.0248379735167
# SE_mean =  0.303997144507
# SE_std =  0.103370173086
# SP_mean =  0.953751386425
# SP_std =  0.0153713454873
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_1.000000 ...
# AC_mean =  0.828939168134
# AC_std =  0.0243130796797
# SE_mean =  0.296845164941
# SE_std =  0.095547341992
# SP_mean =  0.95996683752
# SP_std =  0.0131729890093
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_1.778279 ...
# AC_mean =  0.825626608861
# AC_std =  0.0212596189269
# SE_mean =  0.263440121708
# SE_std =  0.0818922980753
# SP_mean =  0.964081337785
# SP_std =  0.0131443818368
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_3.162278 ...
# AC_mean =  0.82563338301
# AC_std =  0.020223849685
# SE_mean =  0.226328753705
# SE_std =  0.0765117547607
# SP_mean =  0.97339298251
# SP_std =  0.0129319645669
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_5.623413 ...
# AC_mean =  0.819895678092
# AC_std =  0.0182102214295
# SE_mean =  0.160006833774
# SE_std =  0.066819896649
# SP_mean =  0.982510912211
# SP_std =  0.0102810901839
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_10.000000 ...
# AC_mean =  0.816616989568
# AC_std =  0.0183421525153
# SE_mean =  0.111728392103
# SE_std =  0.0586874296236
# SP_mean =  0.990757526866
# SP_std =  0.00712670595944
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_17.782794 ...
# AC_mean =  0.807546402926
# AC_std =  0.0200684803666
# SE_mean =  0.0345176434982
# SE_std =  0.033792005586
# SP_mean =  0.99898989899
# SP_std =  0.0030303030303
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_31.622777 ...
# AC_mean =  0.80262159599
# AC_std =  0.0227803902551
# SE_mean =  0.00689655172414
# SE_std =  0.0206896551724
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type012, l2_penalty_0.010000 ...
# AC_mean =  0.888185882672
# AC_std =  0.0282157482609
# SE_mean =  0.690026358089
# SE_std =  0.106357342318
# SP_mean =  0.937668597549
# SP_std =  0.0290150884814
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type012, l2_penalty_0.017783 ...
# AC_mean =  0.885699769679
# AC_std =  0.0304183474099
# SE_mean =  0.685290203439
# SE_std =  0.104887736836
# SP_mean =  0.935553518868
# SP_std =  0.0313568499082
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type012, l2_penalty_0.031623 ...
# AC_mean =  0.881567538274
# AC_std =  0.0276008003265
# SE_mean =  0.664954916537
# SE_std =  0.0955106720232
# SP_mean =  0.935596049437
# SP_std =  0.0326491957458
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type012, l2_penalty_0.056234 ...
# AC_mean =  0.874996612925
# AC_std =  0.0269412810788
# SE_mean =  0.643018157643
# SE_std =  0.118400656299
# SP_mean =  0.932347646011
# SP_std =  0.0281752985904
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type012, l2_penalty_0.100000 ...
# AC_mean =  0.871697601951
# AC_std =  0.0283030595667
# SE_mean =  0.650024427236
# SE_std =  0.12290083063
# SP_mean =  0.92704945576
# SP_std =  0.0258941093404
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type012, l2_penalty_0.177828 ...
# AC_mean =  0.871711150251
# AC_std =  0.0232541833411
# SE_mean =  0.647309734521
# SE_std =  0.116148298728
# SP_mean =  0.927039148607
# SP_std =  0.0263480675823
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type012, l2_penalty_0.316228 ...
# AC_mean =  0.872544370681
# AC_std =  0.0257042391078
# SE_mean =  0.652935898712
# SE_std =  0.0940125831375
# SP_mean =  0.926997888103
# SP_std =  0.0244248848393
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type012, l2_penalty_0.562341 ...
# AC_mean =  0.867626337895
# AC_std =  0.0274248082733
# SE_mean =  0.626106030817
# SE_std =  0.107118941661
# SP_mean =  0.927061141648
# SP_std =  0.0198617588978
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type012, l2_penalty_1.000000 ...
# AC_mean =  0.865980219482
# AC_std =  0.0266013921089
# SE_mean =  0.61057183363
# SE_std =  0.106154784938
# SP_mean =  0.929081343668
# SP_std =  0.0189370909093
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type012, l2_penalty_1.778279 ...
# AC_mean =  0.863527977239
# AC_std =  0.0209108734094
# SE_mean =  0.583194717992
# SE_std =  0.101606367266
# SP_mean =  0.93216850021
# SP_std =  0.0165183862351
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type012, l2_penalty_3.162278 ...
# AC_mean =  0.860235740415
# AC_std =  0.0233211223729
# SE_mean =  0.548005444497
# SE_std =  0.101170821697
# SP_mean =  0.937292457289
# SP_std =  0.0167817880339
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type012, l2_penalty_5.623413 ...
# AC_mean =  0.852845142935
# AC_std =  0.0292677306689
# SE_mean =  0.470102904897
# SE_std =  0.120059705686
# SP_mean =  0.947621697863
# SP_std =  0.0176399624267
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type012, l2_penalty_10.000000 ...
# AC_mean =  0.840489093619
# AC_std =  0.03128495803
# SE_mean =  0.369152135554
# SE_std =  0.113115286459
# SP_mean =  0.957945356044
# SP_std =  0.0170073142946
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type012, l2_penalty_17.782794 ...
# AC_mean =  0.829772388565
# AC_std =  0.038432020796
# SE_mean =  0.248617034168
# SE_std =  0.148475786806
# SP_mean =  0.976425253629
# SP_std =  0.013256416024
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type012, l2_penalty_31.622777 ...
# AC_mean =  0.815783769137
# AC_std =  0.0313490967805
# SE_mean =  0.104209830233
# SE_std =  0.0731612051864
# SP_mean =  0.993874992561
# SP_std =  0.00674112464221
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type013, l2_penalty_0.010000 ...
# AC_mean =  0.881574312424
# AC_std =  0.0282771028552
# SE_mean =  0.665469762899
# SE_std =  0.0931386406027
# SP_mean =  0.935288885937
# SP_std =  0.024519542783
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type013, l2_penalty_0.017783 ...
# AC_mean =  0.884880097548
# AC_std =  0.0283783876714
# SE_mean =  0.677489467332
# SE_std =  0.0980570337906
# SP_mean =  0.936344152754
# SP_std =  0.022928366212
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type013, l2_penalty_0.031623 ...
# AC_mean =  0.879948516461
# AC_std =  0.0284228797218
# SE_mean =  0.665024758128
# SE_std =  0.106090200358
# SP_mean =  0.93325071841
# SP_std =  0.020701712749
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type013, l2_penalty_0.056234 ...
# AC_mean =  0.878309172199
# AC_std =  0.0294539567828
# SE_mean =  0.665024758128
# SE_std =  0.106090200358
# SP_mean =  0.931147247022
# SP_std =  0.0234279479177
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type013, l2_penalty_0.100000 ...
# AC_mean =  0.870898252269
# AC_std =  0.0347785248841
# SE_mean =  0.644689678554
# SE_std =  0.114332907495
# SP_mean =  0.927139132987
# SP_std =  0.0253025897937
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type013, l2_penalty_0.177828 ...
# AC_mean =  0.875003387075
# AC_std =  0.0304168048277
# SE_mean =  0.634822371948
# SE_std =  0.12580203928
# SP_mean =  0.934265313018
# SP_std =  0.0208937725941
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type013, l2_penalty_0.316228 ...
# AC_mean =  0.871704376101
# AC_std =  0.0316229540757
# SE_mean =  0.625731462857
# SE_std =  0.140382020384
# SP_mean =  0.932048869405
# SP_std =  0.0198889977251
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type013, l2_penalty_0.562341 ...
# AC_mean =  0.874176940794
# AC_std =  0.0340466668562
# SE_mean =  0.622406339704
# SE_std =  0.136340023154
# SP_mean =  0.936168655526
# SP_std =  0.0207274583706
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type013, l2_penalty_1.000000 ...
# AC_mean =  0.874183714944
# AC_std =  0.0311336131464
# SE_mean =  0.610045693104
# SE_std =  0.1341521414
# SP_mean =  0.93924286786
# SP_std =  0.0184466340309
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type013, l2_penalty_1.778279 ...
# AC_mean =  0.867633112044
# AC_std =  0.0300119915167
# SE_mean =  0.583479992299
# SE_std =  0.124421054729
# SP_mean =  0.937252374693
# SP_std =  0.0171570473144
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type013, l2_penalty_3.162278 ...
# AC_mean =  0.867619563745
# AC_std =  0.0305109965019
# SE_mean =  0.571196442516
# SE_std =  0.129247662363
# SP_mean =  0.94024835278
# SP_std =  0.0206417659379
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type013, l2_penalty_5.623413 ...
# AC_mean =  0.865980219482
# AC_std =  0.0273567514226
# SE_mean =  0.535061928881
# SE_std =  0.115652447865
# SP_mean =  0.947583704789
# SP_std =  0.0181740348549
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type013, l2_penalty_10.000000 ...
# AC_mean =  0.859409294134
# AC_std =  0.0311522403981
# SE_mean =  0.466004534779
# SE_std =  0.127123358752
# SP_mean =  0.956843793862
# SP_std =  0.0165272697056
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type013, l2_penalty_17.782794 ...
# AC_mean =  0.847900013548
# AC_std =  0.0285546454869
# SE_mean =  0.366804602056
# SE_std =  0.108744011027
# SP_mean =  0.967119605545
# SP_std =  0.0121070573862
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type013, l2_penalty_31.622777 ...
# AC_mean =  0.828932393985
# AC_std =  0.0229632099427
# ...
# Classifying --> classifier: LR, feature_type123, l2_penalty_17.782794 ...
# AC_mean =  0.837808004558
# AC_std =  0.0323336981749
# SE_mean =  0.677905666871
# SE_std =  0.0545109359304
# SP_mean =  0.92483521413
# SP_std =  0.0329422573795
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type123, l2_penalty_31.622777 ...
# AC_mean =  0.834432417035
# AC_std =  0.0322235928154
# SE_mean =  0.669016777982
# SE_std =  0.0560776548566
# SP_mean =  0.92483521413
# SP_std =  0.0329422573795
#
# ========================================
# Loading features: mouse04, window_length250 ...
#
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.010000 ...
# AC_mean =  0.820367316342
# AC_std =  0.0294822935559
# SE_mean =  0.679018520663
# SE_std =  0.0673348846624
# SP_mean =  0.897305955921
# SP_std =  0.0399539604949
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.017783 ...
# AC_mean =  0.82383808096
# AC_std =  0.0273701901785
# SE_mean =  0.681796298441
# SE_std =  0.0673409958781
# SP_mean =  0.901369118299
# SP_std =  0.0387532938623
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.031623 ...
# AC_mean =  0.82643928036
# AC_std =  0.0271036946252
# SE_mean =  0.686394607109
# SE_std =  0.0629710359482
# SP_mean =  0.902777569003
# SP_std =  0.0379530347365
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.056234 ...
# AC_mean =  0.830779610195
# AC_std =  0.0274640449073
# SE_mean =  0.686608282323
# SE_std =  0.0662238258316
# SP_mean =  0.909423841239
# SP_std =  0.0395581353145
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.100000 ...
# AC_mean =  0.836851574213
# AC_std =  0.0273730274184
# SE_mean =  0.693931514646
# SE_std =  0.0683135455711
# SP_mean =  0.914925859195
# SP_std =  0.041553863345
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.177828 ...
# AC_mean =  0.838583208396
# AC_std =  0.028054817531
# SE_mean =  0.696090798924
# SE_std =  0.0674469115933
# SP_mean =  0.91619168198
# SP_std =  0.0416196933109
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.316228 ...
# AC_mean =  0.835974512744
# AC_std =  0.026462054736
# SE_mean =  0.688887168748
# SE_std =  0.0630530009188
# SP_mean =  0.916075739951
# SP_std =  0.0358358410543
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.562341 ...
# AC_mean =  0.836836581709
# AC_std =  0.0292967333817
# SE_mean =  0.68875923955
# SE_std =  0.0650929262379
# SP_mean =  0.917520184395
# SP_std =  0.0398655277741
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_1.000000 ...
# AC_mean =  0.831626686657
# AC_std =  0.0264435732999
# SE_mean =  0.679767144689
# SE_std =  0.0558149311632
# SP_mean =  0.91476038234
# SP_std =  0.0412052235424
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_1.778279 ...
# AC_mean =  0.829017991004
# AC_std =  0.0269985490789
# SE_mean =  0.676989366911
# SE_std =  0.0557064666892
# SP_mean =  0.912110751209
# SP_std =  0.0409063246105
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_3.162278 ...
# AC_mean =  0.829025487256
# AC_std =  0.0226927727333
# SE_mean =  0.672376429477
# SE_std =  0.0539814382203
# SP_mean =  0.914611983316
# SP_std =  0.034747116926
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_5.623413 ...
# AC_mean =  0.829017991004
# AC_std =  0.0231058864965
# SE_mean =  0.669673726774
# SE_std =  0.0544233711395
# SP_mean =  0.915859788083
# SP_std =  0.0329716496111
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_10.000000 ...
# AC_mean =  0.825547226387
# AC_std =  0.0229042281071
# SE_mean =  0.657322210353
# SE_std =  0.0548772702821
# SP_mean =  0.917268238787
# SP_std =  0.0320093832838
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_17.782794 ...
# AC_mean =  0.822938530735
# AC_std =  0.0265333432814
# SE_mean =  0.644942996953
# SE_std =  0.0534820131736
# SP_mean =  0.920166789512
# SP_std =  0.035266918573
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_31.622777 ...
# AC_mean =  0.817736131934
# AC_std =  0.0240473217168
# SE_mean =  0.623813060884
# SE_std =  0.0582469708852
# SP_mean =  0.924190624831
# SP_std =  0.0326095046441
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.010000 ...
# AC_mean =  0.801244377811
# AC_std =  0.0314885447214
# SE_mean =  0.615891598509
# SE_std =  0.06687517774
# SP_mean =  0.9041927754
# SP_std =  0.0393029190039
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.017783 ...
# AC_mean =  0.802968515742
# AC_std =  0.0279153857473
# SE_mean =  0.605497795127
# SE_std =  0.0572224222165
# SP_mean =  0.912319100156
# SP_std =  0.0376748960971
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.031623 ...
# AC_mean =  0.798620689655
# AC_std =  0.0273563734208
# SE_mean =  0.592326113755
# SE_std =  0.060606972747
# SP_mean =  0.912449298924
# SP_std =  0.039503333606
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.056234 ...
# AC_mean =  0.797773613193
# AC_std =  0.0249361001704
# SE_mean =  0.575747791384
# SE_std =  0.0565082772551
# SP_mean =  0.920398745344
# SP_std =  0.0351656366896
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.100000 ...
# AC_mean =  0.79344077961
# AC_std =  0.026261398911
# SE_mean =  0.552224791031
# SE_std =  0.0654820962756
# SP_mean =  0.927322920909
# SP_std =  0.0370663366666
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.177828 ...
# AC_mean =  0.777818590705
# AC_std =  0.0279845122798
# SE_mean =  0.502717544982
# SE_std =  0.0800567234716
# SP_mean =  0.931257936639
# SP_std =  0.0354552546408
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.316228 ...
# AC_mean =  0.763943028486
# AC_std =  0.0351773470417
# SE_mean =  0.458240610659
# SE_std =  0.0825719248813
# SP_mean =  0.933729195736
# SP_std =  0.0324586811361
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.562341 ...
# AC_mean =  0.749175412294
# AC_std =  0.0282392872306
# SE_mean =  0.398582833529
# SE_std =  0.0732535900183
# SP_mean =  0.942983537686
# SP_std =  0.0267469278557
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_1.000000 ...
# AC_mean =  0.731836581709
# AC_std =  0.0351291679278
# SE_mean =  0.340760048479
# SE_std =  0.0873450384613
# SP_mean =  0.948417567033
# SP_std =  0.0277734523229
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_1.778279 ...
# AC_mean =  0.703178410795
# AC_std =  0.0332809979308
# SE_mean =  0.226510820005
# SE_std =  0.068844741527
# SP_mean =  0.965659447461
# SP_std =  0.0218629301604
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_3.162278 ...
# AC_mean =  0.664092953523
# AC_std =  0.0294901634082
# SE_mean =  0.10007373218
# SE_std =  0.0537114390859
# SP_mean =  0.973728672864
# SP_std =  0.0227871115573
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_5.623413 ...
# AC_mean =  0.646724137931
# AC_std =  0.02744295906
# SE_mean =  0.00716241123218
# SE_std =  0.0109627672492
# SP_mean =  0.996043675229
# SP_std =  0.00605346646902
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_10.000000 ...
# AC_mean =  0.646724137931
# AC_std =  0.0293082943105
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_17.782794 ...
# AC_mean =  0.646724137931
# AC_std =  0.0293082943105
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_31.622777 ...
# AC_mean =  0.646724137931
# AC_std =  0.0293082943105
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.010000 ...
# AC_mean =  0.750869565217
# AC_std =  0.0374784286787
# SE_mean =  0.489846916577
# SE_std =  0.0415451864249
# SP_mean =  0.894777501312
# SP_std =  0.0553806582476
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.017783 ...
# AC_mean =  0.750869565217
# AC_std =  0.0374784286787
# SE_mean =  0.489846916577
# SE_std =  0.0415451864249
# SP_mean =  0.894777501312
# SP_std =  0.0553806582476
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.031623 ...
# AC_mean =  0.752608695652
# AC_std =  0.035849155036
# SE_mean =  0.487144213874
# SE_std =  0.0389579817647
# SP_mean =  0.898717597586
# SP_std =  0.0530615777931
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.056234 ...
# AC_mean =  0.754340329835
# AC_std =  0.0368846132071
# SE_mean =  0.489921991652
# SE_std =  0.0425782903522
# SP_mean =  0.900050930919
# SP_std =  0.0520625233083
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.100000 ...
# AC_mean =  0.75607946027
# AC_std =  0.0350561231064
# SE_mean =  0.492486094216
# SE_std =  0.0415514842366
# SP_mean =  0.901316753704
# SP_std =  0.0506099082512
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.177828 ...
# AC_mean =  0.759550224888
# AC_std =  0.0362588085178
# SE_mean =  0.49047847829
# SE_std =  0.0362674774473
# SP_mean =  0.90798235932
# SP_std =  0.05213535337
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.316228 ...
# AC_mean =  0.759542728636
# AC_std =  0.0348229108199
# SE_mean =  0.482863870676
# SE_std =  0.0341659480071
# SP_mean =  0.911947271601
# SP_std =  0.0472182068511
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.562341 ...
# AC_mean =  0.760419790105
# AC_std =  0.0311235133741
# SE_mean =  0.483393767136
# SE_std =  0.036221043402
# SP_mean =  0.913006509082
# SP_std =  0.0403794596414
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_1.000000 ...
# AC_mean =  0.762173913043
# AC_std =  0.0265039141811
# SE_mean =  0.481196114938
# SE_std =  0.0362759590478
# SP_mean =  0.917212299379
# SP_std =  0.0360596712345
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_1.778279 ...
# AC_mean =  0.763035982009
# AC_std =  0.0228430475414
# SE_mean =  0.471139546742
# SE_std =  0.0399922664966
# SP_mean =  0.924047650668
# SP_std =  0.0326602620124
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_3.162278 ...
# AC_mean =  0.764775112444
# AC_std =  0.02326995123
# SE_mean =  0.464215656678
# SE_std =  0.0465533931454
# SP_mean =  0.930811920498
# SP_std =  0.0267194782471
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_5.623413 ...
# AC_mean =  0.767383808096
# AC_std =  0.0239749882688
# SE_mean =  0.456334519728
# SE_std =  0.043904161168
# SP_mean =  0.938665418566
# SP_std =  0.023667915295
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_10.000000 ...
# AC_mean =  0.763073463268
# AC_std =  0.0313672990003
# SE_mean =  0.430709132212
# SE_std =  0.0648368966259
# SP_mean =  0.946658211236
# SP_std =  0.0247372316707
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_17.782794 ...
# AC_mean =  0.756139430285
# AC_std =  0.0303576627586
# SE_mean =  0.386655786435
# SE_std =  0.0758347135563
# SP_mean =  0.960363168918
# SP_std =  0.0266082855208
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_31.622777 ...
# AC_mean =  0.745727136432
# AC_std =  0.0356604194671
# SE_mean =  0.333047065355
# SE_std =  0.0763805009736
# SP_mean =  0.973684188802
# SP_std =  0.0217102824912
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type012, l2_penalty_0.010000 ...
# AC_mean =  0.822091454273
# AC_std =  0.029367288826
# SE_mean =  0.695470179294
# SE_std =  0.0556862845939
# SP_mean =  0.891952624222
# SP_std =  0.0466301114187
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type012, l2_penalty_0.017783 ...
# AC_mean =  0.822953523238
# AC_std =  0.0299168979084
# SE_mean =  0.692880919586
# SE_std =  0.0570209873717
# SP_mean =  0.894794075594
# SP_std =  0.0508617121322
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type012, l2_penalty_0.031623 ...
# AC_mean =  0.831634182909
# AC_std =  0.0291463681588
# SE_mean =  0.704350264195
# SE_std =  0.0465444226494
# SP_mean =  0.9015096479
# SP_std =  0.0501543061939
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type012, l2_penalty_0.056234 ...
# AC_mean =  0.831634182909
# AC_std =  0.0267096408949
# SE_mean =  0.696280835195
# SE_std =  0.0546190306477
# SP_mean =  0.90537331144
# SP_std =  0.0492867641066
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type012, l2_penalty_0.100000 ...
# AC_mean =  0.836844077961
# AC_std =  0.0222676600388
# SE_mean =  0.704010303795
# SE_std =  0.0683732349573
# SP_mean =  0.909320531789
# SP_std =  0.0432726537365
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type012, l2_penalty_0.177828 ...
# AC_mean =  0.837698650675
# AC_std =  0.0262026860045
# SE_mean =  0.696520774354
# SE_std =  0.0649548079879
# SP_mean =  0.914938017616
# SP_std =  0.0439686550297
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type012, l2_penalty_0.316228 ...
# AC_mean =  0.834235382309
# AC_std =  0.0297125562606
# SE_mean =  0.691212750143
# SE_std =  0.0646854204083
# SP_mean =  0.912338861497
# SP_std =  0.0454526297807
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type012, l2_penalty_0.562341 ...
# AC_mean =  0.829017991004
# AC_std =  0.0336921698641
# SE_mean =  0.679072057912
# SE_std =  0.0593630710016
# SP_mean =  0.911025047684
# SP_std =  0.0485836639151
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type012, l2_penalty_1.000000 ...
# AC_mean =  0.828148425787
# AC_std =  0.0269388478466
# SE_mean =  0.67708818114
# SE_std =  0.0572065409136
# SP_mean =  0.910967994528
# SP_std =  0.0443167385055
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type012, l2_penalty_1.778279 ...
# AC_mean =  0.829017991004
# AC_std =  0.0275529925609
# SE_mean =  0.672376429477
# SE_std =  0.0561422236056
# SP_mean =  0.914765462883
# SP_std =  0.0413815154221
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type012, l2_penalty_3.162278 ...
# AC_mean =  0.830749625187
# AC_std =  0.0228959831171
# SE_mean =  0.674815453867
# SE_std =  0.0527356330948
# SP_mean =  0.91604324066
# SP_std =  0.0357124342029
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type012, l2_penalty_5.623413 ...
# AC_mean =  0.829887556222
# AC_std =  0.0244147767941
# SE_mean =  0.669673726774
# SE_std =  0.0544233711395
# SP_mean =  0.917309063445
# SP_std =  0.0343785691371
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type012, l2_penalty_10.000000 ...

# %%
AC_saveName = ("%s_mouse%02d_window_length%03d_window_step%03d_AC.csv" \
           % (classifier,mouse_id,window_length,window_step))
SE_saveName = ("%s_mouse%02d_window_length%03d_window_step%03d_SE.csv" \
           % (classifier,mouse_id,window_length,window_step))
SP_saveName = ("%s_mouse%02d_window_length%03d_window_step%03d_SP.csv" \
           % (classifier,mouse_id,window_length,window_step))
df_AC = pd.DataFrame(AC)
df_SE = pd.DataFrame(SE)        
df_SP = pd.DataFrame(SP)  

os.chdir("/Users/lizhu/Dropbox/projects/calcium/classification_result") 
df_AC.to_csv(AC_saveName, index = False, header = False)
df_SE.to_csv(SE_saveName, index = False, header = False)
df_SP.to_csv(SP_saveName, index = False, header = False)

# %%
# load and organize feature matrix
def lz_load_feature_matrix(mouse_id, window_length, window_step):
    fileName = "format4ML_GC6f_emx_0" + str(mouse_id) + "_windowLen" + str(window_length) + "_winStep_0" + str(window_step) + "_v2_threshold_10.csv"
    loadPath = "/Users/lizhu/Dropbox/projects/calcium/format4ML/" + fileName
    comb = gl.SFrame.read_csv(loadPath, delimiter=',',header=False,verbose = False)
    colName_dg = 'degree'
    colName_dg = gl.SArray([colName_dg + repr(i+1) for i in range(30)])
    colName_cc = 'clusteringCoef'
    colName_cc = gl.SArray([colName_cc + repr(i+1) for i in range(30)])
    colName_pl = 'pathlength'
    colName_pl = gl.SArray([colName_pl + repr(i+1) for i in range(30)])
    colName = colName_dg.append(colName_cc.append(colName_pl.append(gl.SArray(['Whisker']))))
    colName = (list(colName))
    dictionary = dict(zip(comb.column_names(), colName))
    comb = comb.rename(dictionary)
    comb = gl.toolkits.cross_validation.shuffle(comb, random_seed=1)
    # comb['Whisker'].show(view = 'Categorical')
    
    return comb

# %%
# train and cross-validation
def lz_svm_AC_SE_SP(data, feature_type, l2_penalty):
    
    # clearify features
    feature_dg = comb.column_names()[0:30] # feature 1~30: degree, 31~60: clustering coefficient, 60~90: pathlength
    feature_cc = comb.column_names()[30:60]
    feature_pl = comb.column_names()[60:90]
    
    if feature_type == 1:   feature = feature_dg
    if feature_type == 2:   feature = feature_cc
    if feature_type == 3:   feature = feature_pl
    if feature_type == 12:  feature = feature_dg + feature_cc
    if feature_type == 13:  feature = feature_dg + feature_pl
    if feature_type == 23:  feature = feature_cc + feature_pl
    if feature_type == 123: feature = feature_dg + feature_cc + feature_pl
     
    # Kfold
    num_fold = 10
    folds = gl.cross_validation.KFold(comb, num_fold)
    SE = [None] * num_fold
    SP = [None] * num_fold
    AC = [None] * num_fold
    # print specificity
    idx = 0
    for train, valid in folds:
        m = gl.svm_classifier.create(train,
                                          target='Whisker',
                                          features=feature,
                                          penalty = l2_penalty, 
                                          validation_set=None,
                                          verbose = False)
        confusion_matrix = m.evaluate(valid, 'confusion_matrix')
        confusion_matrix = confusion_matrix.values()[0]
        
        TP, TN, FP, FN = lz_extract_ACC_SE_SP(confusion_matrix)
        
        SP[idx] = float(TN) / (TN + FP)
        SE[idx] = float(TP) / (TP + FN)
        AC[idx] = float(TP+TN) / (TP+TN+FP+FN)
        idx = idx + 1
        
    AC_mn = np.mean(AC)
    AC_sd = np.std(AC)
    SE_mn = np.mean(SE)
    SE_sd = np.std(SE)
    SP_mn = np.mean(SP)
    SP_sd = np.std(SP)
    
    print 'AC_mean = ', AC_mn
    print 'AC_std = ',  AC_sd
    print 'SE_mean = ', SE_mn
    print 'SE_std = ',  SE_sd
    print 'SP_mean = ', SP_mn
    print 'SP_std = ',  SP_sd
    
    return AC_mn, SE_mn, SP_mn

# %%
# train and cross-validation
def lz_logistic_AC_SE_SP(data, feature_type, l2_penalty, l1_penalty):
    
    # clearify features
    feature_dg = comb.column_names()[0:30] # feature 1~30: degree, 31~60: clustering coefficient, 60~90: pathlength
    feature_cc = comb.column_names()[30:60]
    feature_pl = comb.column_names()[60:90]
    
    if feature_type == 1:   feature = feature_dg
    if feature_type == 2:   feature = feature_cc
    if feature_type == 3:   feature = feature_pl
    if feature_type == 12:  feature = feature_dg + feature_cc
    if feature_type == 13:  feature = feature_dg + feature_pl
    if feature_type == 23:  feature = feature_cc + feature_pl
    if feature_type == 123: feature = feature_dg + feature_cc + feature_pl
     
    # Kfold
    num_fold = 10
    folds = gl.cross_validation.KFold(comb, num_fold)
    SE = [None] * num_fold
    SP = [None] * num_fold
    AC = [None] * num_fold
    # print specificity
    idx = 0
    for train, valid in folds:
        m = gl.logistic_classifier.create(train,
                                          target='Whisker',
                                          features=feature,
                                          l2_penalty = l2_penalty, 
                                          l1_penalty = l1_penalty,
                                          validation_set=None,
                                          verbose = False)
        confusion_matrix = m.evaluate(valid, 'confusion_matrix')
        confusion_matrix = confusion_matrix.values()[0]
        
        TP, TN, FP, FN = lz_extract_ACC_SE_SP(confusion_matrix)
        
        SP[idx] = float(TN) / (TN + FP)
        SE[idx] = float(TP) / (TP + FN)
        AC[idx] = float(TP+TN) / (TP+TN+FP+FN)
        idx = idx + 1
        
    AC_mn = np.mean(AC)
    AC_sd = np.std(AC)
    SE_mn = np.mean(SE)
    SE_sd = np.std(SE)
    SP_mn = np.mean(SP)
    SP_sd = np.std(SP)
    
    print 'AC_mean = ', AC_mn
    print 'AC_std = ',  AC_sd
    print 'SE_mean = ', SE_mn
    print 'SE_std = ',  SE_sd
    print 'SP_mean = ', SP_mn
    print 'SP_std = ',  SP_sd
    
    return AC_mn, SE_mn, SP_mn

# %%
def lz_extract_ACC_SE_SP(confusion_matrix):
    TP = confusion_matrix[(confusion_matrix['target_label']==1) & (confusion_matrix['predicted_label']==1)]
    if np.size(TP) == 0:
        TP = 0
    else:
        TP = TP['count'][0]
    TN = confusion_matrix[(confusion_matrix['target_label']==0) & (confusion_matrix['predicted_label']==0)]
    if np.size(TN) == 0:
        TN = 0
    else:
        TN = TN['count'][0]
    FP = confusion_matrix[(confusion_matrix['target_label']==0) & (confusion_matrix['predicted_label']==1)]
    if np.size(FP) == 0:
        FP = 0
    else:
        FP = FP['count'][0]
    FN = confusion_matrix[(confusion_matrix['target_label']==1) & (confusion_matrix['predicted_label']==0)]
    if np.size(FN) == 0:
        FN = 0
    else:
        FN = FN['count'][0]
    
    return TP, TN, FP, FN

# %%
# normalize the features
# feature_matrix is a SFrame, first 90 columns are features, last column is labels.
def normalize_features_mice(comb):
    # extract feature columns
    comb_np = comb.to_numpy()
    comb_feature = comb_np[:,0:90]
    
    # compute normed features and norms 
    norms = np.linalg.norm(comb_feature, axis=0) # gives [norm(X[:,0]), norm(X[:,1]), norm(X[:,2])]
    comb_feature_normed = comb_feature / norms
    
    # combine normalized feature vectors and the labels
    comb_normed = np.concatenate((comb_feature_normed,comb_np[:,90:91]),axis = 1)
    # convert numpy array to SFrame
    comb_normed = gl.SFrame(comb_normed)
    comb_normed = comb_normed.unpack('X1', '')
    dictionary_norm = dict(zip(comb_normed.column_names(), colName))
    comb_normed = comb_normed.rename(dictionary_norm) # this is the normed version

    return comb_normed, norms # note: norms is array, comb_normed is SFrame

# %%
############### this is the normalized version of the above code

# normalize the features
# feature_matrix is a SFrame, first 90 columns are features, last column is labels.
def normalize_features_mice(comb):
    # extract feature columns
    comb_np = comb.to_numpy()
    comb_feature = comb_np[:,0:90]
    
    # compute normed features and norms 
    norms = np.linalg.norm(comb_feature, axis=0) # gives [norm(X[:,0]), norm(X[:,1]), norm(X[:,2])]
    comb_feature_normed = comb_feature / norms
    
    # combine normalized feature vectors and the labels
    comb_normed = np.concatenate((comb_feature_normed,comb_np[:,90:91]),axis = 1)
    # convert numpy array to SFrame
    comb_normed = gl.SFrame(comb_normed)
    comb_normed = comb_normed.unpack('X1', '')
    dictionary_norm = dict(zip(comb_normed.column_names(), colName))
    comb_normed = comb_normed.rename(dictionary_norm) # this is the normed version

    return comb_normed, norms # note: norms is array, comb_normed is SFrame

# comb = gl.toolkits.cross_validation.shuffle(comb, random_seed=2)
def lz_logistic(data, feature):
    
    # normalize 
    comb, norms = normalize_features_mice(data)
    comb['Whisker'] = comb['Whisker'].astype(int)

    folds = gl.cross_validation.KFold(comb, 5)
    SE=[None]*5
    SP=[None]*5
    acc=[None]*5
    # print specificity
    idx = 0
    for train, valid in folds:
        m = gl.logistic_classifier.create(train,
                                          target='Whisker',
                                          features=feature,
                                          l2_penalty = 0.05,
                                          validation_set=None,
                                          verbose = False)
        
        # normalize the validation dataset
        valid_np = valid.to_numpy()
        valid_feature = valid_np[:,0:90]

        # use normed from features
        valid_feature_normed = valid_feature / norms

        # combine normalized feature vectors and the labels
        valid_normed = np.concatenate((valid_feature_normed,valid_np[:,90:91]),axis = 1)

        # convert numpy array to SFrame
        valid_normed = gl.SFrame(valid_normed)
        valid_normed = valid_normed.unpack('X1', '')
        dictionary_norm = dict(zip(valid_normed.column_names(), colName))
        valid_normed = valid_normed.rename(dictionary_norm) # this is the normed version
        valid_normed['Whisker'] = valid_normed['Whisker'].astype(int)

        confusion_matrix = m.evaluate(valid, 'confusion_matrix')
        confusion_matrix = confusion_matrix.values()[0]
        TP = confusion_matrix[(confusion_matrix['target_label']==1) & (confusion_matrix['predicted_label']==1)]
        if np.size(TP) == 0:
            TP = 0
        else:
            TP = TP['count'][0]
        TN = confusion_matrix[(confusion_matrix['target_label']==0) & (confusion_matrix['predicted_label']==0)]
        if np.size(TN) == 0:
            TN = 0
        else:
            TN = TN['count'][0]
        FP = confusion_matrix[(confusion_matrix['target_label']==0) & (confusion_matrix['predicted_label']==1)]
        if np.size(FP) == 0:
            FP = 0
        else:
            FP = FP['count'][0]
        FN = confusion_matrix[(confusion_matrix['target_label']==1) & (confusion_matrix['predicted_label']==0)]
        if np.size(FN) == 0:
            FN = 0
        else:
            FN = FN['count'][0]
        SE[idx] = float(TN) / (TN + FP)
        SP[idx] = float(TP) / (TP + FN)
        acc[idx] = float(TP+TN) / (TP+TN+FP+FN)
        idx = idx + 1
    
    print 'acc_mean = ', np.mean(acc)
    print 'acc_std = ', np.std(acc)
    print 'SE_mean = ', np.mean(SE)
    print 'SE_std = ', np.std(SE)
    print 'SP_mean = ', np.mean(SP)
    print 'SP_std = ', np.std(SP)
    
    return acc, SE, SP

# normalize

feature = comb.column_names()[60:90] 

acc,SE,SP = lz_logistic(comb, feature)

# %%
# exploring the data
num_wm = len(comb[comb['Whisker']==1])
num_wn = len(comb[comb['Whisker']==0])
# major class classifier(naive classifier)
major_classifier = float(num_wn)/(num_wm + num_wn)
major_classifier
num_wn

# %%
train_data,test_data = comb.random_split(.8, seed=0)
# train_valid_shuffled = graphlab.toolkits.cross_validation.shuffle(train_valid, random_seed=1)
train_data = gl.toolkits.cross_validation.shuffle(train_data, random_seed=1)

# %%
folds = gl.cross_validation.KFold(comb, 5)
folds
params = dict([('target', 'Whisker'), ('features', comb.column_names()[0:90]), ('validation_set', None)])

all_feature_model = gl.cross_validation.cross_val_score(folds,
                                              gl.logistic_classifier.create,
                                              params)

# %%
# print all_feature_model.get_results()
all_feature_model.get_results()

# %%
mylist = sum([range(0,30)] + [range(60,90)],[])
mylist[0:3,5]

# %%
type(colName)

# %%
whisker_model.evaluate(test_data)

# %%
## Weight 
weight = whisker_model['coefficients'].sort('value', ascending=False)
weight['name']

# %%
##
