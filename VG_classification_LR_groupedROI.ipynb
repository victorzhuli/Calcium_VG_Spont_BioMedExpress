# %%
import graphlab as gl
import numpy as np
import pandas as pd
import os
from pylab import *
# Out:
# [INFO] graphlab.cython.cy_server: GraphLab Create v2.1 started. Logging: /tmp/graphlab_server_1492314475.log
# This non-commercial license of GraphLab Create for academic use is assigned to victor.li.zhu@rutgers.edu and will expire on October 06, 2017.

# %%
# input parameters
#=================================
classifier_list = ['LR']
#=================================

window_length_list = [200]
window_step = 50
feature_type_list = [1, 2, 3] #1: prefrontal ROI, #2: Back ROIs, #3: all ROIs
l2_penalty_list = np.logspace(-2, 1.5, num=15, endpoint=True, base=10.0, dtype=None).tolist()
l1_penalty = 0.0

for mouse_id in range(1,7):

    for win_ln_idx in range(len(window_length_list)): 
        window_length = window_length_list[win_ln_idx]
        
        ##========================= load features
        # print on screen: progress
        current_progress = ("\n========================================\nLoading features: mouse%02d, window_length%03d ...\n" \
                            % (mouse_id, window_length))
        print current_progress

        # load and organize feature matrix
        comb = lz_load_feature_matrix(mouse_id, window_length, window_step)       
        
        for classifier_idx in range(len(classifier_list)):
            classifier = classifier_list[classifier_idx]

            # initiate
            AC  = [[0] * len(l2_penalty_list) for _ in range(len(feature_type_list))] 
            SE  = [[0] * len(l2_penalty_list) for _ in range(len(feature_type_list))] 
            SP  = [[0] * len(l2_penalty_list) for _ in range(len(feature_type_list))]
            AUC = [[0] * len(l2_penalty_list) for _ in range(len(feature_type_list))]

            for feature_type_idx in range(len(feature_type_list)):
                feature_type = feature_type_list[feature_type_idx]

                ##========================= classification
                for l2_penalty_idx in range(len(l2_penalty_list)):
                    l2_penalty = l2_penalty_list[l2_penalty_idx]

                    # print on screen: progress
                    current_progress = ("\n----------------------------------------\nClassifying --> classifier: %s, feature_type%03d, l2_penalty_%f ..." \
                                        % (classifier, feature_type, l2_penalty))
                    print current_progress

                    if classifier == 'LR':
                        AC[feature_type_idx][l2_penalty_idx],SE[feature_type_idx][l2_penalty_idx],SP[feature_type_idx][l2_penalty_idx],AUC[feature_type_idx][l2_penalty_idx] = \
                            lz_logistic_AC_SE_SP(comb, feature_type, l2_penalty, l1_penalty)

            ##====================== save results
            AC_saveName = ("%s_vg_mouse%02d_window_length%03d_AC.csv" \
                           % (classifier,mouse_id,window_length))
            SE_saveName = ("%s_vg_mouse%02d_window_length%03d_SE.csv" \
                           % (classifier,mouse_id,window_length))
            SP_saveName = ("%s_vg_mouse%02d_window_length%03d_SP.csv" \
                           % (classifier,mouse_id,window_length))
            AUC_saveName = ("%s_vg_mouse%02d_window_length%03d_AUC.csv" \
                           % (classifier,mouse_id,window_length))
            df_AC = pd.DataFrame(AC)
            df_SE = pd.DataFrame(SE)        
            df_SP = pd.DataFrame(SP)  
            df_AUC = pd.DataFrame(AUC)  
            
            os.chdir("/Users/lizhu/Dropbox/projects/calcium/comparison/ROI4FluoroSNNAP/classification_results") 
            df_AC.to_csv(AC_saveName, index = False, header = False)
            df_SE.to_csv(SE_saveName, index = False, header = False)
            df_SP.to_csv(SP_saveName, index = False, header = False)
            df_AUC.to_csv(AUC_saveName, index = False, header = False)
# Out:
# ========================================
# Loading features: mouse01, window_length200 ...
#
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.010000 ...
# AC_mean =  0.883435408062
# AC_std =  0.0331792292146
# SE_mean =  0.651581247823
# SE_std =  0.117619097111
# SP_mean =  0.941135937884
# SP_std =  0.025842352369
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.017783 ...
# AC_mean =  0.883428286569
# AC_std =  0.0267684480946
# SE_mean =  0.655995326498
# SE_std =  0.108688799413
# SP_mean =  0.940204430336
# SP_std =  0.0231207250633
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.031623 ...
# AC_mean =  0.885956416465
# AC_std =  0.0247011762838
# SE_mean =  0.66378753429
# SE_std =  0.108155942645
# SP_mean =  0.941268260124
# SP_std =  0.0236390517256
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.056234 ...
# AC_mean =  0.885101837345
# AC_std =  0.0258531998516
# SE_mean =  0.662169576374
# SE_std =  0.109081899107
# SP_mean =  0.942431050821
# SP_std =  0.0233518539548
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.100000 ...
# AC_mean =  0.880885913688
# AC_std =  0.0285220395491
# SE_mean =  0.651180398885
# SE_std =  0.115390225325
# SP_mean =  0.940324863897
# SP_std =  0.0237233999188
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.177828 ...
# AC_mean =  0.875786924939
# AC_std =  0.0378347660772
# SE_mean =  0.625399395575
# SE_std =  0.147294459082
# SP_mean =  0.94045672676
# SP_std =  0.0251341492778
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.316228 ...
# AC_mean =  0.870716422162
# AC_std =  0.031867978658
# SE_mean =  0.598123762001
# SE_std =  0.119641567666
# SP_mean =  0.941498852803
# SP_std =  0.0225023093284
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.562341 ...
# AC_mean =  0.859749323458
# AC_std =  0.0372187384697
# SE_mean =  0.547047678664
# SE_std =  0.133522045902
# SP_mean =  0.940588358529
# SP_std =  0.0255970198118
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_1.000000 ...
# AC_mean =  0.849615439396
# AC_std =  0.0380524890735
# SE_mean =  0.519726590545
# SE_std =  0.131833968721
# SP_mean =  0.936410267573
# SP_std =  0.02699148657
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_1.778279 ...
# AC_mean =  0.847913402649
# AC_std =  0.0388680761745
# SE_mean =  0.494747111797
# SE_std =  0.141356541092
# SP_mean =  0.940479349257
# SP_std =  0.0259862922077
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_3.162278 ...
# AC_mean =  0.845385272753
# AC_std =  0.0375682255137
# SE_mean =  0.476321419842
# SE_std =  0.139399793045
# SP_mean =  0.941675041907
# SP_std =  0.0274490679518
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_5.623413 ...
# AC_mean =  0.839445947871
# AC_std =  0.0395042395834
# SE_mean =  0.432595846609
# SE_std =  0.144349842678
# SP_mean =  0.944680293803
# SP_std =  0.026109293763
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_10.000000 ...
# AC_mean =  0.82763139154
# AC_std =  0.0387815096692
# SE_mean =  0.353157743365
# SE_std =  0.0996383214073
# SP_mean =  0.949889538675
# SP_std =  0.0288437017925
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_17.782794 ...
# AC_mean =  0.814962256089
# AC_std =  0.0465136743004
# SE_mean =  0.251769854613
# SE_std =  0.105026107621
# SP_mean =  0.961460544673
# SP_std =  0.0239264696986
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_31.622777 ...
# AC_mean =  0.802321606609
# AC_std =  0.0504982006848
# SE_mean =  0.0648806193806
# SE_std =  0.0566449527029
# SP_mean =  0.989581962419
# SP_std =  0.0123076810348
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.010000 ...
# AC_mean =  0.870766272611
# AC_std =  0.0283535780075
# SE_mean =  0.532312495263
# SE_std =  0.0884500853666
# SP_mean =  0.957004989339
# SP_std =  0.0190495165577
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.017783 ...
# AC_mean =  0.867390685088
# AC_std =  0.0273161828119
# SE_mean =  0.515691616142
# SE_std =  0.0768355442023
# SP_mean =  0.955974061504
# SP_std =  0.0192048134712
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.031623 ...
# AC_mean =  0.863160518445
# AC_std =  0.0300104170809
# SE_mean =  0.496064951247
# SE_std =  0.0892673430445
# SP_mean =  0.955842198641
# SP_std =  0.0181424285122
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.056234 ...
# AC_mean =  0.860611024071
# AC_std =  0.0304216138379
# SE_mean =  0.477233782415
# SE_std =  0.104149206548
# SP_mean =  0.956873126476
# SP_std =  0.0185670422834
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.100000 ...
# AC_mean =  0.859770687936
# AC_std =  0.0310712846882
# SE_mean =  0.465778113191
# SE_std =  0.106843538751
# SP_mean =  0.958984371383
# SP_std =  0.0185878694134
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.177828 ...
# AC_mean =  0.855533399801
# AC_std =  0.0340167875724
# SE_mean =  0.443647224472
# SE_std =  0.0969325058178
# SP_mean =  0.959807102955
# SP_std =  0.0172868957746
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.316228 ...
# AC_mean =  0.851274747187
# AC_std =  0.0351624693729
# SE_mean =  0.403516230572
# SE_std =  0.120042030911
# SP_mean =  0.96409557911
# SP_std =  0.0213348260681
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.562341 ...
# AC_mean =  0.839438826378
# AC_std =  0.0458201973827
# SE_mean =  0.334857558469
# SE_std =  0.1186327341
# SP_mean =  0.968296523657
# SP_std =  0.0179929370915
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_1.000000 ...
# AC_mean =  0.836105967811
# AC_std =  0.0430935190763
# SE_mean =  0.281735555578
# SE_std =  0.09346363579
# SP_mean =  0.978058480644
# SP_std =  0.0126885102203
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_1.778279 ...
# AC_mean =  0.832716137302
# AC_std =  0.0508043313673
# SE_mean =  0.240309398615
# SE_std =  0.0964382644708
# SP_mean =  0.984112625221
# SP_std =  0.0118502087235
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_3.162278 ...
# AC_mean =  0.821749038598
# AC_std =  0.0500361669626
# SE_mean =  0.164876691936
# SE_std =  0.102814374539
# SP_mean =  0.989486634907
# SP_std =  0.010168678948
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_5.623413 ...
# AC_mean =  0.814997863552
# AC_std =  0.0519480434601
# SE_mean =  0.106583034612
# SE_std =  0.0781711003086
# SP_mean =  0.995782568169
# SP_std =  0.00519557727049
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_10.000000 ...
# AC_mean =  0.807413473864
# AC_std =  0.0490731518249
# SE_mean =  0.044832618362
# SE_std =  0.0554698838109
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_17.782794 ...
# AC_mean =  0.800648055833
# AC_std =  0.047535406618
# SE_mean =  0.00757575757576
# SE_std =  0.0155256829787
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_31.622777 ...
# AC_mean =  0.798967383564
# AC_std =  0.0484701728778
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.010000 ...
# AC_mean =  0.893547927646
# AC_std =  0.0320230775778
# SE_mean =  0.686157357987
# SE_std =  0.0873504655114
# SP_mean =  0.946449848475
# SP_std =  0.0202465772587
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.017783 ...
# AC_mean =  0.893562170631
# AC_std =  0.0306189436358
# SE_mean =  0.693473049542
# SE_std =  0.0749984540886
# SP_mean =  0.944509116836
# SP_std =  0.0232778875645
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.031623 ...
# AC_mean =  0.896090300527
# AC_std =  0.0296314082225
# SE_mean =  0.696136151146
# SE_std =  0.0801559951067
# SP_mean =  0.94771134503
# SP_std =  0.0225764442887
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.056234 ...
# AC_mean =  0.896090300527
# AC_std =  0.0296070599679
# SE_mean =  0.694710126191
# SE_std =  0.0916841425172
# SP_mean =  0.948709370912
# SP_std =  0.0194315116977
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.100000 ...
# AC_mean =  0.890172340122
# AC_std =  0.0307890024505
# SE_mean =  0.677913229567
# SE_std =  0.0935281453664
# SP_mean =  0.946702144899
# SP_std =  0.0212863930787
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.177828 ...
# AC_mean =  0.887651331719
# AC_std =  0.0350798280813
# SE_mean =  0.667685956839
# SE_std =  0.105973302415
# SP_mean =  0.946844282204
# SP_std =  0.0240711035217
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.316228 ...
# AC_mean =  0.888477424868
# AC_std =  0.0323095929884
# SE_mean =  0.664636832051
# SE_std =  0.095793453958
# SP_mean =  0.947754545384
# SP_std =  0.0206837431758
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.562341 ...
# AC_mean =  0.890143854152
# AC_std =  0.0317801379738
# SE_mean =  0.66188462603
# SE_std =  0.111749524767
# SP_mean =  0.949959002749
# SP_std =  0.0209701002708
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_1.000000 ...
# AC_mean =  0.895207235437
# AC_std =  0.0316049926889
# SE_mean =  0.667856105531
# SE_std =  0.108102086634
# SP_mean =  0.954170221737
# SP_std =  0.0200113776735
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_1.778279 ...
# AC_mean =  0.889317761003
# AC_std =  0.0267555114419
# SE_mean =  0.640399013604
# SE_std =  0.077314522377
# SP_mean =  0.953012647499
# SP_std =  0.0212081270474
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_3.162278 ...
# AC_mean =  0.88594217348
# AC_std =  0.0324557479086
# SE_mean =  0.624880297026
# SE_std =  0.0863936966913
# SP_mean =  0.953956043725
# SP_std =  0.0201010092407
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_5.623413 ...
# AC_mean =  0.882559464464
# AC_std =  0.0320935651177
# SE_mean =  0.598573270719
# SE_std =  0.0950271798037
# SP_mean =  0.955118834423
# SP_std =  0.0210279183002
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_10.000000 ...
# AC_mean =  0.874099131178
# AC_std =  0.0353557037677
# SE_mean =  0.547399042986
# SE_std =  0.111689599929
# SP_mean =  0.957345454908
# SP_std =  0.0237185090993
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_17.782794 ...
# AC_mean =  0.864826947728
# AC_std =  0.0332991044133
# SE_mean =  0.463693283273
# SE_std =  0.1041372961
# SP_mean =  0.96679406865
# SP_std =  0.0216705008211
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_31.622777 ...
# AC_mean =  0.852186298248
# AC_std =  0.0372419505785
# SE_mean =  0.3640770883
# SE_std =  0.102573888158
# SP_mean =  0.976303984268
# SP_std =  0.0142930121128
#
# ========================================
# Loading features: mouse02, window_length200 ...
#
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.010000 ...
# AC_mean =  0.902372234935
# AC_std =  0.0163373284179
# SE_mean =  0.866525821004
# SE_std =  0.0426403304017
# SP_mean =  0.920712487714
# SP_std =  0.0157708720964
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.017783 ...
# AC_mean =  0.899755911518
# AC_std =  0.0182895228936
# SE_mean =  0.866228201956
# SE_std =  0.0399727744667
# SP_mean =  0.916544190258
# SP_std =  0.0178962157111
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.031623 ...
# AC_mean =  0.906742944317
# AC_std =  0.0185679042455
# SE_mean =  0.879431115235
# SE_std =  0.0371517177919
# SP_mean =  0.92056657897
# SP_std =  0.0203922440448
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.056234 ...
# AC_mean =  0.9058733791
# AC_std =  0.0176172972969
# SE_mean =  0.874490639045
# SE_std =  0.0382548873946
# SP_mean =  0.92181657897
# SP_std =  0.0209997540403
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.100000 ...
# AC_mean =  0.904996186117
# AC_std =  0.0156448882965
# SE_mean =  0.874490639045
# SE_std =  0.0382548873946
# SP_mean =  0.920820818927
# SP_std =  0.021683352947
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.177828 ...
# AC_mean =  0.9023798627
# AC_std =  0.0153151694654
# SE_mean =  0.869282305711
# SE_std =  0.0356124053317
# SP_mean =  0.91961599965
# SP_std =  0.0235313620796
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.316228 ...
# AC_mean =  0.896285278413
# AC_std =  0.0150806162464
# SE_mean =  0.861554131108
# SE_std =  0.04035915041
# SP_mean =  0.914284087127
# SP_std =  0.019713921041
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.562341 ...
# AC_mean =  0.897162471396
# AC_std =  0.0157254401208
# SE_mean =  0.861554131108
# SE_std =  0.04035915041
# SP_mean =  0.915533271733
# SP_std =  0.02268905215
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_1.000000 ...
# AC_mean =  0.892784134249
# AC_std =  0.0177338303536
# SE_mean =  0.860353734283
# SE_std =  0.0389474907524
# SP_mean =  0.909222117134
# SP_std =  0.0261643028949
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_1.778279 ...
# AC_mean =  0.892776506484
# AC_std =  0.0139714360208
# SE_mean =  0.86252635333
# SE_std =  0.0329481503663
# SP_mean =  0.907729579821
# SP_std =  0.0238180825794
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_3.162278 ...
# AC_mean =  0.890160183066
# AC_std =  0.0135132914106
# SE_mean =  0.85821232894
# SE_std =  0.0352809001281
# SP_mean =  0.90653910363
# SP_std =  0.0248086018146
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_5.623413 ...
# AC_mean =  0.891037376049
# AC_std =  0.0134971896452
# SE_mean =  0.85821232894
# SE_std =  0.0352809001281
# SP_mean =  0.907908966644
# SP_std =  0.0234656824891
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_10.000000 ...
# AC_mean =  0.889298245614
# AC_std =  0.0149439987613
# SE_mean =  0.847765900369
# SE_std =  0.0350660247964
# SP_mean =  0.910365786179
# SP_std =  0.0232035453877
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_17.782794 ...
# AC_mean =  0.891037376049
# AC_std =  0.0134774320207
# SE_mean =  0.845326875978
# SE_std =  0.0318820872724
# SP_mean =  0.914176125383
# SP_std =  0.021137662601
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_31.622777 ...
# AC_mean =  0.888436308162
# AC_std =  0.0157383253475
# SE_mean =  0.824197375398
# SE_std =  0.0400646930768
# SP_mean =  0.920501623069
# SP_std =  0.0154208510779
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.010000 ...
# AC_mean =  0.896277650648
# AC_std =  0.0191262250583
# SE_mean =  0.862917297884
# SE_std =  0.0595294321107
# SP_mean =  0.913320178741
# SP_std =  0.022647323701
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.017783 ...
# AC_mean =  0.893661327231
# AC_std =  0.0176214729336
# SE_mean =  0.8496831709
# SE_std =  0.0569420862213
# SP_mean =  0.915925348837
# SP_std =  0.0212525647992
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.031623 ...
# AC_mean =  0.893661327231
# AC_std =  0.0176214729336
# SE_mean =  0.849415313757
# SE_std =  0.0518169943637
# SP_mean =  0.915925348837
# SP_std =  0.0212525647992
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.056234 ...
# AC_mean =  0.892791762014
# AC_std =  0.0201145842456
# SE_mean =  0.851498647091
# SE_std =  0.0506976291119
# SP_mean =  0.91347052956
# SP_std =  0.0219213646307
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.100000 ...
# AC_mean =  0.888428680397
# AC_std =  0.0214905441324
# SE_mean =  0.8553081709
# SE_std =  0.0463165833351
# SP_mean =  0.906014894888
# SP_std =  0.0249260634809
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.177828 ...
# AC_mean =  0.891029748284
# AC_std =  0.0220763703686
# SE_mean =  0.851974837567
# SE_std =  0.0441279997791
# SP_mean =  0.910355909172
# SP_std =  0.0224688552412
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.316228 ...
# AC_mean =  0.885812356979
# AC_std =  0.0249726085322
# SE_mean =  0.837361742329
# SE_std =  0.059465528021
# SP_mean =  0.909314133374
# SP_std =  0.0227952904429
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.562341 ...
# AC_mean =  0.884073226545
# AC_std =  0.0241987958453
# SE_mean =  0.823820075662
# SE_std =  0.0657197070249
# SP_mean =  0.913034111132
# SP_std =  0.0178737621512
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_1.000000 ...
# AC_mean =  0.884942791762
# AC_std =  0.0231655664551
# SE_mean =  0.822015971907
# SE_std =  0.0597370288131
# SP_mean =  0.915682194756
# SP_std =  0.0191387029427
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_1.778279 ...
# AC_mean =  0.877101449275
# AC_std =  0.0223365083124
# SE_mean =  0.801053985928
# SE_std =  0.0510550465778
# SP_mean =  0.914175314356
# SP_std =  0.0169673654241
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_3.162278 ...
# AC_mean =  0.864912280702
# AC_std =  0.0284515636918
# SE_mean =  0.768236525611
# SE_std =  0.0652049278975
# SP_mean =  0.913120845897
# SP_std =  0.0199561149942
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_5.623413 ...
# AC_mean =  0.86055682685
# AC_std =  0.0269934621662
# SE_mean =  0.743689150634
# SE_std =  0.0662604553015
# SP_mean =  0.917008678678
# SP_std =  0.0184784396868
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_10.000000 ...
# AC_mean =  0.850083905416
# AC_std =  0.0239948491058
# SE_mean =  0.706020815449
# SE_std =  0.0629383103953
# SP_mean =  0.918331360711
# SP_std =  0.0148086717932
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_17.782794 ...
# AC_mean =  0.832639206712
# AC_std =  0.0371281877848
# SE_mean =  0.633732367991
# SE_std =  0.0830798503377
# SP_mean =  0.928285193751
# SP_std =  0.0153233760477
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_31.622777 ...
# AC_mean =  0.807383676583
# AC_std =  0.0377509613906
# SE_mean =  0.51714456143
# SE_std =  0.0810371883575
# SP_mean =  0.943528745086
# SP_std =  0.0192869310085
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.010000 ...
# AC_mean =  0.910236460717
# AC_std =  0.0208422535524
# SE_mean =  0.869341124661
# SE_std =  0.0639704292945
# SP_mean =  0.932692965568
# SP_std =  0.0153414095926
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.017783 ...
# AC_mean =  0.912837528604
# AC_std =  0.0204993699096
# SE_mean =  0.873805410376
# SE_std =  0.0563749670062
# SP_mean =  0.93377992209
# SP_std =  0.0158282917922
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.031623 ...
# AC_mean =  0.911960335622
# AC_std =  0.0217476879058
# SE_mean =  0.870680410376
# SE_std =  0.0535531170409
# SP_mean =  0.933811594759
# SP_std =  0.0169841421072
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.056234 ...
# AC_mean =  0.914584286804
# AC_std =  0.0176378538661
# SE_mean =  0.88139324429
# SE_std =  0.0511611901026
# SP_mean =  0.932842500992
# SP_std =  0.013333899317
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.100000 ...
# AC_mean =  0.916323417239
# AC_std =  0.01650649065
# SE_mean =  0.883476577623
# SE_std =  0.0504290174333
# SP_mean =  0.934271072421
# SP_std =  0.0135630805452
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.177828 ...
# AC_mean =  0.913714721587
# AC_std =  0.0187374243949
# SE_mean =  0.881688275345
# SE_std =  0.0483777207662
# SP_mean =  0.930326527116
# SP_std =  0.0178314496549
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.316228 ...
# AC_mean =  0.910228832952
# AC_std =  0.0226092013334
# SE_mean =  0.879039465822
# SE_std =  0.0495638269306
# SP_mean =  0.926501844825
# SP_std =  0.0200429046727
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.562341 ...
# AC_mean =  0.90760488177
# AC_std =  0.0198334227745
# SE_mean =  0.874830528624
# SE_std =  0.041526193774
# SP_mean =  0.924379574476
# SP_std =  0.0226388325328
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_1.000000 ...
# AC_mean =  0.904996186117
# AC_std =  0.0178990752985
# SE_mean =  0.875465449259
# SE_std =  0.0391207881144
# SP_mean =  0.920432217886
# SP_std =  0.0192846716233
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_1.778279 ...
# AC_mean =  0.900648360031
# AC_std =  0.020872365501
# SE_mean =  0.867846401639
# SE_std =  0.0478198177749
# SP_mean =  0.917689680572
# SP_std =  0.0169411794203
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_3.162278 ...
# AC_mean =  0.898032036613
# AC_std =  0.0211675579408
# SE_mean =  0.859374179417
# SE_std =  0.05620447749
# SP_mean =  0.917704023659
# SP_std =  0.0150610315695
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_5.623413 ...
# AC_mean =  0.897154843631
# AC_std =  0.0188249486603
# SE_mean =  0.850503995607
# SE_std =  0.0501133102929
# SP_mean =  0.920158842936
# SP_std =  0.0152650056925
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_10.000000 ...
# AC_mean =  0.891906941266
# AC_std =  0.0205875753048
# SE_mean =  0.843573511589
# SE_std =  0.0479334512264
# SP_mean =  0.916379341368
# SP_std =  0.0174109152217
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_17.782794 ...
# AC_mean =  0.896277650648
# AC_std =  0.0220513608946
# SE_mean =  0.840804202646
# SE_std =  0.0511216680741
# SP_mean =  0.92431760885
# SP_std =  0.0207197211993
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_31.622777 ...
# AC_mean =  0.891052631579
# AC_std =  0.0205199654226
# SE_mean =  0.82198362201
# SE_std =  0.0540428949618
# SP_mean =  0.925866858687
# SP_std =  0.0198817246816
#
# ========================================
# Loading features: mouse03, window_length200 ...
#
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.010000 ...
# AC_mean =  0.855209763539
# AC_std =  0.039483404545
# SE_mean =  0.561144639931
# SE_std =  0.118320519304
# SP_mean =  0.935655190157
# SP_std =  0.0309907007105
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.017783 ...
# AC_mean =  0.852585812357
# AC_std =  0.0393681539647
# SE_mean =  0.556977973265
# SE_std =  0.119659148134
# SP_mean =  0.933409706879
# SP_std =  0.0303093799943
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.031623 ...
# AC_mean =  0.853455377574
# AC_std =  0.0380799209497
# SE_mean =  0.565812559731
# SE_std =  0.11833300837
# SP_mean =  0.932368040212
# SP_std =  0.0291890162161
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.056234 ...
# AC_mean =  0.851708619375
# AC_std =  0.0375234945639
# SE_mean =  0.569441995013
# SE_std =  0.125193154443
# SP_mean =  0.929056735677
# SP_std =  0.0294531820948
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.100000 ...
# AC_mean =  0.851723874905
# AC_std =  0.0374274223127
# SE_mean =  0.559923889431
# SE_std =  0.122139994343
# SP_mean =  0.931182269461
# SP_std =  0.0306277620375
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.177828 ...
# AC_mean =  0.8482532418
# AC_std =  0.0344243868409
# SE_mean =  0.540704233386
# SE_std =  0.116397100661
# SP_mean =  0.931271783527
# SP_std =  0.0284473931345
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.316228 ...
# AC_mean =  0.843035850496
# AC_std =  0.0290452794121
# SE_mean =  0.496715968917
# SE_std =  0.106161758876
# SP_mean =  0.935831170501
# SP_std =  0.0301552300113
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.562341 ...
# AC_mean =  0.841319603356
# AC_std =  0.0296261069487
# SE_mean =  0.45833388375
# SE_std =  0.0985549594611
# SP_mean =  0.943595767551
# SP_std =  0.0272412258828
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_1.000000 ...
# AC_mean =  0.836079328757
# AC_std =  0.0311408868714
# SE_mean =  0.423010692449
# SE_std =  0.109989441556
# SP_mean =  0.945721751933
# SP_std =  0.0273454269591
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_1.778279 ...
# AC_mean =  0.833463005339
# AC_std =  0.0303266749334
# SE_mean =  0.392499665108
# SE_std =  0.0972539668504
# SP_mean =  0.950176270997
# SP_std =  0.0248091286551
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_3.162278 ...
# AC_mean =  0.829115179252
# AC_std =  0.0199324476884
# SE_mean =  0.361272558881
# SE_std =  0.0797407689081
# SP_mean =  0.952564342118
# SP_std =  0.0202772594364
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_5.623413 ...
# AC_mean =  0.813401983219
# AC_std =  0.0274609723093
# SE_mean =  0.264507378937
# SE_std =  0.0806661683143
# SP_mean =  0.959217379414
# SP_std =  0.0194166808773
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_10.000000 ...
# AC_mean =  0.802074752098
# AC_std =  0.0274155034752
# SE_mean =  0.183213720488
# SE_std =  0.0749977877843
# SP_mean =  0.967051619602
# SP_std =  0.0184559340582
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_17.782794 ...
# AC_mean =  0.796842105263
# AC_std =  0.0293363725396
# SE_mean =  0.0557029518582
# SE_std =  0.0357112099308
# SP_mean =  0.993396369819
# SP_std =  0.00540240908396
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_31.622777 ...
# AC_mean =  0.792479023646
# AC_std =  0.0271037194762
# SE_mean =  0.00779610194903
# SE_std =  0.015721411369
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.010000 ...
# AC_mean =  0.822112890923
# AC_std =  0.0206556849925
# SE_mean =  0.347740923407
# SE_std =  0.0496740030482
# SP_mean =  0.947181198508
# SP_std =  0.0189523885832
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.017783 ...
# AC_mean =  0.82474446987
# AC_std =  0.0155258356507
# SE_mean =  0.334370960037
# SE_std =  0.056363400938
# SP_mean =  0.953961613448
# SP_std =  0.0180287170893
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.031623 ...
# AC_mean =  0.82649122807
# AC_std =  0.0164517312557
# SE_mean =  0.334370960037
# SE_std =  0.056363400938
# SP_mean =  0.95617319333
# SP_std =  0.0223379372781
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.056234 ...
# AC_mean =  0.82474446987
# AC_std =  0.0186255653894
# SE_mean =  0.314091058779
# SE_std =  0.0558925625993
# SP_mean =  0.959473404926
# SP_std =  0.0224482582598
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.100000 ...
# AC_mean =  0.819519450801
# AC_std =  0.0188368256728
# SE_mean =  0.274528575063
# SE_std =  0.0525918549107
# SP_mean =  0.963789453408
# SP_std =  0.0205761862234
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.177828 ...
# AC_mean =  0.811662852784
# AC_std =  0.0197394254271
# SE_mean =  0.23270706811
# SE_std =  0.0627045993694
# SP_mean =  0.96478383875
# SP_std =  0.0194456291882
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.316228 ...
# AC_mean =  0.815171624714
# AC_std =  0.0193850446215
# SE_mean =  0.206277844896
# SE_std =  0.0693546920597
# SP_mean =  0.97592420057
# SP_std =  0.0180791196588
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.562341 ...
# AC_mean =  0.809938977879
# AC_std =  0.020172692991
# SE_mean =  0.151022610529
# SE_std =  0.043691814528
# SP_mean =  0.984889044235
# SP_std =  0.0146236023358
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_1.000000 ...
# AC_mean =  0.803813882532
# AC_std =  0.0269390589906
# SE_mean =  0.0938002341084
# SE_std =  0.0418922882677
# SP_mean =  0.992410313823
# SP_std =  0.00977882239809
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_1.778279 ...
# AC_mean =  0.798581235698
# AC_std =  0.0252588277536
# SE_mean =  0.0501538844838
# SE_std =  0.0260713333597
# SP_mean =  0.99678442029
# SP_std =  0.00691156427867
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_3.162278 ...
# AC_mean =  0.796834477498
# AC_std =  0.0285613766596
# SE_mean =  0.0299517674971
# SE_std =  0.0202739994556
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_5.623413 ...
# AC_mean =  0.790732265446
# AC_std =  0.0280257676537
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_10.000000 ...
# AC_mean =  0.790732265446
# AC_std =  0.0280257676537
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_17.782794 ...
# AC_mean =  0.790732265446
# AC_std =  0.0280257676537
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_31.622777 ...
# AC_mean =  0.790732265446
# AC_std =  0.0280257676537
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.010000 ...
# AC_mean =  0.885758962624
# AC_std =  0.0317630624388
# SE_mean =  0.659595158386
# SE_std =  0.0534430475754
# SP_mean =  0.945234791997
# SP_std =  0.0355238553663
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.017783 ...
# AC_mean =  0.886643783371
# AC_std =  0.0298618273582
# SE_mean =  0.651799056437
# SE_std =  0.0427355675668
# SP_mean =  0.948698844285
# SP_std =  0.0300545416419
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.031623 ...
# AC_mean =  0.887528604119
# AC_std =  0.0254928364601
# SE_mean =  0.642275246913
# SE_std =  0.0571532341038
# SP_mean =  0.952188442618
# SP_std =  0.0245854850992
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.056234 ...
# AC_mean =  0.887543859649
# AC_std =  0.0245048182465
# SE_mean =  0.630474547612
# SE_std =  0.0653761989567
# SP_mean =  0.955585143959
# SP_std =  0.0230850581048
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.100000 ...
# AC_mean =  0.885804729214
# AC_std =  0.0253943512839
# SE_mean =  0.630057372195
# SE_std =  0.0799514359901
# SP_mean =  0.953407113656
# SP_std =  0.0248557190462
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.177828 ...
# AC_mean =  0.879694889397
# AC_std =  0.0312152863012
# SE_mean =  0.614711412696
# SE_std =  0.0798678982087
# SP_mean =  0.949954154307
# SP_std =  0.0298196219744
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.316228 ...
# AC_mean =  0.881441647597
# AC_std =  0.0292722985317
# SE_mean =  0.606517432763
# SE_std =  0.0861335214676
# SP_mean =  0.954445312355
# SP_std =  0.0270647879325
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.562341 ...
# AC_mean =  0.88230358505
# AC_std =  0.0268893594971
# SE_mean =  0.601528581035
# SE_std =  0.074172041095
# SP_mean =  0.956720458939
# SP_std =  0.0282744669562
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_1.000000 ...
# AC_mean =  0.879702517162
# AC_std =  0.0293684893621
# SE_mean =  0.577780358591
# SE_std =  0.089370438243
# SP_mean =  0.958842390185
# SP_std =  0.026573431916
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_1.778279 ...
# AC_mean =  0.872715484363
# AC_std =  0.0305079336689
# SE_mean =  0.539226029099
# SE_std =  0.0914540205598
# SP_mean =  0.959971579449
# SP_std =  0.0238258108845
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_3.162278 ...
# AC_mean =  0.865736079329
# AC_std =  0.0270817630068
# SE_mean =  0.496007770749
# SE_std =  0.0726374900423
# SP_mean =  0.963234440483
# SP_std =  0.0212975798841
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_5.623413 ...
# AC_mean =  0.856147978642
# AC_std =  0.0289724056062
# SE_mean =  0.423817116145
# SE_std =  0.0842603276072
# SP_mean =  0.971006956024
# SP_std =  0.021055186578
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_10.000000 ...
# AC_mean =  0.847421815408
# AC_std =  0.0259825471794
# SE_mean =  0.356239676693
# SE_std =  0.0602581782564
# SP_mean =  0.977796472433
# SP_std =  0.014671385032
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_17.782794 ...
# AC_mean =  0.839565217391
# AC_std =  0.0300175195438
# SE_mean =  0.278869770931
# SE_std =  0.0859536934226
# SP_mean =  0.988906919504
# SP_std =  0.00717787739865
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_31.622777 ...
# AC_mean =  0.82298245614
# AC_std =  0.0272157984097
# SE_mean =  0.176014998158
# SE_std =  0.0711945951581
# SP_mean =  0.994523883891
# SP_std =  0.00732661517619
#
# ========================================
# Loading features: mouse04, window_length200 ...
#
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.010000 ...
# AC_mean =  0.836162939752
# AC_std =  0.0382219766365
# SE_mean =  0.73367938414
# SE_std =  0.0515871139256
# SP_mean =  0.892225382032
# SP_std =  0.04534439138
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.017783 ...
# AC_mean =  0.836170061245
# AC_std =  0.0408942283371
# SE_mean =  0.733862534323
# SE_std =  0.053764095802
# SP_mean =  0.892225382032
# SP_std =  0.0478144915082
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.031623 ...
# AC_mean =  0.839552770261
# AC_std =  0.0420306973724
# SE_mean =  0.733801558714
# SE_std =  0.0592979434171
# SP_mean =  0.897617022355
# SP_std =  0.0511787506477
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.056234 ...
# AC_mean =  0.839559891753
# AC_std =  0.0434916903535
# SE_mean =  0.733475471757
# SE_std =  0.0591949292012
# SP_mean =  0.897600372338
# SP_std =  0.0537548337901
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.100000 ...
# AC_mean =  0.837872097992
# AC_std =  0.0427707173788
# SE_mean =  0.721515233927
# SE_std =  0.0638815553841
# SP_mean =  0.901446526184
# SP_std =  0.0518914440053
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.177828 ...
# AC_mean =  0.838705312634
# AC_std =  0.0389443753831
# SE_mean =  0.721640312101
# SE_std =  0.0573821536061
# SP_mean =  0.902814527552
# SP_std =  0.047161597569
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.316228 ...
# AC_mean =  0.838719555619
# AC_std =  0.0350390473227
# SE_mean =  0.714262263321
# SE_std =  0.0498392258199
# SP_mean =  0.906644452901
# SP_std =  0.0442535140489
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.562341 ...
# AC_mean =  0.840393106395
# AC_std =  0.0332512978599
# SE_mean =  0.711698160757
# SE_std =  0.0502415677744
# SP_mean =  0.910560328336
# SP_std =  0.0406540713653
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_1.000000 ...
# AC_mean =  0.842914114798
# AC_std =  0.0310888646054
# SE_mean =  0.704695644303
# SE_std =  0.0527049223817
# SP_mean =  0.918397143942
# SP_std =  0.0388591041875
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_1.778279 ...
# AC_mean =  0.842066657171
# AC_std =  0.0296820029673
# SE_mean =  0.699973422081
# SE_std =  0.0494070937822
# SP_mean =  0.919662966727
# SP_std =  0.0366945022552
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_3.162278 ...
# AC_mean =  0.83952428429
# AC_std =  0.0320457864367
# SE_mean =  0.694726169333
# SE_std =  0.0483796223429
# SP_mean =  0.918397143942
# SP_std =  0.0376017491469
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_5.623413 ...
# AC_mean =  0.836974789916
# AC_std =  0.0362827268704
# SE_mean =  0.672738915395
# SE_std =  0.0580758146822
# SP_mean =  0.926122751668
# SP_std =  0.0344391792424
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_10.000000 ...
# AC_mean =  0.836113089304
# AC_std =  0.0371674249946
# SE_mean =  0.665565002351
# SE_std =  0.0622202578963
# SP_mean =  0.928739925804
# SP_std =  0.0331902341455
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_17.782794 ...
# AC_mean =  0.831042586526
# AC_std =  0.0382874951431
# SE_mean =  0.643293469862
# SE_std =  0.0674794830576
# SP_mean =  0.932709567273
# SP_std =  0.0343712100802
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_31.622777 ...
# AC_mean =  0.82765987751
# AC_std =  0.0344424865459
# SE_mean =  0.626604509036
# SE_std =  0.0625239402841
# SP_mean =  0.936641671206
# SP_std =  0.0342178403123
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.010000 ...
# AC_mean =  0.833577837915
# AC_std =  0.0322513438842
# SE_mean =  0.712905149801
# SE_std =  0.0668386273106
# SP_mean =  0.900033655185
# SP_std =  0.0347180358332
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.017783 ...
# AC_mean =  0.834418174049
# AC_std =  0.0314204816227
# SE_mean =  0.715286102182
# SE_std =  0.0672680951531
# SP_mean =  0.900033655185
# SP_std =  0.0347180358332
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.031623 ...
# AC_mean =  0.837793761572
# AC_std =  0.0310838275195
# SE_mean =  0.720008324404
# SE_std =  0.0638127187
# SP_mean =  0.902704595356
# SP_std =  0.0341928383574
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.056234 ...
# AC_mean =  0.838648340692
# AC_std =  0.0295457342162
# SE_mean =  0.721917126101
# SE_std =  0.0541757226513
# SP_mean =  0.902792407087
# SP_std =  0.0373548307686
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.100000 ...
# AC_mean =  0.838655462185
# AC_std =  0.0309273759003
# SE_mean =  0.722798768613
# SE_std =  0.0488953281466
# SP_mean =  0.902704595356
# SP_std =  0.03739565483
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.177828 ...
# AC_mean =  0.836967668423
# AC_std =  0.0330143067829
# SE_mean =  0.714917205732
# SE_std =  0.0532496630402
# SP_mean =  0.904019525152
# SP_std =  0.0354280308503
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.316228 ...
# AC_mean =  0.835272753169
# AC_std =  0.0337617860036
# SE_mean =  0.705456967902
# SE_std =  0.0560725188657
# SP_mean =  0.906600277732
# SP_std =  0.0352387364276
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.562341 ...
# AC_mean =  0.83781512605
# AC_std =  0.0325406895873
# SE_mean =  0.704923841608
# SE_std =  0.0532380271698
# SP_mean =  0.910412004438
# SP_std =  0.0348554254751
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_1.000000 ...
# AC_mean =  0.831049708019
# AC_std =  0.0365390068643
# SE_mean =  0.699989080363
# SE_std =  0.0685972951915
# SP_mean =  0.902576108757
# SP_std =  0.039785637425
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_1.778279 ...
# AC_mean =  0.825153112092
# AC_std =  0.0390960192421
# SE_mean =  0.692696254803
# SE_std =  0.0658182066635
# SP_mean =  0.897586776711
# SP_std =  0.050245162423
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_3.162278 ...
# AC_mean =  0.820944309927
# AC_std =  0.030620663706
# SE_mean =  0.681394356544
# SE_std =  0.0492220564418
# SP_mean =  0.897394410538
# SP_std =  0.0454186828331
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_5.623413 ...
# AC_mean =  0.820082609315
# AC_std =  0.0298610429081
# SE_mean =  0.674418325329
# SE_std =  0.0557751658639
# SP_mean =  0.900049122211
# SP_std =  0.0430476351681
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_10.000000 ...
# AC_mean =  0.810824668851
# AC_std =  0.0341963103195
# SE_mean =  0.647745577167
# SE_std =  0.0539956400767
# SP_mean =  0.900086370999
# SP_std =  0.044099539333
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_17.782794 ...
# AC_mean =  0.805747044581
# AC_std =  0.0316052622727
# SE_mean =  0.611199688218
# SE_std =  0.0570223405708
# SP_mean =  0.911768826238
# SP_std =  0.0452619546546
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_31.622777 ...
# AC_mean =  0.787131462755
# AC_std =  0.0313522280968
# SE_mean =  0.536664015724
# SE_std =  0.0876524469727
# SP_mean =  0.923519008651
# SP_std =  0.0444160950571
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.010000 ...
# AC_mean =  0.846261216351
# AC_std =  0.0382874229523
# SE_mean =  0.741018281251
# SE_std =  0.0675223113766
# SP_mean =  0.903917545099
# SP_std =  0.0459903377377
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.017783 ...
# AC_mean =  0.845406637231
# AC_std =  0.042929463562
# SE_mean =  0.740462725696
# SE_std =  0.0681969651526
# SP_mean =  0.902792184098
# SP_std =  0.0506224219226
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.031623 ...
# AC_mean =  0.844559179604
# AC_std =  0.0419865361135
# SE_mean =  0.740343678077
# SE_std =  0.068806131518
# SP_mean =  0.901510132816
# SP_std =  0.0499253166209
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.056234 ...
# AC_mean =  0.853026634383
# AC_std =  0.0418895109399
# SE_mean =  0.750545390143
# SE_std =  0.0625657591168
# SP_mean =  0.909225322444
# SP_std =  0.0516628881334
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.100000 ...
# AC_mean =  0.856416464891
# AC_std =  0.0363724240487
# SE_mean =  0.755365502017
# SE_std =  0.0541398705927
# SP_mean =  0.911773618031
# SP_std =  0.0520369843417
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.177828 ...
# AC_mean =  0.858104258653
# AC_std =  0.0355681487848
# SE_mean =  0.750545525246
# SE_std =  0.0524564833882
# SP_mean =  0.916853137667
# SP_std =  0.0457589523528
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.316228 ...
# AC_mean =  0.853033755875
# AC_std =  0.0394168674728
# SE_mean =  0.74114938998
# SE_std =  0.0586337615572
# SP_mean =  0.914304436368
# SP_std =  0.0471595466717
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.562341 ...
# AC_mean =  0.851324597636
# AC_std =  0.0385989507728
# SE_mean =  0.732079341671
# SE_std =  0.067997864729
# SP_mean =  0.916901838966
# SP_std =  0.0419247696151
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_1.000000 ...
# AC_mean =  0.849643925367
# AC_std =  0.0383047878789
# SE_mean =  0.729420611512
# SE_std =  0.0692249032012
# SP_mean =  0.915550487614
# SP_std =  0.0411779561795
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_1.778279 ...
# AC_mean =  0.850484261501
# AC_std =  0.0327682041459
# SE_mean =  0.721686025196
# SE_std =  0.0629779556767
# SP_mean =  0.920750275977
# SP_std =  0.036843312903
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_3.162278 ...
# AC_mean =  0.84879646774
# AC_std =  0.0345368870494
# SE_mean =  0.716866048424
# SE_std =  0.0597462676185
# SP_mean =  0.920783154491
# SP_std =  0.0409112341495
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_5.623413 ...
# AC_mean =  0.847108673978
# AC_std =  0.035333348115
# SE_mean =  0.709420993479
# SE_std =  0.0593470711575
# SP_mean =  0.92208185579
# SP_std =  0.0403088915175
#
# ----------------------------------------
# ...
# SE_std =  0.12926332287
# SP_mean =  0.937070511243
# SP_std =  0.0369595513704
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.017783 ...
# AC_mean =  0.877574419598
# AC_std =  0.0312787672736
# SE_mean =  0.613997845157
# SE_std =  0.12834060465
# SP_mean =  0.939289114587
# SP_std =  0.0343575778451
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.031623 ...
# AC_mean =  0.878414755733
# AC_std =  0.0281790733715
# SE_mean =  0.622948061608
# SE_std =  0.10494926095
# SP_mean =  0.938299015578
# SP_std =  0.0332905104606
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.056234 ...
# AC_mean =  0.878421877225
# AC_std =  0.0298685590306
# SE_mean =  0.621412832131
# SE_std =  0.108592651353
# SP_mean =  0.939309116588
# SP_std =  0.0331548896768
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.100000 ...
# AC_mean =  0.880957128614
# AC_std =  0.0347745950569
# SE_mean =  0.616743153983
# SE_std =  0.102515457576
# SP_mean =  0.94354589902
# SP_std =  0.0330042408399
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.177828 ...
# AC_mean =  0.884332716137
# AC_std =  0.0363090936003
# SE_mean =  0.622120602622
# SE_std =  0.096145400986
# SP_mean =  0.946593197478
# SP_std =  0.0311012565351
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.316228 ...
# AC_mean =  0.880942885629
# AC_std =  0.0358356001711
# SE_mean =  0.609977745479
# SE_std =  0.0937105275299
# SP_mean =  0.945437745385
# SP_std =  0.0298353084825
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.562341 ...
# AC_mean =  0.878400512747
# AC_std =  0.0368150486468
# SE_mean =  0.601406316907
# SE_std =  0.0972670206216
# SP_mean =  0.944288981567
# SP_std =  0.028531262085
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_1.000000 ...
# AC_mean =  0.877560176613
# AC_std =  0.0379637022029
# SE_mean =  0.589443279944
# SE_std =  0.117071490683
# SP_mean =  0.946336698687
# SP_std =  0.0244531888549
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_1.778279 ...
# AC_mean =  0.878400512747
# AC_std =  0.0348234474138
# SE_mean =  0.593014708516
# SE_std =  0.114811363889
# SP_mean =  0.946421868494
# SP_std =  0.0229217474683
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_3.162278 ...
# AC_mean =  0.876712718986
# AC_std =  0.0366159397066
# SE_mean =  0.573938375641
# SE_std =  0.107871704617
# SP_mean =  0.948432375667
# SP_std =  0.0252377712029
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_5.623413 ...
# AC_mean =  0.875024925224
# AC_std =  0.032346513481
# SE_mean =  0.549664414309
# SE_std =  0.113343552713
# SP_mean =  0.951685525725
# SP_std =  0.0243142632981
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_10.000000 ...
# AC_mean =  0.869142572283
# AC_std =  0.0392745542646
# SE_mean =  0.511417480084
# SE_std =  0.130760222234
# SP_mean =  0.953907747947
# SP_std =  0.0250626538645
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_17.782794 ...
# AC_mean =  0.860653753027
# AC_std =  0.0427107454192
# SE_mean =  0.423261547198
# SE_std =  0.117709131566
# SP_mean =  0.96419818068
# SP_std =  0.0263061734464
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_31.622777 ...
# AC_mean =  0.849708018801
# AC_std =  0.0404696978043
# SE_mean =  0.322583818793
# SE_std =  0.092240487978
# SP_mean =  0.974591149982
# SP_std =  0.0198464701805
#
# ========================================
# Loading features: mouse06, window_length200 ...
#
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.010000 ...
# AC_mean =  0.902043868395
# AC_std =  0.026629531322
# SE_mean =  0.491524106269
# SE_std =  0.11431444128
# SP_mean =  0.964006261675
# SP_std =  0.0179561912941
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.017783 ...
# AC_mean =  0.899508617006
# AC_std =  0.0250635964219
# SE_mean =  0.455651974015
# SE_std =  0.12407940442
# SP_mean =  0.965987236471
# SP_std =  0.0200553963501
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.031623 ...
# AC_mean =  0.896987608603
# AC_std =  0.0250935826288
# SE_mean =  0.43518628774
# SE_std =  0.109100633168
# SP_mean =  0.966016945325
# SP_std =  0.0227980918571
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.056234 ...
# AC_mean =  0.891091012676
# AC_std =  0.0300482106514
# SE_mean =  0.405878383742
# SE_std =  0.113227111527
# SP_mean =  0.964047186547
# SP_std =  0.0206658660387
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.100000 ...
# AC_mean =  0.885158809286
# AC_std =  0.0280943959718
# SE_mean =  0.348371636104
# SE_std =  0.113854033483
# SP_mean =  0.9649995675
# SP_std =  0.0203228906907
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.177828 ...
# AC_mean =  0.878386269762
# AC_std =  0.027417766182
# SE_mean =  0.324270659681
# SE_std =  0.101913225133
# SP_mean =  0.961105821594
# SP_std =  0.0215819331478
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.316228 ...
# AC_mean =  0.875003560746
# AC_std =  0.0281365443709
# SE_mean =  0.310695999047
# SE_std =  0.112837691121
# SP_mean =  0.959161141145
# SP_std =  0.0186314455161
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_0.562341 ...
# AC_mean =  0.875858139866
# AC_std =  0.0270953433356
# SE_mean =  0.315666759281
# SE_std =  0.0847408964769
# SP_mean =  0.959161141145
# SP_std =  0.0186314455161
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_1.000000 ...
# AC_mean =  0.871642216209
# AC_std =  0.0278044670767
# SE_mean =  0.281953209759
# SE_std =  0.0803629200836
# SP_mean =  0.959161141145
# SP_std =  0.0186314455161
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_1.778279 ...
# AC_mean =  0.872489673836
# AC_std =  0.0324332862199
# SE_mean =  0.301124275621
# SE_std =  0.0956719256823
# SP_mean =  0.958208760192
# SP_std =  0.0196557691826
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_3.162278 ...
# AC_mean =  0.871642216209
# AC_std =  0.0329612685453
# SE_mean =  0.283728764785
# SE_std =  0.099436443345
# SP_mean =  0.960113522097
# SP_std =  0.0189873634723
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_5.623413 ...
# AC_mean =  0.872518159806
# AC_std =  0.029581045833
# SE_mean =  0.242062098119
# SE_std =  0.0711297952688
# SP_mean =  0.966913344937
# SP_std =  0.0184555342203
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_10.000000 ...
# AC_mean =  0.86996154394
# AC_std =  0.0276222495548
# SE_mean =  0.152010730068
# SE_std =  0.0740838489478
# SP_mean =  0.976662856289
# SP_std =  0.0147757805288
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_17.782794 ...
# AC_mean =  0.86996154394
# AC_std =  0.0231684167826
# SE_mean =  0.0519103424096
# SE_std =  0.0439569453059
# SP_mean =  0.991221875535
# SP_std =  0.00926610716138
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type001, l2_penalty_31.622777 ...
# AC_mean =  0.871635094716
# AC_std =  0.0215581651395
# SE_mean =  0.00769230769231
# SE_std =  0.0230769230769
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.010000 ...
# AC_mean =  0.90120353226
# AC_std =  0.0238147453099
# SE_mean =  0.457923844302
# SE_std =  0.138543993522
# SP_mean =  0.968978223504
# SP_std =  0.0160511418252
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.017783 ...
# AC_mean =  0.896154393961
# AC_std =  0.0288686867132
# SE_mean =  0.417611666799
# SE_std =  0.156754954542
# SP_mean =  0.969930604456
# SP_std =  0.0158848720174
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.031623 ...
# AC_mean =  0.894466600199
# AC_std =  0.0303572192363
# SE_mean =  0.403647528512
# SE_std =  0.150184892806
# SP_mean =  0.969893608525
# SP_std =  0.0170494815542
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.056234 ...
# AC_mean =  0.888548639795
# AC_std =  0.0327797751
# SE_mean =  0.357474828663
# SE_std =  0.172802674886
# SP_mean =  0.969863899672
# SP_std =  0.0158815110348
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.100000 ...
# AC_mean =  0.885992023928
# AC_std =  0.0275252361482
# SE_mean =  0.306607558678
# SE_std =  0.12785431527
# SP_mean =  0.973766431559
# SP_std =  0.0122116342622
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.177828 ...
# AC_mean =  0.881776100271
# AC_std =  0.0228570284106
# SE_mean =  0.261763878966
# SE_std =  0.0917883168588
# SP_mean =  0.974813528499
# SP_std =  0.0114793176999
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.316228 ...
# AC_mean =  0.880095428002
# AC_std =  0.0265180338281
# SE_mean =  0.224870504882
# SE_std =  0.0785176524229
# SP_mean =  0.978623052309
# SP_std =  0.00856338277323
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_0.562341 ...
# AC_mean =  0.878400512747
# AC_std =  0.0282242148688
# SE_mean =  0.211915039295
# SE_std =  0.0757806823831
# SP_mean =  0.978585334251
# SP_std =  0.00967064765671
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_1.000000 ...
# AC_mean =  0.872496795328
# AC_std =  0.0266970351369
# SE_mean =  0.161534823106
# SE_std =  0.0733137946583
# SP_mean =  0.978615043105
# SP_std =  0.0115173066454
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_1.778279 ...
# AC_mean =  0.870794758581
# AC_std =  0.0225740994446
# SE_mean =  0.12456901114
# SE_std =  0.0621330603318
# SP_mean =  0.981556408058
# SP_std =  0.00931362952233
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_3.162278 ...
# AC_mean =  0.867404928073
# AC_std =  0.0192230036106
# SE_mean =  0.065745812495
# SE_std =  0.0483885925783
# SP_mean =  0.986487489401
# SP_std =  0.00889953307667
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_5.623413 ...
# AC_mean =  0.877538812135
# AC_std =  0.0203874342759
# SE_mean =  0.059495812495
# SE_std =  0.0441853035284
# SP_mean =  0.999047619048
# SP_std =  0.00285714285714
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_10.000000 ...
# AC_mean =  0.87333000997
# AC_std =  0.0202151331031
# SE_mean =  0.019205465587
# SE_std =  0.0298412362037
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_17.782794 ...
# AC_mean =  0.871635094716
# AC_std =  0.020534444682
# SE_mean =  0.00625
# SE_std =  0.01875
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type002, l2_penalty_31.622777 ...
# AC_mean =  0.870787637089
# AC_std =  0.0206401252689
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.010000 ...
# AC_mean =  0.906274035038
# AC_std =  0.0299653667754
# SE_mean =  0.551171079093
# SE_std =  0.154016501868
# SP_mean =  0.961064917247
# SP_std =  0.0197272327156
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.017783 ...
# AC_mean =  0.90628115653
# AC_std =  0.0324803777886
# SE_mean =  0.545540274139
# SE_std =  0.175249800355
# SP_mean =  0.962063833044
# SP_std =  0.0168169741608
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.031623 ...
# AC_mean =  0.906295399516
# AC_std =  0.0328834844758
# SE_mean =  0.544097966447
# SE_std =  0.169898615483
# SP_mean =  0.962044638626
# SP_std =  0.0168616663431
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.056234 ...
# AC_mean =  0.902926933485
# AC_std =  0.034710793021
# SE_mean =  0.498852239951
# SE_std =  0.149966619932
# SP_mean =  0.964929005649
# SP_std =  0.0141657769062
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.100000 ...
# AC_mean =  0.902934054978
# AC_std =  0.0342883565204
# SE_mean =  0.484963351062
# SE_std =  0.141153690266
# SP_mean =  0.966937214873
# SP_std =  0.0132988345613
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.177828 ...
# AC_mean =  0.901246261216
# AC_std =  0.0285379999493
# SE_mean =  0.473465573814
# SE_std =  0.129766097941
# SP_mean =  0.96603162216
# SP_std =  0.0117687811002
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.316228 ...
# AC_mean =  0.903788634098
# AC_std =  0.0290391383606
# SE_mean =  0.491228731709
# SE_std =  0.131783272607
# SP_mean =  0.966059633364
# SP_std =  0.0124835907792
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_0.562341 ...
# AC_mean =  0.905469306367
# AC_std =  0.0289947128895
# SE_mean =  0.503728731709
# SE_std =  0.143450258109
# SP_mean =  0.966029924511
# SP_std =  0.0131847284525
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_1.000000 ...
# AC_mean =  0.901260504202
# AC_std =  0.0304205335425
# SE_mean =  0.477013045434
# SE_std =  0.119029033851
# SP_mean =  0.965002107444
# SP_std =  0.0171766050123
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_1.778279 ...
# AC_mean =  0.894487964677
# AC_std =  0.0272934251464
# SE_mean =  0.429030390834
# SE_std =  0.0863993611461
# SP_mean =  0.964012008434
# SP_std =  0.017128147291
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_3.162278 ...
# AC_mean =  0.893626264065
# AC_std =  0.0257659905425
# SE_mean =  0.41138333201
# SE_std =  0.0820045471515
# SP_mean =  0.965992206454
# SP_std =  0.0133629077401
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_5.623413 ...
# AC_mean =  0.889396097422
# AC_std =  0.0282453419185
# SE_mean =  0.383169107724
# SE_std =  0.0938950371247
# SP_mean =  0.966012208454
# SP_std =  0.0147356300473
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_10.000000 ...
# AC_mean =  0.886860846033
# AC_std =  0.0273974855633
# SE_mean =  0.350150002646
# SE_std =  0.0968997979124
# SP_mean =  0.967992406474
# SP_std =  0.0130908149034
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_17.782794 ...
# AC_mean =  0.88263067939
# AC_std =  0.0256339006415
# SE_mean =  0.288549026223
# SE_std =  0.0826739786717
# SP_mean =  0.971886152379
# SP_std =  0.0109785011757
#
# ----------------------------------------
# Classifying --> classifier: LR, feature_type003, l2_penalty_31.622777 ...
# AC_mean =  0.876698476001
# AC_std =  0.0192878946972
# SE_mean =  0.181450775317
# SE_std =  0.0779994696608
# SP_mean =  0.980704394134
# SP_std =  0.012155857321

# %%
# load and organize feature matrix
def lz_load_feature_matrix(mouse_id, window_length, window_step):
    fileName = "format4ML_GC6f_emx_0" + str(mouse_id) + "_windowLen" + str(window_length) + "_winStep_0" + str(window_step) + "_v2_threshold_10.csv"
    loadPath = "/Users/lizhu/Dropbox/projects/calcium/format4ML/" + fileName
    comb = gl.SFrame.read_csv(loadPath, delimiter=',',header=False,verbose = False)
    colName_dg = 'degree'
    colName_dg = gl.SArray([colName_dg + repr(i+1) for i in range(30)])
    colName_cc = 'clusteringCoef'
    colName_cc = gl.SArray([colName_cc + repr(i+1) for i in range(30)])
    colName_pl = 'pathlength'
    colName_pl = gl.SArray([colName_pl + repr(i+1) for i in range(30)])
    colName = colName_dg.append(colName_cc.append(colName_pl.append(gl.SArray(['Whisker']))))
    colName = (list(colName))
    dictionary = dict(zip(comb.column_names(), colName))
    comb = comb.rename(dictionary)
    comb = gl.toolkits.cross_validation.shuffle(comb, random_seed=1)
    # comb['Whisker'].show(view = 'Categorical')
    
    return comb

# %%
# train and cross-validation
def lz_logistic_AC_SE_SP(data, feature_type, l2_penalty, l1_penalty):
    
    # clearify features

    if feature_type == 1:   
        ROI_list = [4, 5, 6, 7, 8, 11, 12, 13, 14, 15]

    elif feature_type == 2: 
        ROI_list = [1, 2, 16, 17, 18, 23, 24, 25, 26, 28]
        
    elif feature_type == 3: 
        ROI_list = range(0,30)
                
    ROI_dg = [x - 1 for x in ROI_list]
    ROI_cc = [x + 30 for x in ROI_dg]
    ROI_pl = [x + 60 for x in ROI_dg]
    
    feature_spk = list(comb.column_names()[i] for i in ROI_dg + ROI_cc + ROI_pl)
    
    feature = feature_spk

    # Kfold
    num_fold = 10
    folds = gl.cross_validation.KFold(comb, num_fold)
    SE = [None] * num_fold
    SP = [None] * num_fold
    AC = [None] * num_fold
    AUC = [None] * num_fold
    
    # print specificity
    idx = 0
    for train, valid in folds:
        m = gl.logistic_classifier.create(train,
                                          target='Whisker',
                                          features=feature,
                                          l2_penalty = l2_penalty, 
                                          l1_penalty = l1_penalty,
                                          validation_set=None,
                                          verbose = False)
        results = m.evaluate(valid)
        confusion_matrix = results['confusion_matrix']

        AUC[idx] = results['auc']
                    
        TP, TN, FP, FN = lz_extract_ACC_SE_SP(confusion_matrix)
        SP[idx] = float(TN) / (TN + FP)
        SE[idx] = float(TP) / (TP + FN)
        AC[idx] = float(TP+TN) / (TP+TN+FP+FN)
        
        idx = idx + 1
        
    AC_mn = np.mean(AC)
    AC_sd = np.std(AC)
    SE_mn = np.mean(SE)
    SE_sd = np.std(SE)
    SP_mn = np.mean(SP)
    SP_sd = np.std(SP)
    AUC_mn = np.mean(AUC)
    AUC_sd = np.std(AUC)
    
    print 'AC_mean = ', AC_mn
    print 'AC_std = ',  AC_sd
    print 'SE_mean = ', SE_mn
    print 'SE_std = ',  SE_sd
    print 'SP_mean = ', SP_mn
    print 'SP_std = ',  SP_sd
    
    return AC_mn, SE_mn, SP_mn, AUC_mn

# %%
def lz_extract_ACC_SE_SP(confusion_matrix):
    TP = confusion_matrix[(confusion_matrix['target_label']==1) & (confusion_matrix['predicted_label']==1)]
    if np.size(TP) == 0:
        TP = 0
    else:
        TP = TP['count'][0]
    TN = confusion_matrix[(confusion_matrix['target_label']==0) & (confusion_matrix['predicted_label']==0)]
    if np.size(TN) == 0:
        TN = 0
    else:
        TN = TN['count'][0]
    FP = confusion_matrix[(confusion_matrix['target_label']==0) & (confusion_matrix['predicted_label']==1)]
    if np.size(FP) == 0:
        FP = 0
    else:
        FP = FP['count'][0]
    FN = confusion_matrix[(confusion_matrix['target_label']==1) & (confusion_matrix['predicted_label']==0)]
    if np.size(FN) == 0:
        FN = 0
    else:
        FN = FN['count'][0]
    
    return TP, TN, FP, FN
