# %%
import graphlab as gl
import numpy as np
import pandas as pd
import os
from pylab import *
# Out:
# This non-commercial license of GraphLab Create for academic use is assigned to victor.li.zhu@rutgers.edu and will expire on October 06, 2017.
# [INFO] graphlab.cython.cy_server: GraphLab Create v2.1 started. Logging: /tmp/graphlab_server_1489551298.log

# %%
import threading
threading.activeCount()

from ipyparallel import Client
rc = Client()

rc.ids
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %%
# input parameters
#=================================
classifier_list = ['RF']
#=================================

window_length_list  = [100, 150, 200, 250, 300]
window_step = 50
feature_type_list   = [1, 2, 3, 12, 13, 23, 123]  # 1: dg, 2: cc, 3: pl, 12: dg+cc, 13: dg+pl, 23: cc+pl, 123: dg+cc+pl
row_subSamp_list    = [0.4, 0.7, 1] 
col_subSamp_list    = [0.4, 0.7, 1]
subSample_type_list = [11, 12, 13, 21, 22, 23, 31, 32, 33]  

for mouse_id in range(1,7):

    for win_ln_idx in range(len(window_length_list)): # NOTE HERE!!!!! REMOVE "1" AFTER THIS SESSION!!!!!!!!!!!!!
        window_length = window_length_list[win_ln_idx]
        
        ##========================= load features
        # print on screen: progress
        current_progress = ("\n========================================\nLoading features: mouse%02d, window_length%03d ...\n" \
                            % (mouse_id, window_length))
        print current_progress

        # load and organize feature matrix
        comb = lz_load_feature_matrix(mouse_id, window_length, window_step)       
        
        for classifier_idx in range(len(classifier_list)):
            classifier = classifier_list[classifier_idx]

            # initiate
            AC = [[0] * len(subSample_type_list) for _ in range(len(feature_type_list))] 
            SE = [[0] * len(subSample_type_list) for _ in range(len(feature_type_list))] 
            SP = [[0] * len(subSample_type_list) for _ in range(len(feature_type_list))] 
            
            for feature_type_idx in range(len(feature_type_list)):
                feature_type = feature_type_list[feature_type_idx]             

                ##========================= classification
                for subSample_idx in range(len(subSample_type_list)):
                
                    # identify row/column subsample ratio
                    number_string  = str(subSample_type_list[subSample_idx])
                    row_subSamp    = row_subSamp_list[int(number_string[0]) -1 ]
                    col_subSamp    = col_subSamp_list[int(number_string[1]) -1 ]   

                    # print on screen: progress
                    current_progress = ("\n----------------------------------------\nClassifying --> classifier: %s, feature_type%03d, row_subsampling%f, column_subsampling%f ..." \
                                        % (classifier, feature_type, row_subSamp, col_subSamp))
                    print current_progress

                    if classifier == 'LR':
                        AC[feature_type_idx][l2_penalty_idx],SE[feature_type_idx][l2_penalty_idx],SP[feature_type_idx][l2_penalty_idx] = \
                            lz_logistic_AC_SE_SP(comb, feature_type, l2_penalty, l1_penalty)
                    if classifier == 'SVM':
                        AC[feature_type_idx][l2_penalty_idx],SE[feature_type_idx][l2_penalty_idx],SP[feature_type_idx][l2_penalty_idx] = \
                            lz_svm_AC_SE_SP(comb, feature_type, l2_penalty)
                    if classifier == 'RF':
                        AC[feature_type_idx][subSample_idx],SE[feature_type_idx][subSample_idx],SP[feature_type_idx][subSample_idx] = \
                            lz_RF_AC_SE_SP(comb, feature_type, row_subSamp, col_subSamp)
                    # if classifier == 'KNN'
                        # ...

            ##====================== save results
            AC_saveName = ("%s_mouse%02d_window_length%03d_AC.csv" \
                           % (classifier,mouse_id,window_length))
            SE_saveName = ("%s_mouse%02d_window_length%03d_SE.csv" \
                           % (classifier,mouse_id,window_length))
            SP_saveName = ("%s_mo use%02d_window_length%03d_SP.csv" \
                           % (classifier,mouse_id,window_length))
            df_AC = pd.DataFrame(AC)
            df_SE = pd.DataFrame(SE)        
            df_SP = pd.DataFrame(SP)  
            
            os.chdir("/Users/lizhu/Dropbox/projects/calcium/classification_result") 
            df_AC.to_csv(AC_saveName, index = False, header = False)
            df_SE.to_csv(SE_saveName, index = False, header = False)
            df_SP.to_csv(SP_saveName, index = False, header = False)
# Out:
# ========================================
# Loading features: mouse01, window_length100 ...
#
#
# ----------------------------------------
# Classifying --> classifier: RF, feature_type001, row_subsampling0.400000, column_subsampling0.400000 ...
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0415
# Training accuracy              : 0.9145
# Validation accuracy            : None
# Training log_loss              : 0.3067
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0528
# Training accuracy              : 0.9252
# Validation accuracy            : None
# Training log_loss              : 0.3037
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0401
# Training accuracy              : 0.9181
# Validation accuracy            : None
# Training log_loss              : 0.2968
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0415
# Training accuracy              : 0.9101
# Validation accuracy            : None
# Training log_loss              : 0.309
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0418
# Training accuracy              : 0.9154
# Validation accuracy            : None
# Training log_loss              : 0.3004
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0407
# Training accuracy              : 0.9118
# Validation accuracy            : None
# Training log_loss              : 0.2985
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0429
# Training accuracy              : 0.9172
# Validation accuracy            : None
# Training log_loss              : 0.304
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0388
# Training accuracy              : 0.9029
# Validation accuracy            : None
# Training log_loss              : 0.3055
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1124
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0405
# Training accuracy              : 0.9137
# Validation accuracy            : None
# Training log_loss              : 0.3093
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1124
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0406
# Training accuracy              : 0.9093
# Validation accuracy            : None
# Training log_loss              : 0.3123
# Validation log_loss            : None
# >
# AC_mean =  0.847838709677
# AC_std =  0.0549496960382
# SE_mean =  0.507621618148
# SE_std =  0.122212419525
# SP_mean =  0.932695959317
# SP_std =  0.0316154172328
#
# ----------------------------------------
# Classifying --> classifier: RF, feature_type001, row_subsampling0.400000, column_subsampling0.700000 ...
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0445
# Training accuracy              : 0.9145
# Validation accuracy            : None
# Training log_loss              : 0.3032
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0443
# Training accuracy              : 0.9101
# Validation accuracy            : None
# Training log_loss              : 0.3023
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0438
# Training accuracy              : 0.9234
# Validation accuracy            : None
# Training log_loss              : 0.2907
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0474
# Training accuracy              : 0.9145
# Validation accuracy            : None
# Training log_loss              : 0.3021
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0423
# Training accuracy              : 0.9118
# Validation accuracy            : None
# Training log_loss              : 0.2971
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0436
# Training accuracy              : 0.911
# Validation accuracy            : None
# Training log_loss              : 0.2976
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0507
# Training accuracy              : 0.911
# Validation accuracy            : None
# Training log_loss              : 0.3032
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0414
# Training accuracy              : 0.9145
# Validation accuracy            : None
# Training log_loss              : 0.2998
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1124
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0467
# Training accuracy              : 0.9199
# Validation accuracy            : None
# Training log_loss              : 0.3024
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1124
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0426
# Training accuracy              : 0.9128
# Validation accuracy            : None
# Training log_loss              : 0.3054
# Validation log_loss            : None
# >
# AC_mean =  0.857451612903
# AC_std =  0.0514418718658
# SE_mean =  0.573381589171
# SE_std =  0.121941659921
# SP_mean =  0.929001026734
# SP_std =  0.0264255588358
#
# ----------------------------------------
# Classifying --> classifier: RF, feature_type001, row_subsampling0.400000, column_subsampling1.000000 ...
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0435
# Training accuracy              : 0.9225
# Validation accuracy            : None
# Training log_loss              : 0.2962
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0447
# Training accuracy              : 0.911
# Validation accuracy            : None
# Training log_loss              : 0.2981
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0798
# Training accuracy              : 0.9225
# Validation accuracy            : None
# Training log_loss              : 0.2904
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0485
# Training accuracy              : 0.919
# Validation accuracy            : None
# Training log_loss              : 0.3007
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0614
# Training accuracy              : 0.9154
# Validation accuracy            : None
# Training log_loss              : 0.2916
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0556
# Training accuracy              : 0.9101
# Validation accuracy            : None
# Training log_loss              : 0.2947
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0443
# Training accuracy              : 0.9101
# Validation accuracy            : None
# Training log_loss              : 0.3044
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0544
# Training accuracy              : 0.9127
# Validation accuracy            : None
# Training log_loss              : 0.2953
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1124
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0644
# Training accuracy              : 0.9173
# Validation accuracy            : None
# Training log_loss              : 0.3012
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1124
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0557
# Training accuracy              : 0.9057
# Validation accuracy            : None
# Training log_loss              : 0.3031
# Validation log_loss            : None
# >
# AC_mean =  0.855851612903
# AC_std =  0.0513255066987
# SE_mean =  0.574236929007
# SE_std =  0.119616294004
# SP_mean =  0.925686209672
# SP_std =  0.0289213045128
#
# ----------------------------------------
# Classifying --> classifier: RF, feature_type001, row_subsampling0.700000, column_subsampling0.400000 ...
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0763
# Training accuracy              : 0.9386
# Validation accuracy            : None
# Training log_loss              : 0.285
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0472
# Training accuracy              : 0.935
# Validation accuracy            : None
# Training log_loss              : 0.2884
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0468
# Training accuracy              : 0.943
# Validation accuracy            : None
# Training log_loss              : 0.2747
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0445
# Training accuracy              : 0.9448
# Validation accuracy            : None
# Training log_loss              : 0.2837
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0479
# Training accuracy              : 0.9386
# Validation accuracy            : None
# Training log_loss              : 0.2747
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0431
# Training accuracy              : 0.9377
# Validation accuracy            : None
# Training log_loss              : 0.2754
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0431
# Training accuracy              : 0.9332
# Validation accuracy            : None
# Training log_loss              : 0.2859
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0669
# Training accuracy              : 0.9457
# Validation accuracy            : None
# Training log_loss              : 0.2784
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1124
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0867
# Training accuracy              : 0.9413
# Validation accuracy            : None
# Training log_loss              : 0.2813
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1124
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0437
# Training accuracy              : 0.9422
# Validation accuracy            : None
# Training log_loss              : 0.2847
# Validation log_loss            : None
# >
# AC_mean =  0.845419354839
# AC_std =  0.0448183105141
# SE_mean =  0.527793022036
# SE_std =  0.12863004194
# SP_mean =  0.923326372936
# SP_std =  0.0242189111733
#
# ----------------------------------------
# Classifying --> classifier: RF, feature_type001, row_subsampling0.700000, column_subsampling0.700000 ...
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0459
# Training accuracy              : 0.9421
# Validation accuracy            : None
# Training log_loss              : 0.276
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.047
# Training accuracy              : 0.9412
# Validation accuracy            : None
# Training log_loss              : 0.2789
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0453
# Training accuracy              : 0.9439
# Validation accuracy            : None
# Training log_loss              : 0.2683
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0498
# Training accuracy              : 0.9457
# Validation accuracy            : None
# Training log_loss              : 0.2724
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.049
# Training accuracy              : 0.9457
# Validation accuracy            : None
# Training log_loss              : 0.2736
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0455
# Training accuracy              : 0.9305
# Validation accuracy            : None
# Training log_loss              : 0.2729
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0449
# Training accuracy              : 0.9412
# Validation accuracy            : None
# Training log_loss              : 0.2758
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0433
# Training accuracy              : 0.943
# Validation accuracy            : None
# Training log_loss              : 0.273
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1124
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0474
# Training accuracy              : 0.9333
# Validation accuracy            : None
# Training log_loss              : 0.2795
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1124
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0455
# Training accuracy              : 0.927
# Validation accuracy            : None
# Training log_loss              : 0.2826
# Validation log_loss            : None
# >
# AC_mean =  0.854232258065
# AC_std =  0.0446475498149
# SE_mean =  0.558899470413
# SE_std =  0.115515972192
# SP_mean =  0.929770640787
# SP_std =  0.0211341866956
#
# ----------------------------------------
# Classifying --> classifier: RF, feature_type001, row_subsampling0.700000, column_subsampling1.000000 ...
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0544
# Training accuracy              : 0.9448
# Validation accuracy            : None
# Training log_loss              : 0.2703
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0469
# Training accuracy              : 0.9403
# Validation accuracy            : None
# Training log_loss              : 0.2747
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0447
# Training accuracy              : 0.9386
# Validation accuracy            : None
# Training log_loss              : 0.2683
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0854
# Training accuracy              : 0.9421
# Validation accuracy            : None
# Training log_loss              : 0.2728
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0701
# Training accuracy              : 0.9359
# Validation accuracy            : None
# Training log_loss              : 0.2723
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0835
# Training accuracy              : 0.943
# Validation accuracy            : None
# Training log_loss              : 0.2685
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0465
# Training accuracy              : 0.9439
# Validation accuracy            : None
# Training log_loss              : 0.2741
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.046
# Training accuracy              : 0.9377
# Validation accuracy            : None
# Training log_loss              : 0.2704
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1124
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.058
# Training accuracy              : 0.9306
# Validation accuracy            : None
# Training log_loss              : 0.2782
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1124
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0763
# Training accuracy              : 0.9395
# Validation accuracy            : None
# Training log_loss              : 0.2728
# Validation log_loss            : None
# >
# AC_mean =  0.851838709677
# AC_std =  0.0462414533544
# SE_mean =  0.52643228482
# SE_std =  0.109001211852
# SP_mean =  0.933098072243
# SP_std =  0.0230320555035
#
# ----------------------------------------
# Classifying --> classifier: RF, feature_type001, row_subsampling1.000000, column_subsampling0.400000 ...
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0439
# Training accuracy              : 0.9555
# Validation accuracy            : None
# Training log_loss              : 0.2703
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0457
# Training accuracy              : 0.9564
# Validation accuracy            : None
# Training log_loss              : 0.2695
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0436
# Training accuracy              : 0.9581
# Validation accuracy            : None
# Training log_loss              : 0.2581
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0443
# Training accuracy              : 0.9519
# Validation accuracy            : None
# Training log_loss              : 0.2688
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0458
# Training accuracy              : 0.9475
# Validation accuracy            : None
# Training log_loss              : 0.2638
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0464
# Training accuracy              : 0.9564
# Validation accuracy            : None
# Training log_loss              : 0.2612
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0568
# Training accuracy              : 0.943
# Validation accuracy            : None
# Training log_loss              : 0.2717
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0447
# Training accuracy              : 0.9635
# Validation accuracy            : None
# Training log_loss              : 0.2654
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1124
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0445
# Training accuracy              : 0.9573
# Validation accuracy            : None
# Training log_loss              : 0.2646
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1124
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0446
# Training accuracy              : 0.9573
# Validation accuracy            : None
# Training log_loss              : 0.2664
# Validation log_loss            : None
# >
# AC_mean =  0.855025806452
# AC_std =  0.0461596419985
# SE_mean =  0.513668969919
# SE_std =  0.118948368554
# SP_mean =  0.939485969216
# SP_std =  0.0243725821349
#
# ----------------------------------------
# Classifying --> classifier: RF, feature_type001, row_subsampling1.000000, column_subsampling0.700000 ...
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0472
# Training accuracy              : 0.9466
# Validation accuracy            : None
# Training log_loss              : 0.2691
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0482
# Training accuracy              : 0.9492
# Validation accuracy            : None
# Training log_loss              : 0.2614
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0466
# Training accuracy              : 0.9528
# Validation accuracy            : None
# Training log_loss              : 0.257
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0533
# Training accuracy              : 0.951
# Validation accuracy            : None
# Training log_loss              : 0.2658
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0469
# Training accuracy              : 0.9412
# Validation accuracy            : None
# Training log_loss              : 0.2661
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0458
# Training accuracy              : 0.951
# Validation accuracy            : None
# Training log_loss              : 0.2601
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0459
# Training accuracy              : 0.9501
# Validation accuracy            : None
# Training log_loss              : 0.2654
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0552
# Training accuracy              : 0.9484
# Validation accuracy            : None
# Training log_loss              : 0.2634
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1124
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0484
# Training accuracy              : 0.9466
# Validation accuracy            : None
# Training log_loss              : 0.267
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1124
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0487
# Training accuracy              : 0.9431
# Validation accuracy            : None
# Training log_loss              : 0.2654
# Validation log_loss            : None
# >
# AC_mean =  0.854219354839
# AC_std =  0.0407933417676
# SE_mean =  0.56887007364
# SE_std =  0.0891366805847
# SP_mean =  0.925550335182
# SP_std =  0.0261781389115
#
# ----------------------------------------
# Classifying --> classifier: RF, feature_type001, row_subsampling1.000000, column_subsampling1.000000 ...
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0472
# Training accuracy              : 0.9172
# Validation accuracy            : None
# Training log_loss              : 0.2862
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0507
# Training accuracy              : 0.9332
# Validation accuracy            : None
# Training log_loss              : 0.2672
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1123
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# ...
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0429
# Training accuracy              : 0.9354
# Validation accuracy            : None
# Training log_loss              : 0.283
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1037
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0447
# Training accuracy              : 0.9325
# Validation accuracy            : None
# Training log_loss              : 0.2843
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1037
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0422
# Training accuracy              : 0.9335
# Validation accuracy            : None
# Training log_loss              : 0.2855
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1037
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0419
# Training accuracy              : 0.9402
# Validation accuracy            : None
# Training log_loss              : 0.282
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1037
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.047
# Training accuracy              : 0.9325
# Validation accuracy            : None
# Training log_loss              : 0.2813
# Validation log_loss            : None
# >
# AC_mean =  0.861956521739
# AC_std =  0.0197427210326
# SE_mean =  0.431818688587
# SE_std =  0.0804973995074
# SP_mean =  0.96753784352
# SP_std =  0.0153143440643
#
# ----------------------------------------
# Classifying --> classifier: RF, feature_type002, row_subsampling0.700000, column_subsampling0.700000 ...
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1036
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0464
# Training accuracy              : 0.9402
# Validation accuracy            : None
# Training log_loss              : 0.2644
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1036
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0456
# Training accuracy              : 0.9402
# Validation accuracy            : None
# Training log_loss              : 0.2643
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1037
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0514
# Training accuracy              : 0.9392
# Validation accuracy            : None
# Training log_loss              : 0.269
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1037
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0454
# Training accuracy              : 0.9421
# Validation accuracy            : None
# Training log_loss              : 0.2652
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1037
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0464
# Training accuracy              : 0.946
# Validation accuracy            : None
# Training log_loss              : 0.2557
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1037
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0493
# Training accuracy              : 0.9364
# Validation accuracy            : None
# Training log_loss              : 0.2702
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1037
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0443
# Training accuracy              : 0.9335
# Validation accuracy            : None
# Training log_loss              : 0.2772
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1037
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0434
# Training accuracy              : 0.9325
# Validation accuracy            : None
# Training log_loss              : 0.2741
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1037
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0454
# Training accuracy              : 0.945
# Validation accuracy            : None
# Training log_loss              : 0.2605
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1037
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0446
# Training accuracy              : 0.9421
# Validation accuracy            : None
# Training log_loss              : 0.2632
# Validation log_loss            : None
# >
# AC_mean =  0.864527736132
# AC_std =  0.0260684635205
# SE_mean =  0.449335846606
# SE_std =  0.115921431678
# SP_mean =  0.96509857993
# SP_std =  0.0173089322781
#
# ----------------------------------------
# Classifying --> classifier: RF, feature_type002, row_subsampling0.700000, column_subsampling1.000000 ...
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1036
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0477
# Training accuracy              : 0.9411
# Validation accuracy            : None
# Training log_loss              : 0.2602
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1036
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0495
# Training accuracy              : 0.945
# Validation accuracy            : None
# Training log_loss              : 0.264
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1037
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0475
# Training accuracy              : 0.9402
# Validation accuracy            : None
# Training log_loss              : 0.2573
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1037
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0473
# Training accuracy              : 0.946
# Validation accuracy            : None
# Training log_loss              : 0.2569
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1037
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0459
# Training accuracy              : 0.9441
# Validation accuracy            : None
# Training log_loss              : 0.2585
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1037
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0503
# Training accuracy              : 0.9402
# Validation accuracy            : None
# Training log_loss              : 0.2619
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1037
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0464
# Training accuracy              : 0.9392
# Validation accuracy            : None
# Training log_loss              : 0.2619
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1037
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0463
# Training accuracy              : 0.946
# Validation accuracy            : None
# Training log_loss              : 0.2653
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1037
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0484
# Training accuracy              : 0.945
# Validation accuracy            : None
# Training log_loss              : 0.2535
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1037
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0458
# Training accuracy              : 0.9402
# Validation accuracy            : None
# Training log_loss              : 0.2608
# Validation log_loss            : None
# >
# AC_mean =  0.86715892054
# AC_std =  0.0162566881704
# SE_mean =  0.487546757494
# SE_std =  0.117474376692
# SP_mean =  0.958428619456
# SP_std =  0.0202642617749
#
# ----------------------------------------
# Classifying --> classifier: RF, feature_type002, row_subsampling1.000000, column_subsampling0.400000 ...
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1036
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0442
# Training accuracy              : 0.9431
# Validation accuracy            : None
# Training log_loss              : 0.2615
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1036
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0447
# Training accuracy              : 0.9421
# Validation accuracy            : None
# Training log_loss              : 0.2627
# Validation log_loss            : None
# >
# <bound method RandomForestClassifier.show of Class                          : RandomForestClassifier
#
# Schema
# ------
# Number of examples             : 1037
# Number of feature columns      : 30
# Number of unpacked features    : 30
# Number of classes              : 2
#
# Settings
# --------
# Number of trees                : 10
# Max tree depth                 : 6
# Training time (sec)            : 0.0448
# Training accuracy              : 0.9499
# Validation accuracy            : None
# Training log_loss              : 0.2573
# Validation log_loss            : None
# >

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-991f4d234aca> in <module>()
# ----> 1 gl.random_forest_classifier.RandomForestClassifier.get_current_options()
#
# TypeError: unbound method get_current_options() must be called with RandomForestClassifier instance as first argument (got nothing instead)

# %%
# load and organize feature matrix
def lz_load_feature_matrix(mouse_id, window_length, window_step):
    fileName = "format4ML_GC6f_emx_0" + str(mouse_id) + "_windowLen" + str(window_length) + "_winStep_0" + str(window_step) + "_v2_threshold_10.csv"
    loadPath = "/Users/lizhu/Dropbox/projects/calcium/format4ML/" + fileName
    comb = gl.SFrame.read_csv(loadPath, delimiter=',',header=False,verbose = False)
    colName_dg = 'degree'
    colName_dg = gl.SArray([colName_dg + repr(i+1) for i in range(30)])
    colName_cc = 'clusteringCoef'
    colName_cc = gl.SArray([colName_cc + repr(i+1) for i in range(30)])
    colName_pl = 'pathlength'
    colName_pl = gl.SArray([colName_pl + repr(i+1) for i in range(30)])
    colName = colName_dg.append(colName_cc.append(colName_pl.append(gl.SArray(['Whisker']))))
    colName = (list(colName))
    dictionary = dict(zip(comb.column_names(), colName))
    comb = comb.rename(dictionary)
    comb = gl.toolkits.cross_validation.shuffle(comb, random_seed=1)
    # comb['Whisker'].show(view = 'Categorical')
    
    return comb

# %%
# train and cross-validation
def lz_RF_AC_SE_SP(data, feature_type, row_subSamp, col_subSamp):
    
    # clearify features
    feature_dg = comb.column_names()[0:30] # feature 1~30: degree, 31~60: clustering coefficient, 60~90: pathlength
    feature_cc = comb.column_names()[30:60]
    feature_pl = comb.column_names()[60:90]
    
    if feature_type == 1:   feature = feature_dg
    if feature_type == 2:   feature = feature_cc
    if feature_type == 3:   feature = feature_pl
    if feature_type == 12:  feature = feature_dg + feature_cc
    if feature_type == 13:  feature = feature_dg + feature_pl
    if feature_type == 23:  feature = feature_cc + feature_pl
    if feature_type == 123: feature = feature_dg + feature_cc + feature_pl
     
    # Kfold
    num_fold = 10
    folds = gl.cross_validation.KFold(comb, num_fold)
    SE = [None] * num_fold
    SP = [None] * num_fold
    AC = [None] * num_fold
    # print specificity
    idx = 0
    for train, valid in folds:
        m = gl.random_forest_classifier.create(train,
                                          target = 'Whisker',
                                          features = feature,
                                          row_subsample    = row_subSamp, 
                                          column_subsample = col_subSamp,
                                          validation_set   = None,
                                          verbose = False,
                                          random_seed = 1)
        
        
        confusion_matrix = m.evaluate(valid, 'confusion_matrix')
        confusion_matrix = confusion_matrix.values()[0]
        
        TP, TN, FP, FN = lz_extract_ACC_SE_SP(confusion_matrix)
        
        SP[idx] = float(TN) / (TN + FP)
        SE[idx] = float(TP) / (TP + FN)
        AC[idx] = float(TP+TN) / (TP+TN+FP+FN)
        idx = idx + 1
        
    AC_mn = np.mean(AC)
    AC_sd = np.std(AC)
    SE_mn = np.mean(SE)
    SE_sd = np.std(SE)
    SP_mn = np.mean(SP)
    SP_sd = np.std(SP)
    
    print 'AC_mean = ', AC_mn
    print 'AC_std = ',  AC_sd
    print 'SE_mean = ', SE_mn
    print 'SE_std = ',  SE_sd
    print 'SP_mean = ', SP_mn
    print 'SP_std = ',  SP_sd
    
    return AC_mn, SE_mn, SP_mn

# %%
def lz_extract_ACC_SE_SP(confusion_matrix):
    TP = confusion_matrix[(confusion_matrix['target_label']==1) & (confusion_matrix['predicted_label']==1)]
    if np.size(TP) == 0:
        TP = 0
    else:
        TP = TP['count'][0]
    TN = confusion_matrix[(confusion_matrix['target_label']==0) & (confusion_matrix['predicted_label']==0)]
    if np.size(TN) == 0:
        TN = 0
    else:
        TN = TN['count'][0]
    FP = confusion_matrix[(confusion_matrix['target_label']==0) & (confusion_matrix['predicted_label']==1)]
    if np.size(FP) == 0:
        FP = 0
    else:
        FP = FP['count'][0]
    FN = confusion_matrix[(confusion_matrix['target_label']==1) & (confusion_matrix['predicted_label']==0)]
    if np.size(FN) == 0:
        FN = 0
    else:
        FN = FN['count'][0]
    
    return TP, TN, FP, FN

# %%
# normalize the features
# feature_matrix is a SFrame, first 90 columns are features, last column is labels.
def normalize_features_mice(comb):
    # extract feature columns
    comb_np = comb.to_numpy()
    comb_feature = comb_np[:,0:90]
    
    # compute normed features and norms 
    norms = np.linalg.norm(comb_feature, axis=0) # gives [norm(X[:,0]), norm(X[:,1]), norm(X[:,2])]
    comb_feature_normed = comb_feature / norms
    
    # combine normalized feature vectors and the labels
    comb_normed = np.concatenate((comb_feature_normed,comb_np[:,90:91]),axis = 1)
    # convert numpy array to SFrame
    comb_normed = gl.SFrame(comb_normed)
    comb_normed = comb_normed.unpack('X1', '')
    dictionary_norm = dict(zip(comb_normed.column_names(), colName))
    comb_normed = comb_normed.rename(dictionary_norm) # this is the normed version

    return comb_normed, norms # note: norms is array, comb_normed is SFrame

# %%
############### this is the normalized version of the above code

# normalize the features
# feature_matrix is a SFrame, first 90 columns are features, last column is labels.
def normalize_features_mice(comb):
    # extract feature columns
    comb_np = comb.to_numpy()
    comb_feature = comb_np[:,0:90]
    
    # compute normed features and norms 
    norms = np.linalg.norm(comb_feature, axis=0) # gives [norm(X[:,0]), norm(X[:,1]), norm(X[:,2])]
    comb_feature_normed = comb_feature / norms
    
    # combine normalized feature vectors and the labels
    comb_normed = np.concatenate((comb_feature_normed,comb_np[:,90:91]),axis = 1)
    # convert numpy array to SFrame
    comb_normed = gl.SFrame(comb_normed)
    comb_normed = comb_normed.unpack('X1', '')
    dictionary_norm = dict(zip(comb_normed.column_names(), colName))
    comb_normed = comb_normed.rename(dictionary_norm) # this is the normed version

    return comb_normed, norms # note: norms is array, comb_normed is SFrame

# comb = gl.toolkits.cross_validation.shuffle(comb, random_seed=2)
def lz_logistic(data, feature):
    
    # normalize 
    comb, norms = normalize_features_mice(data)
    comb['Whisker'] = comb['Whisker'].astype(int)

    folds = gl.cross_validation.KFold(comb, 5)
    SE=[None]*5
    SP=[None]*5
    acc=[None]*5
    # print specificity
    idx = 0
    for train, valid in folds:
        m = gl.logistic_classifier.create(train,
                                          target='Whisker',
                                          features=feature,
                                          l2_penalty = 0.05,
                                          validation_set=None,
                                          verbose = False)
        
        # normalize the validation dataset
        valid_np = valid.to_numpy()
        valid_feature = valid_np[:,0:90]

        # use normed from features
        valid_feature_normed = valid_feature / norms

        # combine normalized feature vectors and the labels
        valid_normed = np.concatenate((valid_feature_normed,valid_np[:,90:91]),axis = 1)

        # convert numpy array to SFrame
        valid_normed = gl.SFrame(valid_normed)
        valid_normed = valid_normed.unpack('X1', '')
        dictionary_norm = dict(zip(valid_normed.column_names(), colName))
        valid_normed = valid_normed.rename(dictionary_norm) # this is the normed version
        valid_normed['Whisker'] = valid_normed['Whisker'].astype(int)

        confusion_matrix = m.evaluate(valid, 'confusion_matrix')
        confusion_matrix = confusion_matrix.values()[0]
        TP = confusion_matrix[(confusion_matrix['target_label']==1) & (confusion_matrix['predicted_label']==1)]
        if np.size(TP) == 0:
            TP = 0
        else:
            TP = TP['count'][0]
        TN = confusion_matrix[(confusion_matrix['target_label']==0) & (confusion_matrix['predicted_label']==0)]
        if np.size(TN) == 0:
            TN = 0
        else:
            TN = TN['count'][0]
        FP = confusion_matrix[(confusion_matrix['target_label']==0) & (confusion_matrix['predicted_label']==1)]
        if np.size(FP) == 0:
            FP = 0
        else:
            FP = FP['count'][0]
        FN = confusion_matrix[(confusion_matrix['target_label']==1) & (confusion_matrix['predicted_label']==0)]
        if np.size(FN) == 0:
            FN = 0
        else:
            FN = FN['count'][0]
        SE[idx] = float(TN) / (TN + FP)
        SP[idx] = float(TP) / (TP + FN)
        acc[idx] = float(TP+TN) / (TP+TN+FP+FN)
        idx = idx + 1
    
    print 'acc_mean = ', np.mean(acc)
    print 'acc_std = ', np.std(acc)
    print 'SE_mean = ', np.mean(SE)
    print 'SE_std = ', np.std(SE)
    print 'SP_mean = ', np.mean(SP)
    print 'SP_std = ', np.std(SP)
    
    return acc, SE, SP

# normalize

feature = comb.column_names()[60:90] 

acc,SE,SP = lz_logistic(comb, feature)

# %%
# exploring the data
num_wm = len(comb[comb['Whisker']==1])
num_wn = len(comb[comb['Whisker']==0])
# major class classifier(naive classifier)
major_classifier = float(num_wn)/(num_wm + num_wn)
major_classifier
num_wn

# %%
train_data,test_data = comb.random_split(.8, seed=0)
# train_valid_shuffled = graphlab.toolkits.cross_validation.shuffle(train_valid, random_seed=1)
train_data = gl.toolkits.cross_validation.shuffle(train_data, random_seed=1)

# %%
folds = gl.cross_validation.KFold(comb, 5)
folds
params = dict([('target', 'Whisker'), ('features', comb.column_names()[0:90]), ('validation_set', None)])

all_feature_model = gl.cross_validation.cross_val_score(folds,
                                              gl.logistic_classifier.create,
                                              params)

# %%
# print all_feature_model.get_results()
all_feature_model.get_results()

# %%
mylist = sum([range(0,30)] + [range(60,90)],[])
mylist[0:3,5]

# %%
type(colName)

# %%
whisker_model.evaluate(test_data)

# %%
## Weight 
weight = whisker_model['coefficients'].sort('value', ascending=False)
weight['name']

# %%
##
