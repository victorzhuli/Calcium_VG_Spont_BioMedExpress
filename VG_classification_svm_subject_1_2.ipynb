# %%
import graphlab as gl
import numpy as np
import pandas as pd
import os
from pylab import *
# Out:
# [INFO] graphlab.cython.cy_server: GraphLab Create v2.1 started. Logging: /tmp/graphlab_server_1488978455.log
# This non-commercial license of GraphLab Create for academic use is assigned to victor.li.zhu@rutgers.edu and will expire on October 06, 2017.

# %%
import threading
threading.activeCount()

from ipyparallel import Client
rc = Client()

rc.ids
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %%
# input parameters
#=================================
classifier_list = ['SVM']
#=================================

window_length_list = [100, 150, 200, 250, 300]
window_step = 50
feature_type_list = [1, 2, 3, 12, 13, 23, 123]  # 1: dg, 2: cc, 3: pl, 12: dg+cc, 13: dg+pl, 23: cc+pl, 123: dg+cc+pl
l2_penalty_list = np.logspace(-2, 1.5, num=15, endpoint=True, base=10.0, dtype=None).tolist()
l1_penalty = 0.0

for mouse_id in range(1,3):

    for win_ln_idx in range(len(window_length_list)): # NOTE HERE!!!!! REMOVE "1" AFTER THIS SESSION!!!!!!!!!!!!!
        window_length = window_length_list[win_ln_idx]
        
        ##========================= load features
        # print on screen: progress
        current_progress = ("\n========================================\nLoading features: mouse%02d, window_length%03d ...\n" \
                            % (mouse_id, window_length))
        print current_progress

        # load and organize feature matrix
        comb = lz_load_feature_matrix(mouse_id, window_length, window_step)       
        
        for classifier_idx in range(len(classifier_list)):
            classifier = classifier_list[classifier_idx]

            # initiate
            AC = [[0] * len(l2_penalty_list) for _ in range(len(feature_type_list))] 
            SE = [[0] * len(l2_penalty_list) for _ in range(len(feature_type_list))] 
            SP = [[0] * len(l2_penalty_list) for _ in range(len(feature_type_list))] 

            for feature_type_idx in range(len(feature_type_list)):
                feature_type = feature_type_list[feature_type_idx]

                ##========================= classification
                for l2_penalty_idx in range(len(l2_penalty_list)):
                    l2_penalty = l2_penalty_list[l2_penalty_idx]

                    # print on screen: progress
                    current_progress = ("\n----------------------------------------\nClassifying --> classifier: %s, feature_type%03d, l2_penalty_%f ..." \
                                        % (classifier, feature_type, l2_penalty))
                    print current_progress

                    if classifier == 'LR':
                        AC[feature_type_idx][l2_penalty_idx],SE[feature_type_idx][l2_penalty_idx],SP[feature_type_idx][l2_penalty_idx] = \
                            lz_logistic_AC_SE_SP(comb, feature_type, l2_penalty, l1_penalty)
                    if classifier == 'SVM':
                        AC[feature_type_idx][l2_penalty_idx],SE[feature_type_idx][l2_penalty_idx],SP[feature_type_idx][l2_penalty_idx] = \
                            lz_svm_AC_SE_SP(comb, feature_type, l2_penalty)
                    # if classifier == 'RF'
                        # ...
                    # if classifier == 'KNN'
                        # ...

            ##====================== save results
            AC_saveName = ("%s_mouse%02d_window_length%03d_AC.csv" \
                           % (classifier,mouse_id,window_length))
            SE_saveName = ("%s_mouse%02d_window_length%03d_SE.csv" \
                           % (classifier,mouse_id,window_length))
            SP_saveName = ("%s_mouse%02d_window_length%03d_SP.csv" \
                           % (classifier,mouse_id,window_length))
            df_AC = pd.DataFrame(AC)
            df_SE = pd.DataFrame(SE)        
            df_SP = pd.DataFrame(SP)  
            
            os.chdir("/Users/lizhu/Dropbox/projects/calcium/classification_result") 
            df_AC.to_csv(AC_saveName, index = False, header = False)
            df_SE.to_csv(SE_saveName, index = False, header = False)
            df_SP.to_csv(SP_saveName, index = False, header = False)
# Out:
# ========================================
# Loading features: mouse01, window_length100 ...
#
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type001, l2_penalty_0.010000 ...
# AC_mean =  0.802141935484
# AC_std =  0.0454832834554
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type001, l2_penalty_0.017783 ...
# AC_mean =  0.805341935484
# AC_std =  0.0463376810683
# SE_mean =  0.0174426450742
# SE_std =  0.0217944907527
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type001, l2_penalty_0.031623 ...
# AC_mean =  0.822174193548
# AC_std =  0.0555977978887
# SE_mean =  0.146820723137
# SE_std =  0.0896821539898
# SP_mean =  0.99312940728
# SP_std =  0.00996620202194
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type001, l2_penalty_0.056234 ...
# AC_mean =  0.835012903226
# AC_std =  0.0618458225334
# SE_mean =  0.342539770171
# SE_std =  0.190719434124
# SP_mean =  0.965697193901
# SP_std =  0.0306644319212
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type001, l2_penalty_0.100000 ...
# AC_mean =  0.836625806452
# AC_std =  0.0610042358776
# SE_mean =  0.436538899697
# SE_std =  0.226941532584
# SP_mean =  0.947269069465
# SP_std =  0.0383246426526
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type001, l2_penalty_0.177828 ...
# AC_mean =  0.839025806452
# AC_std =  0.0622795179484
# SE_mean =  0.500898224582
# SE_std =  0.267744530958
# SP_mean =  0.935481003084
# SP_std =  0.0421324060806
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type001, l2_penalty_0.316228 ...
# AC_mean =  0.836632258065
# AC_std =  0.0611000155832
# SE_mean =  0.534208335524
# SE_std =  0.286420648873
# SP_mean =  0.924410734033
# SP_std =  0.0472971071677
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type001, l2_penalty_0.562341 ...
# AC_mean =  0.831819354839
# AC_std =  0.0597001302906
# SE_mean =  0.544525795842
# SE_std =  0.286333037806
# SP_mean =  0.916501926401
# SP_std =  0.0513446142568
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type001, l2_penalty_1.000000 ...
# AC_mean =  0.831012903226
# AC_std =  0.0599683999339
# SE_mean =  0.554049605365
# SE_std =  0.28864401759
# SP_mean =  0.913547210183
# SP_std =  0.0529424612295
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type001, l2_penalty_1.778279 ...
# AC_mean =  0.827812903226
# AC_std =  0.0578727187134
# SE_mean =  0.554049605365
# SE_std =  0.28864401759
# SP_mean =  0.909737340807
# SP_std =  0.053730021121
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type001, l2_penalty_3.162278 ...
# AC_mean =  0.826206451613
# AC_std =  0.0568513024752
# SE_mean =  0.554049605365
# SE_std =  0.28864401759
# SP_mean =  0.907813552424
# SP_std =  0.0547475073041
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type001, l2_penalty_5.623413 ...
# AC_mean =  0.826206451613
# AC_std =  0.0568513024752
# SE_mean =  0.554049605365
# SE_std =  0.28864401759
# SP_mean =  0.907813552424
# SP_std =  0.0547475073041
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type001, l2_penalty_10.000000 ...
# AC_mean =  0.826206451613
# AC_std =  0.0568513024752
# SE_mean =  0.554049605365
# SE_std =  0.28864401759
# SP_mean =  0.907813552424
# SP_std =  0.0547475073041
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type001, l2_penalty_17.782794 ...
# AC_mean =  0.825406451613
# AC_std =  0.0564815095028
# SE_mean =  0.554049605365
# SE_std =  0.28864401759
# SP_mean =  0.906870156197
# SP_std =  0.0555028092409
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type001, l2_penalty_31.622777 ...
# AC_mean =  0.825406451613
# AC_std =  0.0564815095028
# SE_mean =  0.554049605365
# SE_std =  0.28864401759
# SP_mean =  0.906870156197
# SP_std =  0.0555028092409
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type002, l2_penalty_0.010000 ...
# AC_mean =  0.802141935484
# AC_std =  0.0454832834554
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type002, l2_penalty_0.017783 ...
# AC_mean =  0.802141935484
# AC_std =  0.0454832834554
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type002, l2_penalty_0.031623 ...
# AC_mean =  0.753341935484
# AC_std =  0.170810836826
# SE_mean =  0.1
# SE_std =  0.3
# SP_mean =  0.9
# SP_std =  0.3
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type002, l2_penalty_0.056234 ...
# AC_mean =  0.753341935484
# AC_std =  0.170810836826
# SE_mean =  0.1
# SE_std =  0.3
# SP_mean =  0.9
# SP_std =  0.3
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type002, l2_penalty_0.100000 ...
# AC_mean =  0.753341935484
# AC_std =  0.170810836826
# SE_mean =  0.1
# SE_std =  0.3
# SP_mean =  0.9
# SP_std =  0.3
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type002, l2_penalty_0.177828 ...
# AC_mean =  0.753341935484
# AC_std =  0.170810836826
# SE_mean =  0.1
# SE_std =  0.3
# SP_mean =  0.9
# SP_std =  0.3
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type002, l2_penalty_0.316228 ...
# AC_mean =  0.753341935484
# AC_std =  0.170810836826
# SE_mean =  0.1
# SE_std =  0.3
# SP_mean =  0.9
# SP_std =  0.3
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type002, l2_penalty_0.562341 ...
# AC_mean =  0.753341935484
# AC_std =  0.170810836826
# SE_mean =  0.1
# SE_std =  0.3
# SP_mean =  0.9
# SP_std =  0.3
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type002, l2_penalty_1.000000 ...
# AC_mean =  0.802141935484
# AC_std =  0.0454832834554
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type002, l2_penalty_1.778279 ...
# AC_mean =  0.802141935484
# AC_std =  0.0454832834554
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type002, l2_penalty_3.162278 ...
# AC_mean =  0.802141935484
# AC_std =  0.0454832834554
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type002, l2_penalty_5.623413 ...
# AC_mean =  0.802141935484
# AC_std =  0.0454832834554
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type002, l2_penalty_10.000000 ...
# AC_mean =  0.802141935484
# AC_std =  0.0454832834554
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type002, l2_penalty_17.782794 ...
# AC_mean =  0.802141935484
# AC_std =  0.0454832834554
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type002, l2_penalty_31.622777 ...
# AC_mean =  0.802141935484
# AC_std =  0.0454832834554
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type003, l2_penalty_0.010000 ...
# AC_mean =  0.802141935484
# AC_std =  0.0454832834554
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type003, l2_penalty_0.017783 ...
# AC_mean =  0.802141935484
# AC_std =  0.0454832834554
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type003, l2_penalty_0.031623 ...
# AC_mean =  0.802141935484
# AC_std =  0.0454832834554
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type003, l2_penalty_0.056234 ...
# AC_mean =  0.802141935484
# AC_std =  0.0454832834554
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type003, l2_penalty_0.100000 ...
# AC_mean =  0.802141935484
# AC_std =  0.0454832834554
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type003, l2_penalty_0.177828 ...
# AC_mean =  0.802141935484
# AC_std =  0.0454832834554
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type003, l2_penalty_0.316228 ...
# AC_mean =  0.802141935484
# AC_std =  0.0454832834554
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type003, l2_penalty_0.562341 ...
# AC_mean =  0.802141935484
# AC_std =  0.0454832834554
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type003, l2_penalty_1.000000 ...
# AC_mean =  0.802141935484
# AC_std =  0.0454832834554
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type003, l2_penalty_1.778279 ...
# AC_mean =  0.802141935484
# AC_std =  0.0454832834554
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type003, l2_penalty_3.162278 ...
# AC_mean =  0.802141935484
# AC_std =  0.0454832834554
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type003, l2_penalty_5.623413 ...
# AC_mean =  0.802141935484
# AC_std =  0.0454832834554
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type003, l2_penalty_10.000000 ...
# AC_mean =  0.802141935484
# AC_std =  0.0454832834554
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type003, l2_penalty_17.782794 ...
# AC_mean =  0.802141935484
# AC_std =  0.0454832834554
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type003, l2_penalty_31.622777 ...
# AC_mean =  0.802141935484
# AC_std =  0.0454832834554
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type012, l2_penalty_0.010000 ...
# AC_mean =  0.436025806452
# AC_std =  0.29877379539
# SE_mean =  0.6
# SE_std =  0.489897948557
# SP_mean =  0.4
# SP_std =  0.489897948557
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type012, l2_penalty_0.017783 ...
# AC_mean =  0.483225806452
# AC_std =  0.305085405555
# SE_mean =  0.5
# SE_std =  0.5
# SP_mean =  0.5
# SP_std =  0.5
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type012, l2_penalty_0.031623 ...
# AC_mean =  0.461058064516
# AC_std =  0.303054457008
# SE_mean =  0.5
# SE_std =  0.5
# SP_mean =  0.5
# SP_std =  0.5
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type012, l2_penalty_0.056234 ...
# AC_mean =  0.461058064516
# AC_std =  0.303054457008
# SE_mean =  0.5
# SE_std =  0.5
# SP_mean =  0.5
# SP_std =  0.5
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type012, l2_penalty_0.100000 ...
# AC_mean =  0.461058064516
# AC_std =  0.303054457008
# SE_mean =  0.5
# SE_std =  0.5
# SP_mean =  0.5
# SP_std =  0.5
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type012, l2_penalty_0.177828 ...
# AC_mean =  0.533083870968
# AC_std =  0.303212843649
# SE_mean =  0.414285714286
# SE_std =  0.480008503326
# SP_mean =  0.603921568627
# SP_std =  0.485213897113
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type012, l2_penalty_0.316228 ...
# AC_mean =  0.461058064516
# AC_std =  0.303054457008
# SE_mean =  0.5
# SE_std =  0.5
# SP_mean =  0.5
# SP_std =  0.5
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type012, l2_penalty_0.562341 ...
# AC_mean =  0.461058064516
# AC_std =  0.303054457008
# SE_mean =  0.5
# SE_std =  0.5
# SP_mean =  0.5
# SP_std =  0.5
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type012, l2_penalty_1.000000 ...
# AC_mean =  0.525574193548
# AC_std =  0.304474036457
# SE_mean =  0.4
# SE_std =  0.489897948557
# SP_mean =  0.6
# SP_std =  0.489897948557
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type012, l2_penalty_1.778279 ...
# AC_mean =  0.525574193548
# AC_std =  0.304474036457
# SE_mean =  0.4
# SE_std =  0.489897948557
# SP_mean =  0.6
# SP_std =  0.489897948557
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type012, l2_penalty_3.162278 ...
# AC_mean =  0.525574193548
# AC_std =  0.304474036457
# SE_mean =  0.4
# SE_std =  0.489897948557
# SP_mean =  0.6
# SP_std =  0.489897948557
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type012, l2_penalty_5.623413 ...
# AC_mean =  0.525574193548
# AC_std =  0.304474036457
# SE_mean =  0.4
# SE_std =  0.489897948557
# SP_mean =  0.6
# SP_std =  0.489897948557
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type012, l2_penalty_10.000000 ...
# AC_mean =  0.525574193548
# AC_std =  0.304474036457
# SE_mean =  0.4
# SE_std =  0.489897948557
# SP_mean =  0.6
# SP_std =  0.489897948557
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type012, l2_penalty_17.782794 ...
# AC_mean =  0.525574193548
# AC_std =  0.304474036457
# SE_mean =  0.4
# SE_std =  0.489897948557
# SP_mean =  0.6
# SP_std =  0.489897948557
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type012, l2_penalty_31.622777 ...
# AC_mean =  0.525574193548
# AC_std =  0.304474036457
# SE_mean =  0.4
# SE_std =  0.489897948557
# SP_mean =  0.6
# SP_std =  0.489897948557
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type013, l2_penalty_0.010000 ...
# AC_mean =  0.424025806452
# AC_std =  0.282469235955
# SE_mean =  0.6
# SE_std =  0.489897948557
# SP_mean =  0.414169085631
# SP_std =  0.478918793231
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type013, l2_penalty_0.017783 ...
# AC_mean =  0.577141935484
# AC_std =  0.263609682215
# SE_mean =  0.640058479532
# SE_std =  0.431617872537
# SP_mean =  0.576378809869
# SP_std =  0.423432562126
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type013, l2_penalty_0.031623 ...
# AC_mean =  0.626922580645
# AC_std =  0.273934860969
# SE_mean =  0.358771929825
# SE_std =  0.437937223816
# SP_mean =  0.685849056604
# SP_std =  0.449833836653
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type013, l2_penalty_0.056234 ...
# AC_mean =  0.630141935484
# AC_std =  0.276444487882
# SE_mean =  0.3
# SE_std =  0.458257569496
# SP_mean =  0.7
# SP_std =  0.458257569496
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type013, l2_penalty_0.100000 ...
# AC_mean =  0.630141935484
# AC_std =  0.276444487882
# SE_mean =  0.3
# SE_std =  0.458257569496
# SP_mean =  0.7
# SP_std =  0.458257569496
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type013, l2_penalty_0.177828 ...
# AC_mean =  0.630141935484
# AC_std =  0.276444487882
# SE_mean =  0.3
# SE_std =  0.458257569496
# SP_mean =  0.7
# SP_std =  0.458257569496
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type013, l2_penalty_0.316228 ...
# AC_mean =  0.631741935484
# AC_std =  0.277744020074
# SE_mean =  0.373684210526
# SE_std =  0.463307392141
# SP_mean =  0.688679245283
# SP_std =  0.452063029406
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type013, l2_penalty_0.562341 ...
# AC_mean =  0.560541935484
# AC_std =  0.299488150516
# SE_mean =  0.4
# SE_std =  0.489897948557
# SP_mean =  0.6
# SP_std =  0.489897948557
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type013, l2_penalty_1.000000 ...
# AC_mean =  0.560541935484
# AC_std =  0.299488150516
# SE_mean =  0.4
# SE_std =  0.489897948557
# SP_mean =  0.6
# SP_std =  0.489897948557
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type013, l2_penalty_1.778279 ...
# AC_mean =  0.560541935484
# AC_std =  0.299488150516
# SE_mean =  0.4
# SE_std =  0.489897948557
# SP_mean =  0.6
# SP_std =  0.489897948557
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type013, l2_penalty_3.162278 ...
# AC_mean =  0.560541935484
# AC_std =  0.299488150516
# SE_mean =  0.4
# SE_std =  0.489897948557
# SP_mean =  0.6
# SP_std =  0.489897948557
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type013, l2_penalty_5.623413 ...
# AC_mean =  0.560541935484
# AC_std =  0.299488150516
# SE_mean =  0.4
# SE_std =  0.489897948557
# SP_mean =  0.6
# SP_std =  0.489897948557
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type013, l2_penalty_10.000000 ...
# AC_mean =  0.560541935484
# AC_std =  0.299488150516
# SE_mean =  0.4
# SE_std =  0.489897948557
# SP_mean =  0.6
# SP_std =  0.489897948557
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type013, l2_penalty_17.782794 ...
# AC_mean =  0.560541935484
# AC_std =  0.299488150516
# SE_mean =  0.4
# SE_std =  0.489897948557
# SP_mean =  0.6
# SP_std =  0.489897948557
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type013, l2_penalty_31.622777 ...
# AC_mean =  0.560541935484
# AC_std =  0.299488150516
# SE_mean =  0.4
# SE_std =  0.489897948557
# SP_mean =  0.6
# SP_std =  0.489897948557
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type023, l2_penalty_0.010000 ...
# AC_mean =  0.197858064516
# AC_std =  0.0454832834554
# SE_mean =  1.0
# SE_std =  0.0
# SP_mean =  0.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type023, l2_penalty_0.017783 ...
# AC_mean =  0.197858064516
# AC_std =  0.0454832834554
# SE_mean =  1.0
# SE_std =  0.0
# SP_mean =  0.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type023, l2_penalty_0.031623 ...
# AC_mean =  0.337058064516
# AC_std =  0.258473217012
# SE_mean =  0.8
# SE_std =  0.4
# SP_mean =  0.2
# SP_std =  0.4
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type023, l2_penalty_0.056234 ...
# AC_mean =  0.337058064516
# AC_std =  0.258473217012
# SE_mean =  0.8
# SE_std =  0.4
# SP_mean =  0.2
# SP_std =  0.4
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type023, l2_penalty_0.100000 ...
# AC_mean =  0.337058064516
# AC_std =  0.258473217012
# SE_mean =  0.8
# SE_std =  0.4
# SP_mean =  0.2
# SP_std =  0.4
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type023, l2_penalty_0.177828 ...
# AC_mean =  0.197858064516
# AC_std =  0.0454832834554
# SE_mean =  1.0
# SE_std =  0.0
# SP_mean =  0.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type023, l2_penalty_0.316228 ...
# AC_mean =  0.197858064516
# AC_std =  0.0454832834554
# SE_mean =  1.0
# SE_std =  0.0
# SP_mean =  0.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type023, l2_penalty_0.562341 ...
# AC_mean =  0.197858064516
# AC_std =  0.0454832834554
# SE_mean =  1.0
# SE_std =  0.0
# SP_mean =  0.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type023, l2_penalty_1.000000 ...
# AC_mean =  0.197858064516
# AC_std =  0.0454832834554
# SE_mean =  1.0
# SE_std =  0.0
# SP_mean =  0.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type023, l2_penalty_1.778279 ...
# AC_mean =  0.240258064516
# AC_std =  0.160911793238
# SE_mean =  0.9
# SE_std =  0.3
# SP_mean =  0.1
# SP_std =  0.3
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type023, l2_penalty_3.162278 ...
# AC_mean =  0.240258064516
# AC_std =  0.160911793238
# SE_mean =  0.9
# SE_std =  0.3
# SP_mean =  0.1
# SP_std =  0.3
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type023, l2_penalty_5.623413 ...
# AC_mean =  0.240258064516
# AC_std =  0.160911793238
# SE_mean =  0.9
# SE_std =  0.3
# SP_mean =  0.1
# SP_std =  0.3
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type023, l2_penalty_10.000000 ...
# AC_mean =  0.240258064516
# AC_std =  0.160911793238
# SE_mean =  0.9
# SE_std =  0.3
# SP_mean =  0.1
# SP_std =  0.3
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type023, l2_penalty_17.782794 ...
# AC_mean =  0.240258064516
# AC_std =  0.160911793238
# SE_mean =  0.9
# SE_std =  0.3
# SP_mean =  0.1
# SP_std =  0.3
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type023, l2_penalty_31.622777 ...
# AC_mean =  0.240258064516
# AC_std =  0.160911793238
# SE_mean =  0.9
# SE_std =  0.3
# SP_mean =  0.1
# SP_std =  0.3
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type123, l2_penalty_0.010000 ...
# AC_mean =  0.591974193548
# AC_std =  0.291374717457
# SE_mean =  0.3
# SE_std =  0.458257569496
# SP_mean =  0.7
# SP_std =  0.458257569496
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type123, l2_penalty_0.017783 ...
# AC_mean =  0.623174193548
# AC_std =  0.283776313838
# SE_mean =  0.322527472527
# SE_std =  0.444933167439
# SP_mean =  0.69898989899
# SP_std =  0.457605858934
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type123, l2_penalty_0.031623 ...
# AC_mean =  0.597574193548
# AC_std =  0.307762497724
# SE_mean =  0.508718912666
# SE_std =  0.437593541831
# SP_mean =  0.595128782476
# SP_std =  0.485983773456
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type123, l2_penalty_0.056234 ...
# AC_mean =  0.672548387097
# AC_std =  0.267845342254
# SE_mean =  0.388886113886
# SE_std =  0.432597546468
# SP_mean =  0.700947620535
# SP_std =  0.448137921166
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type123, l2_penalty_0.100000 ...
# AC_mean =  0.779741935484
# AC_std =  0.165502047672
# SE_mean =  0.290384615385
# SE_std =  0.349180147127
# SP_mean =  0.868633457958
# SP_std =  0.294453789988
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type123, l2_penalty_0.177828 ...
# AC_mean =  0.721348387097
# AC_std =  0.225992399843
# SE_mean =  0.273776223776
# SE_std =  0.387815832399
# SP_mean =  0.793939393939
# SP_std =  0.397168839966
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type123, l2_penalty_0.316228 ...
# AC_mean =  0.714141935484
# AC_std =  0.222338727439
# SE_mean =  0.3
# SE_std =  0.403314668582
# SP_mean =  0.777777777778
# SP_std =  0.391679610204
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type123, l2_penalty_0.562341 ...
# AC_mean =  0.726161290323
# AC_std =  0.227774887957
# SE_mean =  0.433910533911
# SE_std =  0.396727491809
# SP_mean =  0.763235054297
# SP_std =  0.384937781451
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type123, l2_penalty_1.000000 ...
# AC_mean =  0.715767741935
# AC_std =  0.224184076291
# SE_mean =  0.354700854701
# SE_std =  0.414005307306
# SP_mean =  0.76774347246
# SP_std =  0.390439119065
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type123, l2_penalty_1.778279 ...
# AC_mean =  0.714935483871
# AC_std =  0.222545723768
# SE_mean =  0.319230769231
# SE_std =  0.418524457939
# SP_mean =  0.773804078521
# SP_std =  0.390704542051
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type123, l2_penalty_3.162278 ...
# AC_mean =  0.710935483871
# AC_std =  0.221018739112
# SE_mean =  0.311538461538
# SE_std =  0.413689561452
# SP_mean =  0.770773775491
# SP_std =  0.390466039253
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type123, l2_penalty_5.623413 ...
# AC_mean =  0.713348387097
# AC_std =  0.222445876825
# SE_mean =  0.295726495726
# SE_std =  0.386754733901
# SP_mean =  0.778854583572
# SP_std =  0.391571024959
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type123, l2_penalty_10.000000 ...
# AC_mean =  0.71495483871
# AC_std =  0.223235192419
# SE_mean =  0.301282051282
# SE_std =  0.384455094804
# SP_mean =  0.779864684582
# SP_std =  0.391814407198
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type123, l2_penalty_17.782794 ...
# AC_mean =  0.76375483871
# AC_std =  0.172035225684
# SE_mean =  0.290170940171
# SE_std =  0.365225636429
# SP_mean =  0.853011886942
# SP_std =  0.295476068583
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type123, l2_penalty_31.622777 ...
# AC_mean =  0.760561290323
# AC_std =  0.172706069708
# SE_mean =  0.233974358974
# SE_std =  0.311246756496
# SP_mean =  0.873350100539
# SP_std =  0.294398441831
#
# ========================================
# Loading features: mouse01, window_length150 ...
#
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type001, l2_penalty_0.010000 ...
# AC_mean =  0.800968703428
# AC_std =  0.025073862977
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type001, l2_penalty_0.017783 ...
# AC_mean =  0.810825091451
# AC_std =  0.0298377609395
# SE_mean =  0.068702008747
# SE_std =  0.068749356766
# SP_mean =  0.995897108844
# SP_std =  0.00936631904069
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type001, l2_penalty_0.031623 ...
# AC_mean =  0.844607776724
# AC_std =  0.0309501031888
# SE_mean =  0.360499274311
# SE_std =  0.144573384841
# SP_mean =  0.964839793708
# SP_std =  0.0191425106008
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type001, l2_penalty_0.056234 ...
# AC_mean =  0.849485164612
# AC_std =  0.0421414134067
# SE_mean =  0.434457302373
# SE_std =  0.150685145059
# SP_mean =  0.956099075961
# SP_std =  0.0292035114506
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type001, l2_penalty_0.100000 ...
# AC_mean =  0.843774556293
# AC_std =  0.0365517432729
# SE_mean =  0.424375482783
# SE_std =  0.259825251947
# SP_mean =  0.948244916151
# SP_std =  0.0374448619095
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type001, l2_penalty_0.177828 ...
# AC_mean =  0.845393578106
# AC_std =  0.0450989813184
# SE_mean =  0.43196111457
# SE_std =  0.267994065494
# SP_mean =  0.953172127378
# SP_std =  0.0272838121054
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type001, l2_penalty_0.316228 ...
# AC_mean =  0.842954884162
# AC_std =  0.0443430286429
# SE_mean =  0.425084931172
# SE_std =  0.237608051323
# SP_mean =  0.951077062703
# SP_std =  0.0241250723748
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type001, l2_penalty_0.562341 ...
# AC_mean =  0.85608318656
# AC_std =  0.0436627170025
# SE_mean =  0.490041222867
# SE_std =  0.214533579294
# SP_mean =  0.948847334707
# SP_std =  0.0216647074399
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type001, l2_penalty_1.000000 ...
# AC_mean =  0.847879691099
# AC_std =  0.0431299135188
# SE_mean =  0.442359134424
# SE_std =  0.22188046093
# SP_mean =  0.951982592206
# SP_std =  0.0257810333327
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type001, l2_penalty_1.778279 ...
# AC_mean =  0.853610621867
# AC_std =  0.0423471390595
# SE_mean =  0.528053114357
# SE_std =  0.23872516856
# SP_mean =  0.936327890513
# SP_std =  0.0359277622612
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type001, l2_penalty_3.162278 ...
# AC_mean =  0.858528654654
# AC_std =  0.042085664081
# SE_mean =  0.513882421926
# SE_std =  0.217314572075
# SP_mean =  0.946821982887
# SP_std =  0.0225337007894
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type001, l2_penalty_5.623413 ...
# AC_mean =  0.856062864111
# AC_std =  0.0415123837808
# SE_mean =  0.491660199704
# SE_std =  0.211848192825
# SP_mean =  0.949957240385
# SP_std =  0.0271826021944
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type001, l2_penalty_10.000000 ...
# AC_mean =  0.856056089961
# AC_std =  0.0391946063809
# SE_mean =  0.486008025791
# SE_std =  0.208267524824
# SP_mean =  0.950967941695
# SP_std =  0.0283876236003
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type001, l2_penalty_17.782794 ...
# AC_mean =  0.856875762092
# AC_std =  0.0395378500321
# SE_mean =  0.493415433198
# SE_std =  0.207974595314
# SP_mean =  0.949987549539
# SP_std =  0.0282003529128
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type001, l2_penalty_31.622777 ...
# AC_mean =  0.856875762092
# AC_std =  0.0395378500321
# SE_mean =  0.493415433198
# SE_std =  0.207974595314
# SP_mean =  0.949987549539
# SP_std =  0.0282003529128
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type002, l2_penalty_0.010000 ...
# AC_mean =  0.800968703428
# AC_std =  0.025073862977
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type002, l2_penalty_0.017783 ...
# AC_mean =  0.800968703428
# AC_std =  0.025073862977
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type002, l2_penalty_0.031623 ...
# AC_mean =  0.800968703428
# AC_std =  0.025073862977
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type002, l2_penalty_0.056234 ...
# AC_mean =  0.800968703428
# AC_std =  0.025073862977
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type002, l2_penalty_0.100000 ...
# AC_mean =  0.800968703428
# AC_std =  0.025073862977
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type002, l2_penalty_0.177828 ...
# AC_mean =  0.800968703428
# AC_std =  0.025073862977
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type002, l2_penalty_0.316228 ...
# AC_mean =  0.800968703428
# AC_std =  0.025073862977
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type002, l2_penalty_0.562341 ...
# AC_mean =  0.800968703428
# AC_std =  0.025073862977
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type002, l2_penalty_1.000000 ...
# AC_mean =  0.800968703428
# AC_std =  0.025073862977
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type002, l2_penalty_1.778279 ...
# AC_mean =  0.800968703428
# AC_std =  0.025073862977
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type002, l2_penalty_3.162278 ...
# AC_mean =  0.800968703428
# AC_std =  0.025073862977
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type002, l2_penalty_5.623413 ...
# AC_mean =  0.800968703428
# AC_std =  0.025073862977
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type002, l2_penalty_10.000000 ...
# AC_mean =  0.800968703428
# AC_std =  0.025073862977
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type002, l2_penalty_17.782794 ...
# AC_mean =  0.800968703428
# AC_std =  0.025073862977
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type002, l2_penalty_31.622777 ...
# AC_mean =  0.800968703428
# AC_std =  0.025073862977
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type003, l2_penalty_0.010000 ...
# AC_mean =  0.800968703428
# AC_std =  0.025073862977
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type003, l2_penalty_0.017783 ...
# AC_mean =  0.800968703428
# AC_std =  0.025073862977
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type003, l2_penalty_0.031623 ...
# AC_mean =  0.800968703428
# AC_std =  0.025073862977
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type003, l2_penalty_0.056234 ...
# AC_mean =  0.800968703428
# AC_std =  0.025073862977
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type003, l2_penalty_0.100000 ...
# AC_mean =  0.800968703428
# AC_std =  0.025073862977
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type003, l2_penalty_0.177828 ...
# AC_mean =  0.800968703428
# AC_std =  0.025073862977
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type003, l2_penalty_0.316228 ...
# AC_mean =  0.800968703428
# AC_std =  0.025073862977
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type003, l2_penalty_0.562341 ...
# AC_mean =  0.800968703428
# AC_std =  0.025073862977
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type003, l2_penalty_1.000000 ...
# AC_mean =  0.800968703428
# AC_std =  0.025073862977
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type003, l2_penalty_1.778279 ...
# AC_mean =  0.800968703428
# AC_std =  0.025073862977
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type003, l2_penalty_3.162278 ...
# AC_mean =  0.800968703428
# AC_std =  0.025073862977
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type003, l2_penalty_5.623413 ...
# AC_mean =  0.800968703428
# AC_std =  0.025073862977
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type003, l2_penalty_10.000000 ...
# AC_mean =  0.800968703428
# AC_std =  0.025073862977
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type003, l2_penalty_17.782794 ...
# AC_mean =  0.800968703428
# AC_std =  0.025073862977
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type003, l2_penalty_31.622777 ...
# AC_mean =  0.800968703428
# AC_std =  0.025073862977
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type012, l2_penalty_0.010000 ...
# AC_mean =  0.390563609267
# AC_std =  0.281486297057
# SE_mean =  0.7
# SE_std =  0.458257569496
# SP_mean =  0.3
# SP_std =  0.458257569496
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type012, l2_penalty_0.017783 ...
# AC_mean =  0.319963419591
# AC_std =  0.242482347321
# SE_mean =  0.8
# SE_std =  0.4
# SP_mean =  0.2
# SP_std =  0.4
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type012, l2_penalty_0.031623 ...
# AC_mean =  0.427767240211
# AC_std =  0.293246120965
# SE_mean =  0.6
# SE_std =  0.489897948557
# SP_mean =  0.4
# SP_std =  0.489897948557
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type012, l2_penalty_0.056234 ...
# AC_mean =  0.431865600867
# AC_std =  0.290259603482
# SE_mean =  0.6
# SE_std =  0.489897948557
# SP_mean =  0.405102040816
# SP_std =  0.485955393767
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type012, l2_penalty_0.100000 ...
# AC_mean =  0.368310527029
# AC_std =  0.26736422765
# SE_mean =  0.7
# SE_std =  0.458257569496
# SP_mean =  0.305050505051
# SP_std =  0.455191460136
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type012, l2_penalty_0.177828 ...
# AC_mean =  0.417931174638
# AC_std =  0.290646807915
# SE_mean =  0.6
# SE_std =  0.489897948557
# SP_mean =  0.4
# SP_std =  0.489897948557
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type012, l2_penalty_0.316228 ...
# AC_mean =  0.417931174638
# AC_std =  0.290646807915
# SE_mean =  0.6
# SE_std =  0.489897948557
# SP_mean =  0.4
# SP_std =  0.489897948557
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type012, l2_penalty_0.562341 ...
# AC_mean =  0.478586912343
# AC_std =  0.301251288337
# SE_mean =  0.5
# SE_std =  0.5
# SP_mean =  0.5
# SP_std =  0.5
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type012, l2_penalty_1.000000 ...
# AC_mean =  0.478586912343
# AC_std =  0.301251288337
# SE_mean =  0.5
# SE_std =  0.5
# SP_mean =  0.5
# SP_std =  0.5
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type012, l2_penalty_1.778279 ...
# AC_mean =  0.478586912343
# AC_std =  0.301251288337
# SE_mean =  0.5
# SE_std =  0.5
# SP_mean =  0.5
# SP_std =  0.5
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type012, l2_penalty_3.162278 ...
# AC_mean =  0.478586912343
# AC_std =  0.301251288337
# SE_mean =  0.5
# SE_std =  0.5
# SP_mean =  0.5
# SP_std =  0.5
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type012, l2_penalty_5.623413 ...
# AC_mean =  0.478586912343
# AC_std =  0.301251288337
# SE_mean =  0.5
# SE_std =  0.5
# SP_mean =  0.5
# SP_std =  0.5
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type012, l2_penalty_10.000000 ...
# AC_mean =  0.478586912343
# AC_std =  0.301251288337
# SE_mean =  0.5
# SE_std =  0.5
# SP_mean =  0.5
# SP_std =  0.5
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type012, l2_penalty_17.782794 ...
# AC_mean =  0.478586912343
# AC_std =  0.301251288337
# SE_mean =  0.5
# SE_std =  0.5
# SP_mean =  0.5
# SP_std =  0.5
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type012, l2_penalty_31.622777 ...
# AC_mean =  0.478586912343
# AC_std =  0.301251288337
# SE_mean =  0.5
# SE_std =  0.5
# SP_mean =  0.5
# SP_std =  0.5
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type013, l2_penalty_0.010000 ...
# AC_mean =  0.580348191302
# AC_std =  0.280980668452
# SE_mean =  0.4
# SE_std =  0.489897948557
# SP_mean =  0.616666666667
# SP_std =  0.471699056603
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type013, l2_penalty_0.017783 ...
# AC_mean =  0.601632570112
# AC_std =  0.255104174291
# SE_mean =  0.673913043478
# SE_std =  0.44392560558
# SP_mean =  0.568521954236
# SP_std =  0.401779096558
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type013, l2_penalty_0.031623 ...
# AC_mean =  0.646016799892
# AC_std =  0.272410519688
# SE_mean =  0.471936758893
# SE_std =  0.419554372355
# SP_mean =  0.668686868687
# SP_std =  0.439940447315
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type013, l2_penalty_0.056234 ...
# AC_mean =  0.639452648693
# AC_std =  0.267941544956
# SE_mean =  0.304545454545
# SE_std =  0.455476319567
# SP_mean =  0.69898989899
# SP_std =  0.457605858934
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type013, l2_penalty_0.100000 ...
# AC_mean =  0.578790136838
# AC_std =  0.29155269401
# SE_mean =  0.4
# SE_std =  0.489897948557
# SP_mean =  0.6
# SP_std =  0.489897948557
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type013, l2_penalty_0.177828 ...
# AC_mean =  0.639445874543
# AC_std =  0.267891222552
# SE_mean =  0.3
# SE_std =  0.458257569496
# SP_mean =  0.7
# SP_std =  0.458257569496
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type013, l2_penalty_0.316228 ...
# AC_mean =  0.639445874543
# AC_std =  0.267891222552
# SE_mean =  0.3
# SE_std =  0.458257569496
# SP_mean =  0.7
# SP_std =  0.458257569496
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type013, l2_penalty_0.562341 ...
# AC_mean =  0.639445874543
# AC_std =  0.267891222552
# SE_mean =  0.3
# SE_std =  0.458257569496
# SP_mean =  0.7
# SP_std =  0.458257569496
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type013, l2_penalty_1.000000 ...
# AC_mean =  0.639445874543
# AC_std =  0.267891222552
# SE_mean =  0.3
# SE_std =  0.458257569496
# SP_mean =  0.7
# SP_std =  0.458257569496
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type013, l2_penalty_1.778279 ...
# AC_mean =  0.639445874543
# AC_std =  0.267891222552
# SE_mean =  0.3
# SE_std =  0.458257569496
# SP_mean =  0.7
# SP_std =  0.458257569496
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type013, l2_penalty_3.162278 ...
# AC_mean =  0.639445874543
# AC_std =  0.267891222552
# SE_mean =  0.3
# SE_std =  0.458257569496
# SP_mean =  0.7
# SP_std =  0.458257569496
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type013, l2_penalty_5.623413 ...
# AC_mean =  0.639445874543
# AC_std =  0.267891222552
# SE_mean =  0.3
# SE_std =  0.458257569496
# SP_mean =  0.7
# SP_std =  0.458257569496
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type013, l2_penalty_10.000000 ...
# AC_mean =  0.639445874543
# AC_std =  0.267891222552
# SE_mean =  0.3
# SE_std =  0.458257569496
# SP_mean =  0.7
# SP_std =  0.458257569496
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type013, l2_penalty_17.782794 ...
# AC_mean =  0.639445874543
# AC_std =  0.267891222552
# SE_mean =  0.3
# SE_std =  0.458257569496
# SP_mean =  0.7
# SP_std =  0.458257569496
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type013, l2_penalty_31.622777 ...
# AC_mean =  0.639445874543
# AC_std =  0.267891222552
# SE_mean =  0.3
# SE_std =  0.458257569496
# SP_mean =  0.7
# SP_std =  0.458257569496
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type023, l2_penalty_0.010000 ...
# AC_mean =  0.304816420539
# AC_std =  0.230465245442
# SE_mean =  0.8
# SE_std =  0.4
# SP_mean =  0.2
# SP_std =  0.4
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type023, l2_penalty_0.017783 ...
# AC_mean =  0.36219346972
# AC_std =  0.268738198363
# SE_mean =  0.7
# SE_std =  0.458257569496
# SP_mean =  0.3
# SP_std =  0.458257569496
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type023, l2_penalty_0.031623 ...
# AC_mean =  0.436905568351
# AC_std =  0.29093518435
# SE_mean =  0.6
# SE_std =  0.489897948557
# SP_mean =  0.404901960784
# SP_std =  0.486101526791
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type023, l2_penalty_0.056234 ...
# AC_mean =  0.432807207695
# AC_std =  0.294441823982
# SE_mean =  0.6
# SE_std =  0.489897948557
# SP_mean =  0.4
# SP_std =  0.489897948557
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type023, l2_penalty_0.100000 ...
# AC_mean =  0.437725240482
# AC_std =  0.300525843218
# SE_mean =  0.622222222222
# SE_std =  0.466666666667
# SP_mean =  0.4
# SP_std =  0.489897948557
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type023, l2_penalty_0.177828 ...
# AC_mean =  0.50002032245
# AC_std =  0.302011355142
# SE_mean =  0.5
# SE_std =  0.5
# SP_mean =  0.5
# SP_std =  0.5
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type023, l2_penalty_0.316228 ...
# AC_mean =  0.50002032245
# AC_std =  0.302011355142
# SE_mean =  0.5
# SE_std =  0.5
# SP_mean =  0.5
# SP_std =  0.5
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type023, l2_penalty_0.562341 ...
# AC_mean =  0.432807207695
# AC_std =  0.294441823982
# SE_mean =  0.6
# SE_std =  0.489897948557
# SP_mean =  0.4
# SP_std =  0.489897948557
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type023, l2_penalty_1.000000 ...
# AC_mean =  0.432807207695
# AC_std =  0.294441823982
# SE_mean =  0.6
# SE_std =  0.489897948557
# SP_mean =  0.4
# SP_std =  0.489897948557
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type023, l2_penalty_1.778279 ...
# AC_mean =  0.496443571332
# AC_std =  0.301990415183
# SE_mean =  0.5
# SE_std =  0.5
# SP_mean =  0.5
# SP_std =  0.5
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type023, l2_penalty_3.162278 ...
# AC_mean =  0.496443571332
# AC_std =  0.301990415183
# SE_mean =  0.5
# SE_std =  0.5
# SP_mean =  0.5
# SP_std =  0.5
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type023, l2_penalty_5.623413 ...
# AC_mean =  0.496443571332
# AC_std =  0.301990415183
# SE_mean =  0.5
# SE_std =  0.5
# SP_mean =  0.5
# SP_std =  0.5
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type023, l2_penalty_10.000000 ...
# AC_mean =  0.432807207695
# AC_std =  0.294441823982
# SE_mean =  0.6
# SE_std =  0.489897948557
# SP_mean =  0.4
# SP_std =  0.489897948557
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type023, l2_penalty_17.782794 ...
# AC_mean =  0.432807207695
# AC_std =  0.294441823982
# SE_mean =  0.6
# SE_std =  0.489897948557
# SP_mean =  0.4
# SP_std =  0.489897948557
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type023, l2_penalty_31.622777 ...
# AC_mean =  0.432807207695
# AC_std =  0.294441823982
# SE_mean =  0.6
# SE_std =  0.489897948557
# SP_mean =  0.4
# SP_std =  0.489897948557
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type123, l2_penalty_0.010000 ...
# AC_mean =  0.744709388972
# AC_std =  0.196075906534
# SE_mean =  0.161323663565
# SE_std =  0.302854879467
# SP_mean =  0.898958333333
# SP_std =  0.299668871076
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type123, l2_penalty_0.017783 ...
# AC_mean =  0.814970871156
# AC_std =  0.0202040356326
# SE_mean =  0.0757740024981
# SE_std =  0.118860225616
# SP_mean =  0.995822368421
# SP_std =  0.00955426484878
#
# ----------------------------------------
# ...
# AC_mean =  0.798967383564
# AC_std =  0.0484701728778
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type002, l2_penalty_0.100000 ...
# AC_mean =  0.798967383564
# AC_std =  0.0484701728778
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type002, l2_penalty_0.177828 ...
# AC_mean =  0.798967383564
# AC_std =  0.0484701728778
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type002, l2_penalty_0.316228 ...
# AC_mean =  0.798967383564
# AC_std =  0.0484701728778
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type002, l2_penalty_0.562341 ...
# AC_mean =  0.798967383564
# AC_std =  0.0484701728778
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type002, l2_penalty_1.000000 ...
# AC_mean =  0.798967383564
# AC_std =  0.0484701728778
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type002, l2_penalty_1.778279 ...
# AC_mean =  0.798967383564
# AC_std =  0.0484701728778
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type002, l2_penalty_3.162278 ...
# AC_mean =  0.798967383564
# AC_std =  0.0484701728778
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type002, l2_penalty_5.623413 ...
# AC_mean =  0.798967383564
# AC_std =  0.0484701728778
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type002, l2_penalty_10.000000 ...
# AC_mean =  0.798967383564
# AC_std =  0.0484701728778
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type002, l2_penalty_17.782794 ...
# AC_mean =  0.798967383564
# AC_std =  0.0484701728778
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type002, l2_penalty_31.622777 ...
# AC_mean =  0.798967383564
# AC_std =  0.0484701728778
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type003, l2_penalty_0.010000 ...
# AC_mean =  0.798967383564
# AC_std =  0.0484701728778
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type003, l2_penalty_0.017783 ...
# AC_mean =  0.739645349665
# AC_std =  0.185205184802
# SE_mean =  0.1
# SE_std =  0.3
# SP_mean =  0.9
# SP_std =  0.3
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type003, l2_penalty_0.031623 ...
# AC_mean =  0.798967383564
# AC_std =  0.0484701728778
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type003, l2_penalty_0.056234 ...
# AC_mean =  0.798967383564
# AC_std =  0.0484701728778
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type003, l2_penalty_0.100000 ...
# AC_mean =  0.798967383564
# AC_std =  0.0484701728778
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type003, l2_penalty_0.177828 ...
# AC_mean =  0.798967383564
# AC_std =  0.0484701728778
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type003, l2_penalty_0.316228 ...
# AC_mean =  0.798967383564
# AC_std =  0.0484701728778
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type003, l2_penalty_0.562341 ...
# AC_mean =  0.798967383564
# AC_std =  0.0484701728778
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type003, l2_penalty_1.000000 ...
# AC_mean =  0.798967383564
# AC_std =  0.0484701728778
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type003, l2_penalty_1.778279 ...
# AC_mean =  0.798967383564
# AC_std =  0.0484701728778
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type003, l2_penalty_3.162278 ...
# AC_mean =  0.798967383564
# AC_std =  0.0484701728778
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type003, l2_penalty_5.623413 ...
# AC_mean =  0.798967383564
# AC_std =  0.0484701728778
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type003, l2_penalty_10.000000 ...
# AC_mean =  0.798967383564
# AC_std =  0.0484701728778
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type003, l2_penalty_17.782794 ...
# AC_mean =  0.798967383564
# AC_std =  0.0484701728778
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type003, l2_penalty_31.622777 ...
# AC_mean =  0.798967383564
# AC_std =  0.0484701728778
# SE_mean =  0.0
# SE_std =  0.0
# SP_mean =  1.0
# SP_std =  0.0
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type012, l2_penalty_0.010000 ...
# AC_mean =  0.675238570004
# AC_std =  0.247026916907
# SE_mean =  0.2
# SE_std =  0.4
# SP_mean =  0.8
# SP_std =  0.4
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type012, l2_penalty_0.017783 ...
# AC_mean =  0.564285714286
# AC_std =  0.297711918826
# SE_mean =  0.408333333333
# SE_std =  0.483692395364
# SP_mean =  0.6
# SP_std =  0.489897948557
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type012, l2_penalty_0.031623 ...
# AC_mean =  0.600968523002
# AC_std =  0.282777982798
# SE_mean =  0.385714285714
# SE_std =  0.474018857801
# SP_mean =  0.678350515464
# SP_std =  0.448585121136
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type012, l2_penalty_0.056234 ...
# AC_mean =  0.49321321749
# AC_std =  0.304545081446
# SE_mean =  0.517391304348
# SE_std =  0.485109073152
# SP_mean =  0.497894736842
# SP_std =  0.497930342557
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type012, l2_penalty_0.100000 ...
# AC_mean =  0.55454351232
# AC_std =  0.29791921616
# SE_mean =  0.4
# SE_std =  0.489897948557
# SP_mean =  0.6
# SP_std =  0.489897948557
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type012, l2_penalty_0.177828 ...
# AC_mean =  0.467632815838
# AC_std =  0.301136546243
# SE_mean =  0.6
# SE_std =  0.489897948557
# SP_mean =  0.4
# SP_std =  0.489897948557
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type012, l2_penalty_0.316228 ...
# AC_mean =  0.512170630964
# AC_std =  0.302626386549
# SE_mean =  0.5
# SE_std =  0.5
# SP_mean =  0.5
# SP_std =  0.5
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type012, l2_penalty_0.562341 ...
# AC_mean =  0.451153681812
# AC_std =  0.298906158005
# SE_mean =  0.6
# SE_std =  0.489897948557
# SP_mean =  0.4
# SP_std =  0.489897948557
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type012, l2_penalty_1.000000 ...
# AC_mean =  0.451153681812
# AC_std =  0.298906158005
# SE_mean =  0.6
# SE_std =  0.489897948557
# SP_mean =  0.4
# SP_std =  0.489897948557
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type012, l2_penalty_1.778279 ...
# AC_mean =  0.451153681812
# AC_std =  0.298906158005
# SE_mean =  0.6
# SE_std =  0.489897948557
# SP_mean =  0.4
# SP_std =  0.489897948557
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type012, l2_penalty_3.162278 ...
# AC_mean =  0.451153681812
# AC_std =  0.298906158005
# SE_mean =  0.6
# SE_std =  0.489897948557
# SP_mean =  0.4
# SP_std =  0.489897948557
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type012, l2_penalty_5.623413 ...
# AC_mean =  0.451153681812
# AC_std =  0.298906158005
# SE_mean =  0.6
# SE_std =  0.489897948557
# SP_mean =  0.4
# SP_std =  0.489897948557
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type012, l2_penalty_10.000000 ...
# AC_mean =  0.493526563168
# AC_std =  0.302801830756
# SE_mean =  0.5
# SE_std =  0.5
# SP_mean =  0.5
# SP_std =  0.5
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type012, l2_penalty_17.782794 ...
# AC_mean =  0.493526563168
# AC_std =  0.302801830756
# SE_mean =  0.5
# SE_std =  0.5
# SP_mean =  0.5
# SP_std =  0.5
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type012, l2_penalty_31.622777 ...
# AC_mean =  0.493526563168
# AC_std =  0.302801830756
# SE_mean =  0.5
# SE_std =  0.5
# SP_mean =  0.5
# SP_std =  0.5
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type013, l2_penalty_0.010000 ...
# AC_mean =  0.633905426577
# AC_std =  0.271661905365
# SE_mean =  0.3
# SE_std =  0.458257569496
# SP_mean =  0.7
# SP_std =  0.458257569496
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type013, l2_penalty_0.017783 ...
# AC_mean =  0.455583250249
# AC_std =  0.301365093186
# SE_mean =  0.608695652174
# SE_std =  0.479839292568
# SP_mean =  0.4
# SP_std =  0.489897948557
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type013, l2_penalty_0.031623 ...
# AC_mean =  0.452193419741
# AC_std =  0.299074213161
# SE_mean =  0.6
# SE_std =  0.489897948557
# SP_mean =  0.4
# SP_std =  0.489897948557
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type013, l2_penalty_0.056234 ...
# AC_mean =  0.516600199402
# AC_std =  0.302415752687
# SE_mean =  0.5
# SE_std =  0.5
# SP_mean =  0.5
# SP_std =  0.5
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type013, l2_penalty_0.100000 ...
# AC_mean =  0.516600199402
# AC_std =  0.302415752687
# SE_mean =  0.5
# SE_std =  0.5
# SP_mean =  0.5
# SP_std =  0.5
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type013, l2_penalty_0.177828 ...
# AC_mean =  0.455583250249
# AC_std =  0.299596405912
# SE_mean =  0.6
# SE_std =  0.489897948557
# SP_mean =  0.4
# SP_std =  0.489897948557
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type013, l2_penalty_0.316228 ...
# AC_mean =  0.455583250249
# AC_std =  0.299596405912
# SE_mean =  0.6
# SE_std =  0.489897948557
# SP_mean =  0.4
# SP_std =  0.489897948557
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type013, l2_penalty_0.562341 ...
# AC_mean =  0.455583250249
# AC_std =  0.299596405912
# SE_mean =  0.6
# SE_std =  0.489897948557
# SP_mean =  0.4
# SP_std =  0.489897948557
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type013, l2_penalty_1.000000 ...
# AC_mean =  0.455583250249
# AC_std =  0.299596405912
# SE_mean =  0.6
# SE_std =  0.489897948557
# SP_mean =  0.4
# SP_std =  0.489897948557
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type013, l2_penalty_1.778279 ...
# AC_mean =  0.455583250249
# AC_std =  0.299596405912
# SE_mean =  0.6
# SE_std =  0.489897948557
# SP_mean =  0.4
# SP_std =  0.489897948557
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type013, l2_penalty_3.162278 ...
# AC_mean =  0.455583250249
# AC_std =  0.299596405912
# SE_mean =  0.6
# SE_std =  0.489897948557
# SP_mean =  0.4
# SP_std =  0.489897948557
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type013, l2_penalty_5.623413 ...
# AC_mean =  0.455583250249
# AC_std =  0.299596405912
# SE_mean =  0.6
# SE_std =  0.489897948557
# SP_mean =  0.4
# SP_std =  0.489897948557
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type013, l2_penalty_10.000000 ...
# AC_mean =  0.455583250249
# AC_std =  0.299596405912
# SE_mean =  0.6
# SE_std =  0.489897948557
# SP_mean =  0.4
# SP_std =  0.489897948557
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type013, l2_penalty_17.782794 ...
# AC_mean =  0.455583250249
# AC_std =  0.299596405912
# SE_mean =  0.6
# SE_std =  0.489897948557
# SP_mean =  0.4
# SP_std =  0.489897948557
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type013, l2_penalty_31.622777 ...
# AC_mean =  0.455583250249
# AC_std =  0.299596405912
# SE_mean =  0.6
# SE_std =  0.489897948557
# SP_mean =  0.4
# SP_std =  0.489897948557
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type023, l2_penalty_0.010000 ...
# AC_mean =  0.295285571856
# AC_std =  0.205712978959
# SE_mean =  0.9
# SE_std =  0.3
# SP_mean =  0.119791666667
# SP_std =  0.299277558951
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type023, l2_penalty_0.017783 ...
# AC_mean =  0.312234724398
# AC_std =  0.214736242983
# SE_mean =  0.880952380952
# SE_std =  0.299091595189
# SP_mean =  0.144329896907
# SP_std =  0.314356928438
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type023, l2_penalty_0.031623 ...
# AC_mean =  0.402414186013
# AC_std =  0.287874378735
# SE_mean =  0.707692307692
# SE_std =  0.446948893733
# SP_mean =  0.3
# SP_std =  0.458257569496
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type023, l2_penalty_0.056234 ...
# AC_mean =  0.401573849879
# AC_std =  0.286431749403
# SE_mean =  0.7
# SE_std =  0.458257569496
# SP_mean =  0.3
# SP_std =  0.458257569496
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type023, l2_penalty_0.100000 ...
# AC_mean =  0.401573849879
# AC_std =  0.286431749403
# SE_mean =  0.7
# SE_std =  0.458257569496
# SP_mean =  0.3
# SP_std =  0.458257569496
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type023, l2_penalty_0.177828 ...
# AC_mean =  0.402414186013
# AC_std =  0.287874378735
# SE_mean =  0.707692307692
# SE_std =  0.446948893733
# SP_mean =  0.3
# SP_std =  0.458257569496
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type023, l2_penalty_0.316228 ...
# AC_mean =  0.338007406352
# AC_std =  0.257202349575
# SE_mean =  0.846153846154
# SE_std =  0.324538817073
# SP_mean =  0.195283018868
# SP_std =  0.390708432706
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type023, l2_penalty_0.562341 ...
# AC_mean =  0.337167070218
# AC_std =  0.255374805085
# SE_mean =  0.846153846154
# SE_std =  0.324538817073
# SP_mean =  0.194339622642
# SP_std =  0.388885272379
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type023, l2_penalty_1.000000 ...
# AC_mean =  0.322041019798
# AC_std =  0.245074387603
# SE_mean =  0.8
# SE_std =  0.4
# SP_mean =  0.2
# SP_std =  0.4
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type023, l2_penalty_1.778279 ...
# AC_mean =  0.400192280302
# AC_std =  0.285953270977
# SE_mean =  0.7
# SE_std =  0.458257569496
# SP_mean =  0.3
# SP_std =  0.458257569496
#
# ----------------------------------------
# Classifying --> classifier: SVM, feature_type023, l2_penalty_3.162278 ...

# %%
# load and organize feature matrix
def lz_load_feature_matrix(mouse_id, window_length, window_step):
    fileName = "format4ML_GC6f_emx_0" + str(mouse_id) + "_windowLen" + str(window_length) + "_winStep_0" + str(window_step) + "_v2_threshold_10.csv"
    loadPath = "/Users/lizhu/Dropbox/projects/calcium/format4ML/" + fileName
    comb = gl.SFrame.read_csv(loadPath, delimiter=',',header=False,verbose = False)
    colName_dg = 'degree'
    colName_dg = gl.SArray([colName_dg + repr(i+1) for i in range(30)])
    colName_cc = 'clusteringCoef'
    colName_cc = gl.SArray([colName_cc + repr(i+1) for i in range(30)])
    colName_pl = 'pathlength'
    colName_pl = gl.SArray([colName_pl + repr(i+1) for i in range(30)])
    colName = colName_dg.append(colName_cc.append(colName_pl.append(gl.SArray(['Whisker']))))
    colName = (list(colName))
    dictionary = dict(zip(comb.column_names(), colName))
    comb = comb.rename(dictionary)
    comb = gl.toolkits.cross_validation.shuffle(comb, random_seed=1)
    # comb['Whisker'].show(view = 'Categorical')
    
    return comb

# %%
# train and cross-validation
def lz_svm_AC_SE_SP(data, feature_type, l2_penalty):
    
    # clearify features
    feature_dg = comb.column_names()[0:30] # feature 1~30: degree, 31~60: clustering coefficient, 60~90: pathlength
    feature_cc = comb.column_names()[30:60]
    feature_pl = comb.column_names()[60:90]
    
    if feature_type == 1:   feature = feature_dg
    if feature_type == 2:   feature = feature_cc
    if feature_type == 3:   feature = feature_pl
    if feature_type == 12:  feature = feature_dg + feature_cc
    if feature_type == 13:  feature = feature_dg + feature_pl
    if feature_type == 23:  feature = feature_cc + feature_pl
    if feature_type == 123: feature = feature_dg + feature_cc + feature_pl
     
    # Kfold
    num_fold = 10
    folds = gl.cross_validation.KFold(comb, num_fold)
    SE = [None] * num_fold
    SP = [None] * num_fold
    AC = [None] * num_fold
    # print specificity
    idx = 0
    for train, valid in folds:
        m = gl.svm_classifier.create(train,
                                      target='Whisker',
                                      features=feature,
                                      penalty = l2_penalty, 
                                      convergence_threshold = 0.001,
                                      validation_set=None,
                                      verbose = False)
        confusion_matrix = m.evaluate(valid, 'confusion_matrix')
        confusion_matrix = confusion_matrix.values()[0]
        
        TP, TN, FP, FN = lz_extract_ACC_SE_SP(confusion_matrix)
        
        SP[idx] = float(TN) / (TN + FP)
        SE[idx] = float(TP) / (TP + FN)
        AC[idx] = float(TP+TN) / (TP+TN+FP+FN)
        idx = idx + 1
        
    AC_mn = np.mean(AC)
    AC_sd = np.std(AC)
    SE_mn = np.mean(SE)
    SE_sd = np.std(SE)
    SP_mn = np.mean(SP)
    SP_sd = np.std(SP)
    
    print 'AC_mean = ', AC_mn
    print 'AC_std = ',  AC_sd
    print 'SE_mean = ', SE_mn
    print 'SE_std = ',  SE_sd
    print 'SP_mean = ', SP_mn
    print 'SP_std = ',  SP_sd
    
    return AC_mn, SE_mn, SP_mn

# %%
# train and cross-validation
def lz_logistic_AC_SE_SP(data, feature_type, l2_penalty, l1_penalty):
    
    # clearify features
    feature_dg = comb.column_names()[0:30] # feature 1~30: degree, 31~60: clustering coefficient, 60~90: pathlength
    feature_cc = comb.column_names()[30:60]
    feature_pl = comb.column_names()[60:90]
    
    if feature_type == 1:   feature = feature_dg
    if feature_type == 2:   feature = feature_cc
    if feature_type == 3:   feature = feature_pl
    if feature_type == 12:  feature = feature_dg + feature_cc
    if feature_type == 13:  feature = feature_dg + feature_pl
    if feature_type == 23:  feature = feature_cc + feature_pl
    if feature_type == 123: feature = feature_dg + feature_cc + feature_pl
     
    # Kfold
    num_fold = 10
    folds = gl.cross_validation.KFold(comb, num_fold)
    SE = [None] * num_fold
    SP = [None] * num_fold
    AC = [None] * num_fold
    # print specificity
    idx = 0
    for train, valid in folds:
        m = gl.logistic_classifier.create(train,
                                          target='Whisker',
                                          features=feature,
                                          l2_penalty = l2_penalty, 
                                          l1_penalty = l1_penalty,
                                          validation_set=None,
                                          verbose = False)
        confusion_matrix = m.evaluate(valid, 'confusion_matrix')
        confusion_matrix = confusion_matrix.values()[0]
        
        TP, TN, FP, FN = lz_extract_ACC_SE_SP(confusion_matrix)
        
        SP[idx] = float(TN) / (TN + FP)
        SE[idx] = float(TP) / (TP + FN)
        AC[idx] = float(TP+TN) / (TP+TN+FP+FN)
        idx = idx + 1
        
    AC_mn = np.mean(AC)
    AC_sd = np.std(AC)
    SE_mn = np.mean(SE)
    SE_sd = np.std(SE)
    SP_mn = np.mean(SP)
    SP_sd = np.std(SP)
    
    print 'AC_mean = ', AC_mn
    print 'AC_std = ',  AC_sd
    print 'SE_mean = ', SE_mn
    print 'SE_std = ',  SE_sd
    print 'SP_mean = ', SP_mn
    print 'SP_std = ',  SP_sd
    
    return AC_mn, SE_mn, SP_mn

# %%
def lz_extract_ACC_SE_SP(confusion_matrix):
    TP = confusion_matrix[(confusion_matrix['target_label']==1) & (confusion_matrix['predicted_label']==1)]
    if np.size(TP) == 0:
        TP = 0
    else:
        TP = TP['count'][0]
    TN = confusion_matrix[(confusion_matrix['target_label']==0) & (confusion_matrix['predicted_label']==0)]
    if np.size(TN) == 0:
        TN = 0
    else:
        TN = TN['count'][0]
    FP = confusion_matrix[(confusion_matrix['target_label']==0) & (confusion_matrix['predicted_label']==1)]
    if np.size(FP) == 0:
        FP = 0
    else:
        FP = FP['count'][0]
    FN = confusion_matrix[(confusion_matrix['target_label']==1) & (confusion_matrix['predicted_label']==0)]
    if np.size(FN) == 0:
        FN = 0
    else:
        FN = FN['count'][0]
    
    return TP, TN, FP, FN

# %%
############### this is the normalized version of the above code

# normalize the features
# feature_matrix is a SFrame, first 90 columns are features, last column is labels.
def normalize_features_mice(comb):
    # extract feature columns
    comb_np = comb.to_numpy()
    comb_feature = comb_np[:,0:90]
    
    # compute normed features and norms 
    norms = np.linalg.norm(comb_feature, axis=0) # gives [norm(X[:,0]), norm(X[:,1]), norm(X[:,2])]
    comb_feature_normed = comb_feature / norms
    
    # combine normalized feature vectors and the labels
    comb_normed = np.concatenate((comb_feature_normed,comb_np[:,90:91]),axis = 1)
    # convert numpy array to SFrame
    comb_normed = gl.SFrame(comb_normed)
    comb_normed = comb_normed.unpack('X1', '')
    dictionary_norm = dict(zip(comb_normed.column_names(), colName))
    comb_normed = comb_normed.rename(dictionary_norm) # this is the normed version

    return comb_normed, norms # note: norms is array, comb_normed is SFrame

# comb = gl.toolkits.cross_validation.shuffle(comb, random_seed=2)
def lz_logistic(data, feature):
    
    # normalize 
    comb, norms = normalize_features_mice(data)
    comb['Whisker'] = comb['Whisker'].astype(int)

    folds = gl.cross_validation.KFold(comb, 5)
    SE=[None]*5
    SP=[None]*5
    acc=[None]*5
    # print specificity
    idx = 0
    for train, valid in folds:
        m = gl.logistic_classifier.create(train,
                                          target='Whisker',
                                          features=feature,
                                          l2_penalty = 0.05,
                                          validation_set=None,
                                          verbose = False)
        
        # normalize the validation dataset
        valid_np = valid.to_numpy()
        valid_feature = valid_np[:,0:90]

        # use normed from features
        valid_feature_normed = valid_feature / norms

        # combine normalized feature vectors and the labels
        valid_normed = np.concatenate((valid_feature_normed,valid_np[:,90:91]),axis = 1)

        # convert numpy array to SFrame
        valid_normed = gl.SFrame(valid_normed)
        valid_normed = valid_normed.unpack('X1', '')
        dictionary_norm = dict(zip(valid_normed.column_names(), colName))
        valid_normed = valid_normed.rename(dictionary_norm) # this is the normed version
        valid_normed['Whisker'] = valid_normed['Whisker'].astype(int)

        confusion_matrix = m.evaluate(valid, 'confusion_matrix')
        confusion_matrix = confusion_matrix.values()[0]
        TP = confusion_matrix[(confusion_matrix['target_label']==1) & (confusion_matrix['predicted_label']==1)]
        if np.size(TP) == 0:
            TP = 0
        else:
            TP = TP['count'][0]
        TN = confusion_matrix[(confusion_matrix['target_label']==0) & (confusion_matrix['predicted_label']==0)]
        if np.size(TN) == 0:
            TN = 0
        else:
            TN = TN['count'][0]
        FP = confusion_matrix[(confusion_matrix['target_label']==0) & (confusion_matrix['predicted_label']==1)]
        if np.size(FP) == 0:
            FP = 0
        else:
            FP = FP['count'][0]
        FN = confusion_matrix[(confusion_matrix['target_label']==1) & (confusion_matrix['predicted_label']==0)]
        if np.size(FN) == 0:
            FN = 0
        else:
            FN = FN['count'][0]
        SE[idx] = float(TN) / (TN + FP)
        SP[idx] = float(TP) / (TP + FN)
        acc[idx] = float(TP+TN) / (TP+TN+FP+FN)
        idx = idx + 1
    
    print 'acc_mean = ', np.mean(acc)
    print 'acc_std = ', np.std(acc)
    print 'SE_mean = ', np.mean(SE)
    print 'SE_std = ', np.std(SE)
    print 'SP_mean = ', np.mean(SP)
    print 'SP_std = ', np.std(SP)
    
    return acc, SE, SP

# normalize

feature = comb.column_names()[60:90] 

acc,SE,SP = lz_logistic(comb, feature)

# %%
# exploring the data
num_wm = len(comb[comb['Whisker']==1])
num_wn = len(comb[comb['Whisker']==0])
# major class classifier(naive classifier)
major_classifier = float(num_wn)/(num_wm + num_wn)
major_classifier
num_wn

# %%
train_data,test_data = comb.random_split(.8, seed=0)
# train_valid_shuffled = graphlab.toolkits.cross_validation.shuffle(train_valid, random_seed=1)
train_data = gl.toolkits.cross_validation.shuffle(train_data, random_seed=1)

# %%
folds = gl.cross_validation.KFold(comb, 5)
folds
params = dict([('target', 'Whisker'), ('features', comb.column_names()[0:90]), ('validation_set', None)])

all_feature_model = gl.cross_validation.cross_val_score(folds,
                                              gl.logistic_classifier.create,
                                              params)

# %%
# print all_feature_model.get_results()
all_feature_model.get_results()

# %%
mylist = sum([range(0,30)] + [range(60,90)],[])
mylist[0:3,5]

# %%
type(colName)

# %%
whisker_model.evaluate(test_data)

# %%
## Weight 
weight = whisker_model['coefficients'].sort('value', ascending=False)
weight['name']

# %%
##
